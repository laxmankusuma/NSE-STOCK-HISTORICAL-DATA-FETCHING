# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa351 = data.DataReader('M&M.NS', 'yahoo', start_date, end_date)
panel_dataa352 = data.DataReader('ZODJRDMKJ.NS', 'yahoo', start_date, end_date)
panel_dataa353 = data.DataReader('GOACARBON.NS', 'yahoo', start_date, end_date)
panel_dataa354 = data.DataReader('GODFRYPHLP.NS', 'yahoo', start_date, end_date)
panel_dataa355 = data.DataReader('TIINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa356 = data.DataReader('JINDALPOLY.NS', 'yahoo', start_date, end_date)
panel_dataa357 = data.DataReader('EIHAHOTELS.NS', 'yahoo', start_date, end_date)
panel_dataa358 = data.DataReader('KNRCON.NS', 'yahoo', start_date, end_date)
panel_dataa359 = data.DataReader('ARVSMART.NS', 'yahoo', start_date, end_date)
panel_dataa360 = data.DataReader('ROHLTD.NS', 'yahoo', start_date, end_date)
panel_dataa361 = data.DataReader('DLINKINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa362 = data.DataReader('SANGHVIMOV.NS', 'yahoo', start_date, end_date)
panel_dataa363 = data.DataReader('ORIENTCEM.NS', 'yahoo', start_date, end_date)
panel_dataa364 = data.DataReader('SHANTIGEAR.NS', 'yahoo', start_date, end_date)
panel_dataa365 = data.DataReader('SFL.NS', 'yahoo', start_date, end_date)
panel_dataa366 = data.DataReader('CREDITACC.NS', 'yahoo', start_date, end_date)
panel_dataa367 = data.DataReader('PRAJIND.NS', 'yahoo', start_date, end_date)
panel_dataa368 = data.DataReader('VESUVIUS.NS', 'yahoo', start_date, end_date)
panel_dataa369 = data.DataReader('JAYAGROGN.NS', 'yahoo', start_date, end_date)
panel_dataa370 = data.DataReader('MUTHOOTCAP.NS', 'yahoo', start_date, end_date)
panel_dataa371 = data.DataReader('HGS.NS', 'yahoo', start_date, end_date)
panel_dataa372 = data.DataReader('SHREYAS.NS', 'yahoo', start_date, end_date)
panel_dataa373 = data.DataReader('BIGBLOC.NS', 'yahoo', start_date, end_date)
panel_dataa374 = data.DataReader('OPTOCIRCUI.NS', 'yahoo', start_date, end_date)
panel_dataa375 = data.DataReader('KIRLOSBROS.NS', 'yahoo', start_date, end_date)
panel_dataa376 = data.DataReader('BBL.NS', 'yahoo', start_date, end_date)
panel_dataa377 = data.DataReader('PDMJEPAPER.NS', 'yahoo', start_date, end_date)
panel_dataa378 = data.DataReader('CORDSCABLE.NS', 'yahoo', start_date, end_date)
panel_dataa379 = data.DataReader('DBL.NS', 'yahoo', start_date, end_date)
panel_dataa380 = data.DataReader('GMDCLTD.NS', 'yahoo', start_date, end_date)
panel_dataa381 = data.DataReader('LT.NS', 'yahoo', start_date, end_date)
panel_dataa382 = data.DataReader('BALAJITELE.NS', 'yahoo', start_date, end_date)
panel_dataa383 = data.DataReader('AHLUCONT.NS', 'yahoo', start_date, end_date)
panel_dataa384 = data.DataReader('NH.NS', 'yahoo', start_date, end_date)
panel_dataa385 = data.DataReader('NFL.NS', 'yahoo', start_date, end_date)
panel_dataa386 = data.DataReader('PANACEABIO.NS', 'yahoo', start_date, end_date)
panel_dataa387 = data.DataReader('SIMBHALS.NS', 'yahoo', start_date, end_date)
panel_dataa388 = data.DataReader('GENUSPAPER.NS', 'yahoo', start_date, end_date)
panel_dataa389 = data.DataReader('21STCENMGM.NS', 'yahoo', start_date, end_date)
panel_dataa390 = data.DataReader('SUNDARMFIN.NS', 'yahoo', start_date, end_date)
panel_dataa391 = data.DataReader('GODREJIND.NS', 'yahoo', start_date, end_date)
panel_dataa392 = data.DataReader('DISHTV.NS', 'yahoo', start_date, end_date)
panel_dataa393 = data.DataReader('TNPL.NS', 'yahoo', start_date, end_date)
panel_dataa394 = data.DataReader('ALKYLAMINE.NS', 'yahoo', start_date, end_date)
panel_dataa395 = data.DataReader('COMPUSOFT.NS', 'yahoo', start_date, end_date)
panel_dataa396 = data.DataReader('IBULISL.NS', 'yahoo', start_date, end_date)
panel_dataa397 = data.DataReader('CTE.NS', 'yahoo', start_date, end_date)
panel_dataa398 = data.DataReader('APOLLOPIPE.NS', 'yahoo', start_date, end_date)
panel_dataa399 = data.DataReader('SOBHA.NS', 'yahoo', start_date, end_date)
panel_dataa400 = data.DataReader('PARAGMILK.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa351['SYMBOL']='M&M.NS'
panel_dataa352['SYMBOL']='ZODJRDMKJ.NS'
panel_dataa353['SYMBOL']='GOACARBON.NS'
panel_dataa354['SYMBOL']='GODFRYPHLP.NS'
panel_dataa355['SYMBOL']='TIINDIA.NS'
panel_dataa356['SYMBOL']='JINDALPOLY.NS'
panel_dataa357['SYMBOL']='EIHAHOTELS.NS'
panel_dataa358['SYMBOL']='KNRCON.NS'
panel_dataa359['SYMBOL']='ARVSMART.NS'
panel_dataa360['SYMBOL']='ROHLTD.NS'
panel_dataa361['SYMBOL']='DLINKINDIA.NS'
panel_dataa362['SYMBOL']='SANGHVIMOV.NS'
panel_dataa363['SYMBOL']='ORIENTCEM.NS'
panel_dataa364['SYMBOL']='SHANTIGEAR.NS'
panel_dataa365['SYMBOL']='SFL.NS'
panel_dataa366['SYMBOL']='CREDITACC.NS'
panel_dataa367['SYMBOL']='PRAJIND.NS'
panel_dataa368['SYMBOL']='VESUVIUS.NS'
panel_dataa369['SYMBOL']='JAYAGROGN.NS'
panel_dataa370['SYMBOL']='MUTHOOTCAP.NS'
panel_dataa371['SYMBOL']='HGS.NS'
panel_dataa372['SYMBOL']='SHREYAS.NS'
panel_dataa373['SYMBOL']='BIGBLOC.NS'
panel_dataa374['SYMBOL']='OPTOCIRCUI.NS'
panel_dataa375['SYMBOL']='KIRLOSBROS.NS'
panel_dataa376['SYMBOL']='BBL.NS'
panel_dataa377['SYMBOL']='PDMJEPAPER.NS'
panel_dataa378['SYMBOL']='CORDSCABLE.NS'
panel_dataa379['SYMBOL']='DBL.NS'
panel_dataa380['SYMBOL']='GMDCLTD.NS'
panel_dataa381['SYMBOL']='LT.NS'
panel_dataa382['SYMBOL']='BALAJITELE.NS'
panel_dataa383['SYMBOL']='AHLUCONT.NS'
panel_dataa384['SYMBOL']='NH.NS'
panel_dataa385['SYMBOL']='NFL.NS'
panel_dataa386['SYMBOL']='PANACEABIO.NS'
panel_dataa387['SYMBOL']='SIMBHALS.NS'
panel_dataa388['SYMBOL']='GENUSPAPER.NS'
panel_dataa389['SYMBOL']='21STCENMGM.NS'
panel_dataa390['SYMBOL']='SUNDARMFIN.NS'
panel_dataa391['SYMBOL']='GODREJIND.NS'
panel_dataa392['SYMBOL']='DISHTV.NS'
panel_dataa393['SYMBOL']='TNPL.NS'
panel_dataa394['SYMBOL']='ALKYLAMINE.NS'
panel_dataa395['SYMBOL']='COMPUSOFT.NS'
panel_dataa396['SYMBOL']='IBULISL.NS'
panel_dataa397['SYMBOL']='CTE.NS'
panel_dataa398['SYMBOL']='APOLLOPIPE.NS'
panel_dataa399['SYMBOL']='SOBHA.NS'
panel_dataa400['SYMBOL']='PARAGMILK.NS'

# %%
finall = pd.concat([panel_dataa351,
panel_dataa352,
panel_dataa353,
panel_dataa354,
panel_dataa355,
panel_dataa356,
panel_dataa357,
panel_dataa358,
panel_dataa359,
panel_dataa360,
panel_dataa361,
panel_dataa362,
panel_dataa363,
panel_dataa364,
panel_dataa365,
panel_dataa366,
panel_dataa367,
panel_dataa368,
panel_dataa369,
panel_dataa370,
panel_dataa371,
panel_dataa372,
panel_dataa373,
panel_dataa374,
panel_dataa375,
panel_dataa376,
panel_dataa377,
panel_dataa378,
panel_dataa379,
panel_dataa380,
panel_dataa381,
panel_dataa382,
panel_dataa383,
panel_dataa384,
panel_dataa385,
panel_dataa386,
panel_dataa387,
panel_dataa388,
panel_dataa389,
panel_dataa390,
panel_dataa391,
panel_dataa392,
panel_dataa393,
panel_dataa394,
panel_dataa395,
panel_dataa396,
panel_dataa397,
panel_dataa398,
panel_dataa399,
panel_dataa400])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_351_TO_400_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_351_TO_400_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_351_TO_400_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...     Volume   Adj Close        SYMBOL
# 0                0  1996-01-01   41.437500  ...     3600.0    2.468105        M&M.NS
# 1                1  1996-01-02   40.687500  ...    15600.0    2.432919        M&M.NS
# 2                2  1996-01-03   26.250000  ...    17600.0    1.551698        M&M.NS
# 3                3  1996-01-04   25.750000  ...     8800.0    1.543750        M&M.NS
# 4                4  1996-01-05   25.750000  ...    15200.0    1.551698        M&M.NS
# ...            ...         ...         ...  ...        ...         ...           ...
# 150155      150155  2020-08-10   94.949997  ...   650295.0   92.900002  PARAGMILK.NS
# 150156      150156  2020-08-11  102.000000  ...  3554328.0   99.849998  PARAGMILK.NS
# 150157      150157  2020-08-12  104.000000  ...  2749190.0  101.800003  PARAGMILK.NS
# 150158      150158  2020-08-13  105.000000  ...  2521703.0  104.349998  PARAGMILK.NS
# ...
