# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa1001 = data.DataReader('SPIC.NS', 'yahoo', start_date, end_date)
panel_dataa1002 = data.DataReader('MAANALU.NS', 'yahoo', start_date, end_date)
panel_dataa1003 = data.DataReader('ICICIPRULI.NS', 'yahoo', start_date, end_date)
panel_dataa1004 = data.DataReader('ASTERDM.NS', 'yahoo', start_date, end_date)
panel_dataa1005 = data.DataReader('CHALET.NS', 'yahoo', start_date, end_date)
panel_dataa1006 = data.DataReader('GAIL.NS', 'yahoo', start_date, end_date)
panel_dataa1007 = data.DataReader('FORCEMOT.NS', 'yahoo', start_date, end_date)
panel_dataa1008 = data.DataReader('ORIENTELEC.NS', 'yahoo', start_date, end_date)
panel_dataa1009 = data.DataReader('ALPA.NS', 'yahoo', start_date, end_date)
panel_dataa1010 = data.DataReader('TCIEXP.NS', 'yahoo', start_date, end_date)
panel_dataa1011 = data.DataReader('LALPATHLAB.NS', 'yahoo', start_date, end_date)
panel_dataa1012 = data.DataReader('GRASIM.NS', 'yahoo', start_date, end_date)
panel_dataa1013 = data.DataReader('MIDHANI.NS', 'yahoo', start_date, end_date)
panel_dataa1014 = data.DataReader('BHAGERIA.NS', 'yahoo', start_date, end_date)
panel_dataa1015 = data.DataReader('RAIN.NS', 'yahoo', start_date, end_date)
panel_dataa1016 = data.DataReader('APLLTD.NS', 'yahoo', start_date, end_date)
panel_dataa1017 = data.DataReader('ELECON.NS', 'yahoo', start_date, end_date)
panel_dataa1018 = data.DataReader('ARCHIDPLY.NS', 'yahoo', start_date, end_date)
panel_dataa1019 = data.DataReader('SPANDANA.NS', 'yahoo', start_date, end_date)
panel_dataa1020 = data.DataReader('ZUARI.NS', 'yahoo', start_date, end_date)
panel_dataa1021 = data.DataReader('AUTOAXLES.NS', 'yahoo', start_date, end_date)
panel_dataa1022 = data.DataReader('CDSL.NS', 'yahoo', start_date, end_date)
panel_dataa1023 = data.DataReader('VAIBHAVGBL.NS', 'yahoo', start_date, end_date)
panel_dataa1024 = data.DataReader('MOLDTKPAC.NS', 'yahoo', start_date, end_date)
panel_dataa1025 = data.DataReader('PGHL.NS', 'yahoo', start_date, end_date)
panel_dataa1026 = data.DataReader('ATUL.NS', 'yahoo', start_date, end_date)
panel_dataa1027 = data.DataReader('DHAMPURSUG.NS', 'yahoo', start_date, end_date)
panel_dataa1028 = data.DataReader('TANLA.NS', 'yahoo', start_date, end_date)
panel_dataa1029 = data.DataReader('BFINVEST.NS', 'yahoo', start_date, end_date)
panel_dataa1030 = data.DataReader('SKFINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1031 = data.DataReader('DMART.NS', 'yahoo', start_date, end_date)
panel_dataa1032 = data.DataReader('KANSAINER.NS', 'yahoo', start_date, end_date)
panel_dataa1033 = data.DataReader('UCALFUEL.NS', 'yahoo', start_date, end_date)
panel_dataa1034 = data.DataReader('ADANIPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa1035 = data.DataReader('AEGISCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa1036 = data.DataReader('PFOCUS.NS', 'yahoo', start_date, end_date)
panel_dataa1037 = data.DataReader('PHILIPCARB.NS', 'yahoo', start_date, end_date)
panel_dataa1038 = data.DataReader('MOLDTECH.NS', 'yahoo', start_date, end_date)
panel_dataa1039 = data.DataReader('KSB.NS', 'yahoo', start_date, end_date)
panel_dataa1040 = data.DataReader('INOXWIND.NS', 'yahoo', start_date, end_date)
panel_dataa1041 = data.DataReader('IMFA.NS', 'yahoo', start_date, end_date)
panel_dataa1042 = data.DataReader('INDIAMART.NS', 'yahoo', start_date, end_date)
panel_dataa1043 = data.DataReader('ASTRON.NS', 'yahoo', start_date, end_date)
panel_dataa1044 = data.DataReader('STARCEMENT.NS', 'yahoo', start_date, end_date)
panel_dataa1045 = data.DataReader('CEATLTD.NS', 'yahoo', start_date, end_date)
panel_dataa1046 = data.DataReader('NAM-INDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1047 = data.DataReader('FSC.NS', 'yahoo', start_date, end_date)
panel_dataa1048 = data.DataReader('HINDALCO.NS', 'yahoo', start_date, end_date)
panel_dataa1049 = data.DataReader('REFEX.NS', 'yahoo', start_date, end_date)
panel_dataa1050 = data.DataReader('JKCEMENT.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1001['SYMBOL']='SPIC.NS'
panel_dataa1002['SYMBOL']='MAANALU.NS'
panel_dataa1003['SYMBOL']='ICICIPRULI.NS'
panel_dataa1004['SYMBOL']='ASTERDM.NS'
panel_dataa1005['SYMBOL']='CHALET.NS'
panel_dataa1006['SYMBOL']='GAIL.NS'
panel_dataa1007['SYMBOL']='FORCEMOT.NS'
panel_dataa1008['SYMBOL']='ORIENTELEC.NS'
panel_dataa1009['SYMBOL']='ALPA.NS'
panel_dataa1010['SYMBOL']='TCIEXP.NS'
panel_dataa1011['SYMBOL']='LALPATHLAB.NS'
panel_dataa1012['SYMBOL']='GRASIM.NS'
panel_dataa1013['SYMBOL']='MIDHANI.NS'
panel_dataa1014['SYMBOL']='BHAGERIA.NS'
panel_dataa1015['SYMBOL']='RAIN.NS'
panel_dataa1016['SYMBOL']='APLLTD.NS'
panel_dataa1017['SYMBOL']='ELECON.NS'
panel_dataa1018['SYMBOL']='ARCHIDPLY.NS'
panel_dataa1019['SYMBOL']='SPANDANA.NS'
panel_dataa1020['SYMBOL']='ZUARI.NS'
panel_dataa1021['SYMBOL']='AUTOAXLES.NS'
panel_dataa1022['SYMBOL']='CDSL.NS'
panel_dataa1023['SYMBOL']='VAIBHAVGBL.NS'
panel_dataa1024['SYMBOL']='MOLDTKPAC.NS'
panel_dataa1025['SYMBOL']='PGHL.NS'
panel_dataa1026['SYMBOL']='ATUL.NS'
panel_dataa1027['SYMBOL']='DHAMPURSUG.NS'
panel_dataa1028['SYMBOL']='TANLA.NS'
panel_dataa1029['SYMBOL']='BFINVEST.NS'
panel_dataa1030['SYMBOL']='SKFINDIA.NS'
panel_dataa1031['SYMBOL']='DMART.NS'
panel_dataa1032['SYMBOL']='KANSAINER.NS'
panel_dataa1033['SYMBOL']='UCALFUEL.NS'
panel_dataa1034['SYMBOL']='ADANIPOWER.NS'
panel_dataa1035['SYMBOL']='AEGISCHEM.NS'
panel_dataa1036['SYMBOL']='PFOCUS.NS'
panel_dataa1037['SYMBOL']='PHILIPCARB.NS'
panel_dataa1038['SYMBOL']='MOLDTECH.NS'
panel_dataa1039['SYMBOL']='KSB.NS'
panel_dataa1040['SYMBOL']='INOXWIND.NS'
panel_dataa1041['SYMBOL']='IMFA.NS'
panel_dataa1042['SYMBOL']='INDIAMART.NS'
panel_dataa1043['SYMBOL']='ASTRON.NS'
panel_dataa1044['SYMBOL']='STARCEMENT.NS'
panel_dataa1045['SYMBOL']='CEATLTD.NS'
panel_dataa1046['SYMBOL']='NAM-INDIA.NS'
panel_dataa1047['SYMBOL']='FSC.NS'
panel_dataa1048['SYMBOL']='HINDALCO.NS'
panel_dataa1049['SYMBOL']='REFEX.NS'
panel_dataa1050['SYMBOL']='JKCEMENT.NS'

# %%
finall = pd.concat([panel_dataa1001,
panel_dataa1002,
panel_dataa1003,
panel_dataa1004,
panel_dataa1005,
panel_dataa1006,
panel_dataa1007,
panel_dataa1008,
panel_dataa1009,
panel_dataa1010,
panel_dataa1011,
panel_dataa1012,
panel_dataa1013,
panel_dataa1014,
panel_dataa1015,
panel_dataa1016,
panel_dataa1017,
panel_dataa1018,
panel_dataa1019,
panel_dataa1020,
panel_dataa1021,
panel_dataa1022,
panel_dataa1023,
panel_dataa1024,
panel_dataa1025,
panel_dataa1026,
panel_dataa1027,
panel_dataa1028,
panel_dataa1029,
panel_dataa1030,
panel_dataa1031,
panel_dataa1032,
panel_dataa1033,
panel_dataa1034,
panel_dataa1035,
panel_dataa1036,
panel_dataa1037,
panel_dataa1038,
panel_dataa1039,
panel_dataa1040,
panel_dataa1041,
panel_dataa1042,
panel_dataa1043,
panel_dataa1044,
panel_dataa1045,
panel_dataa1046,
panel_dataa1047,
panel_dataa1048,
panel_dataa1049,
panel_dataa1050])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1001_TO_1050_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1001_TO_1050_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1001_TO_1050_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date         High  ...    Volume    Adj Close       SYMBOL
# 0                0  2002-07-01    10.650000  ...  463977.0    10.350000      SPIC.NS
# 1                1  2002-07-02    11.600000  ...  371253.0    11.400000      SPIC.NS
# 2                2  2002-07-03    12.400000  ...  440465.0    11.900000      SPIC.NS
# 3                3  2002-07-04    12.100000  ...   87343.0    11.650000      SPIC.NS
# 4                4  2002-07-05    12.250000  ...  162943.0    11.550000      SPIC.NS
# ...            ...         ...          ...  ...       ...          ...          ...
# 122378      122378  2020-08-10  1614.000000  ...   50446.0  1564.750000  JKCEMENT.NS
# 122379      122379  2020-08-11  1578.599976  ...   29649.0  1524.349976  JKCEMENT.NS
# 122380      122380  2020-08-12  1524.800049  ...   55570.0  1505.300049  JKCEMENT.NS
# 122381      122381  2020-08-13  1540.699951  ...   44362.0  1509.199951  JKCEMENT.NS
# ...
