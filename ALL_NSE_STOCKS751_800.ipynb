# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa751 = data.DataReader('EQUITAS.NS', 'yahoo', start_date, end_date)
panel_dataa752 = data.DataReader('SANGHVIFOR.NS', 'yahoo', start_date, end_date)
panel_dataa753 = data.DataReader('NRBBEARING.NS', 'yahoo', start_date, end_date)
panel_dataa754 = data.DataReader('AMRUTANJAN.NS', 'yahoo', start_date, end_date)
panel_dataa755 = data.DataReader('GICRE.NS', 'yahoo', start_date, end_date)
panel_dataa756 = data.DataReader('ACC.NS', 'yahoo', start_date, end_date)
panel_dataa757 = data.DataReader('GULFOILLUB.NS', 'yahoo', start_date, end_date)
panel_dataa758 = data.DataReader('AMARAJABAT.NS', 'yahoo', start_date, end_date)
panel_dataa759 = data.DataReader('BLUEDART.NS', 'yahoo', start_date, end_date)
panel_dataa760 = data.DataReader('NOCIL.NS', 'yahoo', start_date, end_date)
panel_dataa761 = data.DataReader('ITC.NS', 'yahoo', start_date, end_date)
panel_dataa762 = data.DataReader('JKIL.NS', 'yahoo', start_date, end_date)
panel_dataa763 = data.DataReader('GNFC.NS', 'yahoo', start_date, end_date)
panel_dataa764 = data.DataReader('PAGEIND.NS', 'yahoo', start_date, end_date)
panel_dataa765 = data.DataReader('HDFCAMC.NS', 'yahoo', start_date, end_date)
#panel_dataa766 = data.DataReader('INDIGRID.NS', 'yahoo', start_date, end_date)
panel_dataa767 = data.DataReader('SAFARI.NS', 'yahoo', start_date, end_date)
panel_dataa768 = data.DataReader('RIIL.NS', 'yahoo', start_date, end_date)
panel_dataa769 = data.DataReader('SRIPIPES.NS', 'yahoo', start_date, end_date)
panel_dataa770 = data.DataReader('SPARC.NS', 'yahoo', start_date, end_date)
panel_dataa771 = data.DataReader('FLFL.NS', 'yahoo', start_date, end_date)
panel_dataa772 = data.DataReader('MIRZAINT.NS', 'yahoo', start_date, end_date)
panel_dataa773 = data.DataReader('TITAN.NS', 'yahoo', start_date, end_date)
panel_dataa774 = data.DataReader('DHANUKA.NS', 'yahoo', start_date, end_date)
panel_dataa775 = data.DataReader('MAHLOG.NS', 'yahoo', start_date, end_date)
panel_dataa776 = data.DataReader('DIXON.NS', 'yahoo', start_date, end_date)
panel_dataa777 = data.DataReader('IGL.NS', 'yahoo', start_date, end_date)
panel_dataa778 = data.DataReader('NELCO.NS', 'yahoo', start_date, end_date)
panel_dataa779 = data.DataReader('NAVKARCORP.NS', 'yahoo', start_date, end_date)
panel_dataa780 = data.DataReader('BIRLACORPN.NS', 'yahoo', start_date, end_date)
panel_dataa781 = data.DataReader('PNBGILTS.NS', 'yahoo', start_date, end_date)
panel_dataa782 = data.DataReader('BEML.NS', 'yahoo', start_date, end_date)
panel_dataa783 = data.DataReader('UPL.NS', 'yahoo', start_date, end_date)
panel_dataa784 = data.DataReader('WOCKPHARMA.NS', 'yahoo', start_date, end_date)
panel_dataa785 = data.DataReader('ADANIPORTS.NS', 'yahoo', start_date, end_date)
panel_dataa786 = data.DataReader('THERMAX.NS', 'yahoo', start_date, end_date)
panel_dataa787 = data.DataReader('SWANENERGY.NS', 'yahoo', start_date, end_date)
panel_dataa788 = data.DataReader('PHOENIXLTD.NS', 'yahoo', start_date, end_date)
panel_dataa789 = data.DataReader('GOLDIAM.NS', 'yahoo', start_date, end_date)
panel_dataa790 = data.DataReader('BAJAJHLDNG.NS', 'yahoo', start_date, end_date)
panel_dataa791 = data.DataReader('BDL.NS', 'yahoo', start_date, end_date)
panel_dataa792 = data.DataReader('BIRLAMONEY.NS', 'yahoo', start_date, end_date)
panel_dataa793 = data.DataReader('GEOJITFSL.NS', 'yahoo', start_date, end_date)
panel_dataa794 = data.DataReader('AUBANK.NS', 'yahoo', start_date, end_date)
panel_dataa795 = data.DataReader('WIPRO.NS', 'yahoo', start_date, end_date)
panel_dataa796 = data.DataReader('IEX.NS', 'yahoo', start_date, end_date)
panel_dataa797 = data.DataReader('STAR.NS', 'yahoo', start_date, end_date)
panel_dataa798 = data.DataReader('CENTURYTEX.NS', 'yahoo', start_date, end_date)
panel_dataa799 = data.DataReader('BRITANNIA.NS', 'yahoo', start_date, end_date)
panel_dataa800 = data.DataReader('RAMCOIND.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa751['SYMBOL']='EQUITAS.NS'
panel_dataa752['SYMBOL']='SANGHVIFOR.NS'
panel_dataa753['SYMBOL']='NRBBEARING.NS'
panel_dataa754['SYMBOL']='AMRUTANJAN.NS'
panel_dataa755['SYMBOL']='GICRE.NS'
panel_dataa756['SYMBOL']='ACC.NS'
panel_dataa757['SYMBOL']='GULFOILLUB.NS'
panel_dataa758['SYMBOL']='AMARAJABAT.NS'
panel_dataa759['SYMBOL']='BLUEDART.NS'
panel_dataa760['SYMBOL']='NOCIL.NS'
panel_dataa761['SYMBOL']='ITC.NS'
panel_dataa762['SYMBOL']='JKIL.NS'
panel_dataa763['SYMBOL']='GNFC.NS'
panel_dataa764['SYMBOL']='PAGEIND.NS'
panel_dataa765['SYMBOL']='HDFCAMC.NS'
#panel_dataa766['SYMBOL']='INDIGRID.NS'
panel_dataa767['SYMBOL']='SAFARI.NS'
panel_dataa768['SYMBOL']='RIIL.NS'
panel_dataa769['SYMBOL']='SRIPIPES.NS'
panel_dataa770['SYMBOL']='SPARC.NS'
panel_dataa771['SYMBOL']='FLFL.NS'
panel_dataa772['SYMBOL']='MIRZAINT.NS'
panel_dataa773['SYMBOL']='TITAN.NS'
panel_dataa774['SYMBOL']='DHANUKA.NS'
panel_dataa775['SYMBOL']='MAHLOG.NS'
panel_dataa776['SYMBOL']='DIXON.NS'
panel_dataa777['SYMBOL']='IGL.NS'
panel_dataa778['SYMBOL']='NELCO.NS'
panel_dataa779['SYMBOL']='NAVKARCORP.NS'
panel_dataa780['SYMBOL']='BIRLACORPN.NS'
panel_dataa781['SYMBOL']='PNBGILTS.NS'
panel_dataa782['SYMBOL']='BEML.NS'
panel_dataa783['SYMBOL']='UPL.NS'
panel_dataa784['SYMBOL']='WOCKPHARMA.NS'
panel_dataa785['SYMBOL']='ADANIPORTS.NS'
panel_dataa786['SYMBOL']='THERMAX.NS'
panel_dataa787['SYMBOL']='SWANENERGY.NS'
panel_dataa788['SYMBOL']='PHOENIXLTD.NS'
panel_dataa789['SYMBOL']='GOLDIAM.NS'
panel_dataa790['SYMBOL']='BAJAJHLDNG.NS'
panel_dataa791['SYMBOL']='BDL.NS'
panel_dataa792['SYMBOL']='BIRLAMONEY.NS'
panel_dataa793['SYMBOL']='GEOJITFSL.NS'
panel_dataa794['SYMBOL']='AUBANK.NS'
panel_dataa795['SYMBOL']='WIPRO.NS'
panel_dataa796['SYMBOL']='IEX.NS'
panel_dataa797['SYMBOL']='STAR.NS'
panel_dataa798['SYMBOL']='CENTURYTEX.NS'
panel_dataa799['SYMBOL']='BRITANNIA.NS'
panel_dataa800['SYMBOL']='RAMCOIND.NS'

# %%
finall = pd.concat([panel_dataa751,
panel_dataa752,
panel_dataa753,
panel_dataa754,
panel_dataa755,
panel_dataa756,
panel_dataa757,
panel_dataa758,
panel_dataa759,
panel_dataa760,
panel_dataa761,
panel_dataa762,
panel_dataa763,
panel_dataa764,
panel_dataa765,
#panel_dataa766,
panel_dataa767,
panel_dataa768,
panel_dataa769,
panel_dataa770,
panel_dataa771,
panel_dataa772,
panel_dataa773,
panel_dataa774,
panel_dataa775,
panel_dataa776,
panel_dataa777,
panel_dataa778,
panel_dataa779,
panel_dataa780,
panel_dataa781,
panel_dataa782,
panel_dataa783,
panel_dataa784,
panel_dataa785,
panel_dataa786,
panel_dataa787,
panel_dataa788,
panel_dataa789,
panel_dataa790,
panel_dataa791,
panel_dataa792,
panel_dataa793,
panel_dataa794,
panel_dataa795,
panel_dataa796,
panel_dataa797,
panel_dataa798,
panel_dataa799,
panel_dataa800])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_751_TO_800_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_751_TO_800_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_751_TO_800_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...      Volume   Adj Close       SYMBOL
# 0                0  2016-04-22  140.550003  ...  16016315.0  135.373932   EQUITAS.NS
# 1                1  2016-04-25  139.449997  ...   6635973.0  133.461044   EQUITAS.NS
# 2                2  2016-04-26  141.350006  ...   8740837.0  136.060608   EQUITAS.NS
# 3                3  2016-04-27  143.300003  ...  12469123.0  139.150665   EQUITAS.NS
# 4                4  2016-04-28  142.800003  ...   5001100.0  136.158707   EQUITAS.NS
# ...            ...         ...         ...  ...         ...         ...          ...
# 165093      165093  2020-08-10  193.250000  ...    179545.0  188.949997  RAMCOIND.NS
# 165094      165094  2020-08-11  191.949997  ...    107345.0  189.149994  RAMCOIND.NS
# 165095      165095  2020-08-12  189.949997  ...     30312.0  184.699997  RAMCOIND.NS
# 165096      165096  2020-08-13  189.899994  ...     58680.0  183.100006  RAMCOIND.NS
# ...
