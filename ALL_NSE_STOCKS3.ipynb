# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

panel_dataa101 = data.DataReader('OLECTRA.NS', 'yahoo', start_date, end_date)
panel_dataa102 = data.DataReader('TREEHOUSE.NS', 'yahoo', start_date, end_date)
panel_dataa103 = data.DataReader('MANUGRAPH.NS', 'yahoo', start_date, end_date)
panel_dataa104 = data.DataReader('CINEVISTA.NS', 'yahoo', start_date, end_date)
panel_dataa105 = data.DataReader('VISHNU.NS', 'yahoo', start_date, end_date)
panel_dataa106 = data.DataReader('SPMLINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa107 = data.DataReader('USHAMART.NS', 'yahoo', start_date, end_date)
panel_dataa108 = data.DataReader('BALPHARMA.NS', 'yahoo', start_date, end_date)
panel_dataa109 = data.DataReader('HDIL.NS', 'yahoo', start_date, end_date)
panel_dataa110 = data.DataReader('MANAKCOAT.NS', 'yahoo', start_date, end_date)
panel_dataa111 = data.DataReader('RPPINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa112 = data.DataReader('INDTERRAIN.NS', 'yahoo', start_date, end_date)
panel_dataa113 = data.DataReader('ROLTA.NS', 'yahoo', start_date, end_date)
panel_dataa114 = data.DataReader('NDL.NS', 'yahoo', start_date, end_date)
panel_dataa115 = data.DataReader('CALSOFT.NS', 'yahoo', start_date, end_date)
panel_dataa116 = data.DataReader('ANSALAPI.NS', 'yahoo', start_date, end_date)
panel_dataa117 = data.DataReader('GOLDENTOBC.NS', 'yahoo', start_date, end_date)
panel_dataa118 = data.DataReader('BLS.NS', 'yahoo', start_date, end_date)
panel_dataa119 = data.DataReader('THOMASCOTT.NS', 'yahoo', start_date, end_date)
panel_dataa120 = data.DataReader('DIGISPICE.NS', 'yahoo', start_date, end_date)
panel_dataa121 = data.DataReader('GPTINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa122 = data.DataReader('UMANGDAIRY.NS', 'yahoo', start_date, end_date)
panel_dataa123 = data.DataReader('RNAVAL.NS', 'yahoo', start_date, end_date)
panel_dataa124 = data.DataReader('PARSVNATH.NS', 'yahoo', start_date, end_date)
panel_dataa125 = data.DataReader('EDUCOMP.NS', 'yahoo', start_date, end_date)
panel_dataa126 = data.DataReader('BKMINDST.NS', 'yahoo', start_date, end_date)
panel_dataa127 = data.DataReader('HMVL.NS', 'yahoo', start_date, end_date)
panel_dataa128 = data.DataReader('PURVA.NS', 'yahoo', start_date, end_date)
panel_dataa129 = data.DataReader('GOKEX.NS', 'yahoo', start_date, end_date)
panel_dataa130 = data.DataReader('GLOBOFFS.NS', 'yahoo', start_date, end_date)
panel_dataa131 = data.DataReader('AKSHOPTFBR.NS', 'yahoo', start_date, end_date)
panel_dataa132 = data.DataReader('KOLTEPATIL.NS', 'yahoo', start_date, end_date)
panel_dataa133 = data.DataReader('NBCC.NS', 'yahoo', start_date, end_date)
panel_dataa134 = data.DataReader('MEP.NS', 'yahoo', start_date, end_date)
panel_dataa135 = data.DataReader('JINDWORLD.NS', 'yahoo', start_date, end_date)
panel_dataa136 = data.DataReader('REVATHI.NS', 'yahoo', start_date, end_date)
panel_dataa137 = data.DataReader('XELPMOC.NS', 'yahoo', start_date, end_date)
panel_dataa138 = data.DataReader('NEXTMEDIA.NS', 'yahoo', start_date, end_date)
panel_dataa139 = data.DataReader('NCC.NS', 'yahoo', start_date, end_date)
panel_dataa140 = data.DataReader('EKC.NS', 'yahoo', start_date, end_date)
panel_dataa141 = data.DataReader('MAHESHWARI.NS', 'yahoo', start_date, end_date)
panel_dataa142 = data.DataReader('VAKRANGEE.NS', 'yahoo', start_date, end_date)
panel_dataa143 = data.DataReader('NCLIND.NS', 'yahoo', start_date, end_date)
panel_dataa144 = data.DataReader('IIFLWAM.NS', 'yahoo', start_date, end_date)
panel_dataa145 = data.DataReader('RCOM.NS', 'yahoo', start_date, end_date)
panel_dataa146 = data.DataReader('DICIND.NS', 'yahoo', start_date, end_date)
panel_dataa147 = data.DataReader('ONMOBILE.NS', 'yahoo', start_date, end_date)
panel_dataa148 = data.DataReader('CYBERTECH.NS', 'yahoo', start_date, end_date)
panel_dataa149 = data.DataReader('BGRENERGY.NS', 'yahoo', start_date, end_date)
panel_dataa150 = data.DataReader('ALPSINDUS.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa101['SYMBOL']='OLECTRA.NS'
panel_dataa102['SYMBOL']='TREEHOUSE.NS'
panel_dataa103['SYMBOL']='MANUGRAPH.NS'
panel_dataa104['SYMBOL']='CINEVISTA.NS'
panel_dataa105['SYMBOL']='VISHNU.NS'
panel_dataa106['SYMBOL']='SPMLINFRA.NS'
panel_dataa107['SYMBOL']='USHAMART.NS'
panel_dataa108['SYMBOL']='BALPHARMA.NS'
panel_dataa109['SYMBOL']='HDIL.NS'
panel_dataa110['SYMBOL']='MANAKCOAT.NS'
panel_dataa111['SYMBOL']='RPPINFRA.NS'
panel_dataa112['SYMBOL']='INDTERRAIN.NS'
panel_dataa113['SYMBOL']='ROLTA.NS'
panel_dataa114['SYMBOL']='NDL.NS'
panel_dataa115['SYMBOL']='CALSOFT.NS'
panel_dataa116['SYMBOL']='ANSALAPI.NS'
panel_dataa117['SYMBOL']='GOLDENTOBC.NS'
panel_dataa118['SYMBOL']='BLS.NS'
panel_dataa119['SYMBOL']='THOMASCOTT.NS'
panel_dataa120['SYMBOL']='DIGISPICE.NS'
panel_dataa121['SYMBOL']='GPTINFRA.NS'
panel_dataa122['SYMBOL']='UMANGDAIRY.NS'
panel_dataa123['SYMBOL']='RNAVAL.NS'
panel_dataa124['SYMBOL']='PARSVNATH.NS'
panel_dataa125['SYMBOL']='EDUCOMP.NS'
panel_dataa126['SYMBOL']='BKMINDST.NS'
panel_dataa127['SYMBOL']='HMVL.NS'
panel_dataa128['SYMBOL']='PURVA.NS'
panel_dataa129['SYMBOL']='GOKEX.NS'
panel_dataa130['SYMBOL']='GLOBOFFS.NS'
panel_dataa131['SYMBOL']='AKSHOPTFBR.NS'
panel_dataa132['SYMBOL']='KOLTEPATIL.NS'
panel_dataa133['SYMBOL']='NBCC.NS'
panel_dataa134['SYMBOL']='MEP.NS'
panel_dataa135['SYMBOL']='JINDWORLD.NS'
panel_dataa136['SYMBOL']='REVATHI.NS'
panel_dataa137['SYMBOL']='XELPMOC.NS'
panel_dataa138['SYMBOL']='NEXTMEDIA.NS'
panel_dataa139['SYMBOL']='NCC.NS'
panel_dataa140['SYMBOL']='EKC.NS'
panel_dataa141['SYMBOL']='MAHESHWARI.NS'
panel_dataa142['SYMBOL']='VAKRANGEE.NS'
panel_dataa143['SYMBOL']='NCLIND.NS'
panel_dataa144['SYMBOL']='IIFLWAM.NS'
panel_dataa145['SYMBOL']='RCOM.NS'
panel_dataa146['SYMBOL']='DICIND.NS'
panel_dataa147['SYMBOL']='ONMOBILE.NS'
panel_dataa148['SYMBOL']='CYBERTECH.NS'
panel_dataa149['SYMBOL']='BGRENERGY.NS'
panel_dataa150['SYMBOL']='ALPSINDUS.NS'

# %%
finall = pd.concat([panel_dataa101,
panel_dataa102,
panel_dataa103,
panel_dataa104,
panel_dataa105,
panel_dataa106,
panel_dataa107,
panel_dataa108,
panel_dataa109,
panel_dataa110,
panel_dataa111,
panel_dataa112,
panel_dataa113,
panel_dataa114,
panel_dataa115,
panel_dataa116,
panel_dataa117,
panel_dataa118,
panel_dataa119,
panel_dataa120,
panel_dataa121,
panel_dataa122,
panel_dataa123,
panel_dataa124,
panel_dataa125,
panel_dataa126,
panel_dataa127,
panel_dataa128,
panel_dataa129,
panel_dataa130,
panel_dataa131,
panel_dataa132,
panel_dataa133,
panel_dataa134,
panel_dataa135,
panel_dataa136,
panel_dataa137,
panel_dataa138,
panel_dataa139,
panel_dataa140,
panel_dataa141,
panel_dataa142,
panel_dataa143,
panel_dataa144,
panel_dataa145,
panel_dataa146,
panel_dataa147,
panel_dataa148,
panel_dataa149,
panel_dataa150])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_101_TO_150_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_101_TO_150_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_101_TO_150_start_to_15082020.csv")

readdf

# %%
readdf
# Out:
#         Unnamed: 0        Date   High  ...    Volume  Adj Close        SYMBOL
# 0                0  2002-07-04  20.85  ...   12626.0  19.650681    OLECTRA.NS
# 1                1  2002-07-10  27.35  ...  356025.0  23.250061    OLECTRA.NS
# 2                2  2002-07-11  24.90  ...  170127.0  23.055502    OLECTRA.NS
# 3                3  2002-07-12  25.00  ...  131447.0  22.520458    OLECTRA.NS
# 4                4  2002-07-15  26.85  ...   75047.0  21.742214    OLECTRA.NS
# ...            ...         ...    ...  ...       ...        ...           ...
# 147170      147170  2020-08-10   1.15  ...   23291.0   1.100000  ALPSINDUS.NS
# 147171      147171  2020-08-11   1.15  ...   27634.0   1.050000  ALPSINDUS.NS
# 147172      147172  2020-08-12   1.10  ...   24831.0   1.100000  ALPSINDUS.NS
# 147173      147173  2020-08-13   1.15  ...   17386.0   1.150000  ALPSINDUS.NS
# 147174      147174  2020-08-14   1.20  ...   40822.0   1.200000  ALPSINDUS.NS
#
# [147175 rows x 9 columns]
