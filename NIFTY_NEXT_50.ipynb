# %%
# install required libraries
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

# %%
#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

#fetching data
#panel_data1 = data.DataReader('^NSMIDCP', 'yahoo', start_date, end_date)
panel_data2 = data.DataReader('MOTHERSUMI.NS', 'yahoo', start_date, end_date)
panel_data3 = data.DataReader('DLF.NS', 'yahoo', start_date, end_date)
panel_data4 = data.DataReader('SBICARD.NS', 'yahoo', start_date, end_date)
panel_data5 = data.DataReader('PAGEIND.NS', 'yahoo', start_date, end_date)
panel_data6 = data.DataReader('PFC.NS', 'yahoo', start_date, end_date)
panel_data7 = data.DataReader('NMDC.NS', 'yahoo', start_date, end_date)
panel_data8 = data.DataReader('BOSCHLTD.NS', 'yahoo', start_date, end_date)
panel_data9 = data.DataReader('CONCOR.NS', 'yahoo', start_date, end_date)
panel_data10 = data.DataReader('SIEMENS.NS', 'yahoo', start_date, end_date)
panel_data11 = data.DataReader('IGL.NS', 'yahoo', start_date, end_date)
panel_data12 = data.DataReader('DIVISLAB.NS', 'yahoo', start_date, end_date)
panel_data13 = data.DataReader('NAUKRI.NS', 'yahoo', start_date, end_date)
panel_data14 = data.DataReader('HDFCAMC.NS', 'yahoo', start_date, end_date)
panel_data15 = data.DataReader('ABBOTINDIA.NS', 'yahoo', start_date, end_date)
panel_data16 = data.DataReader('HINDPETRO.NS', 'yahoo', start_date, end_date)
panel_data17 = data.DataReader('HAVELLS.NS', 'yahoo', start_date, end_date)
panel_data18 = data.DataReader('UBL.NS', 'yahoo', start_date, end_date)
panel_data19 = data.DataReader('MUTHOOTFIN.NS', 'yahoo', start_date, end_date)
panel_data20 = data.DataReader('OFSS.NS', 'yahoo', start_date, end_date)
panel_data21 = data.DataReader('PEL.NS', 'yahoo', start_date, end_date)
panel_data22 = data.DataReader('MARICO.NS', 'yahoo', start_date, end_date)
panel_data23 = data.DataReader('PNB.NS', 'yahoo', start_date, end_date)
panel_data24 = data.DataReader('SBILIFE.NS', 'yahoo', start_date, end_date)
panel_data25 = data.DataReader('COLPAL.NS', 'yahoo', start_date, end_date)
panel_data26 = data.DataReader('BAJAJHLDNG.NS', 'yahoo', start_date, end_date)
panel_data27 = data.DataReader('PIDILITIND.NS', 'yahoo', start_date, end_date)
panel_data28 = data.DataReader('DMART.NS', 'yahoo', start_date, end_date)
panel_data29 = data.DataReader('CADILAHC.NS', 'yahoo', start_date, end_date)
panel_data30 = data.DataReader('BANKBARODA.NS', 'yahoo', start_date, end_date)
panel_data31 = data.DataReader('INDIGO.NS', 'yahoo', start_date, end_date)
panel_data32 = data.DataReader('MCDOWELL-N.NS', 'yahoo', start_date, end_date)
panel_data33 = data.DataReader('PGHH.NS', 'yahoo', start_date, end_date)
panel_data34 = data.DataReader('NHPC.NS', 'yahoo', start_date, end_date)
panel_data35 = data.DataReader('ACC.NS', 'yahoo', start_date, end_date)
panel_data36 = data.DataReader('BANDHANBNK.NS', 'yahoo', start_date, end_date)
panel_data37 = data.DataReader('DABUR.NS', 'yahoo', start_date, end_date)
panel_data38 = data.DataReader('GODREJCP.NS', 'yahoo', start_date, end_date)
panel_data39 = data.DataReader('AMBUJACEM.NS', 'yahoo', start_date, end_date)
panel_data40 = data.DataReader('GICRE.NS', 'yahoo', start_date, end_date)
panel_data41 = data.DataReader('ICICIGI.NS', 'yahoo', start_date, end_date)
panel_data42 = data.DataReader('HINDZINC.NS', 'yahoo', start_date, end_date)
panel_data43 = data.DataReader('BIOCON.NS', 'yahoo', start_date, end_date)
panel_data44 = data.DataReader('SRTRANSFIN.NS', 'yahoo', start_date, end_date)
panel_data45 = data.DataReader('ICICIPRULI.NS', 'yahoo', start_date, end_date)
panel_data46 = data.DataReader('TORNTPHARM.NS', 'yahoo', start_date, end_date)
panel_data47 = data.DataReader('LUPIN.NS', 'yahoo', start_date, end_date)
panel_data48 = data.DataReader('BERGEPAINT.NS', 'yahoo', start_date, end_date)
panel_data49 = data.DataReader('AUROPHARMA.NS', 'yahoo', start_date, end_date)
panel_data50 = data.DataReader('ADANITRANS.NS', 'yahoo', start_date, end_date)
panel_data51 = data.DataReader('PETRONET.NS', 'yahoo', start_date, end_date)

#define symbol to know which staock
#panel_data1['SYMBOL']='^NSMIDCP.NS'
panel_data2['SYMBOL']='MOTHERSUMI.NS'
panel_data3['SYMBOL']='DLF.NS'
panel_data4['SYMBOL']='SBICARD.NS'
panel_data5['SYMBOL']='PAGEIND.NS'
panel_data6['SYMBOL']='PFC.NS'
panel_data7['SYMBOL']='NMDC.NS'
panel_data8['SYMBOL']='BOSCHLTD.NS'
panel_data9['SYMBOL']='CONCOR.NS'
panel_data10['SYMBOL']='SIEMENS.NS'
panel_data11['SYMBOL']='IGL.NS'
panel_data12['SYMBOL']='DIVISLAB.NS'
panel_data13['SYMBOL']='NAUKRI.NS'
panel_data14['SYMBOL']='HDFCAMC.NS'
panel_data15['SYMBOL']='ABBOTINDIA.NS'
panel_data16['SYMBOL']='HINDPETRO.NS'
panel_data17['SYMBOL']='HAVELLS.NS'
panel_data18['SYMBOL']='UBL.NS'
panel_data19['SYMBOL']='MUTHOOTFIN.NS'
panel_data20['SYMBOL']='OFSS.NS'
panel_data21['SYMBOL']='PEL.NS'
panel_data22['SYMBOL']='MARICO.NS'
panel_data23['SYMBOL']='PNB.NS'
panel_data24['SYMBOL']='SBILIFE.NS'
panel_data25['SYMBOL']='COLPAL.NS'
panel_data26['SYMBOL']='BAJAJHLDNG.NS'
panel_data27['SYMBOL']='PIDILITIND.NS'
panel_data28['SYMBOL']='DMART.NS'
panel_data29['SYMBOL']='CADILAHC.NS'
panel_data30['SYMBOL']='BANKBARODA.NS'
panel_data31['SYMBOL']='INDIGO.NS'
panel_data32['SYMBOL']='MCDOWELL-N.NS'
panel_data33['SYMBOL']='PGHH.NS'
panel_data34['SYMBOL']='NHPC.NS'
panel_data35['SYMBOL']='ACC.NS'
panel_data36['SYMBOL']='BANDHANBNK.NS'
panel_data37['SYMBOL']='DABUR.NS'
panel_data38['SYMBOL']='GODREJCP.NS'
panel_data39['SYMBOL']='AMBUJACEM.NS'
panel_data40['SYMBOL']='GICRE.NS'
panel_data41['SYMBOL']='ICICIGI.NS'
panel_data42['SYMBOL']='HINDZINC.NS'
panel_data43['SYMBOL']='BIOCON.NS'
panel_data44['SYMBOL']='SRTRANSFIN.NS'
panel_data45['SYMBOL']='ICICIPRULI.NS'
panel_data46['SYMBOL']='TORNTPHARM.NS'
panel_data47['SYMBOL']='LUPIN.NS'
panel_data48['SYMBOL']='BERGEPAINT.NS'
panel_data49['SYMBOL']='AUROPHARMA.NS'
panel_data50['SYMBOL']='ADANITRANS.NS'
panel_data51['SYMBOL']='PETRONET.NS'

# %%
# concate all dataframes to single dataframe
finall = pd.concat([panel_data2,panel_data3,panel_data4,panel_data5,panel_data6,
                    panel_data7,panel_data8,panel_data9,panel_data10,
                    panel_data11,panel_data12,panel_data13,panel_data14,
                    panel_data15,panel_data16,panel_data17,panel_data18,
                    panel_data19,panel_data20,panel_data21,panel_data22,
                    panel_data23,panel_data24,panel_data25,panel_data26,
                    panel_data27,panel_data28,panel_data29,panel_data30,
                    panel_data31,panel_data32,panel_data33,panel_data34,
                    panel_data35,panel_data36,panel_data37,panel_data38,
                    panel_data39,panel_data40,panel_data41,panel_data42,
                    panel_data43,panel_data44,panel_data45,panel_data46,
                    panel_data47,panel_data48,panel_data49,panel_data50,
                    panel_data51])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#create file in local colab 
finall.reset_index().to_csv('nifty_next_50_start_to_15082020.csv')

# %%
#copy colab to google drive
# !cp nifty_next_50_start_to_15082020.csv "drive/My Drive/"

# %%
#read file from google drive
readdf = pd.read_csv("drive/My Drive/nifty_next_50_start_to_15082020.csv")

# %%
readdf.head()
# Out:
#    Unnamed: 0        Date     High  ...    Volume  Adj Close         SYMBOL
# 0           0  2002-07-01  0.29264  ...   52539.0   2.004262  MOTHERSUMI.NS
# 1           1  2002-07-02  0.29264  ...  244568.0   2.004262  MOTHERSUMI.NS
# 2           2  2002-07-03  0.29264  ...  184631.0   2.004262  MOTHERSUMI.NS
# 3           3  2002-07-04  0.29264  ...  122096.0   2.004262  MOTHERSUMI.NS
# 4           4  2002-07-05  0.29264  ...  125992.0   2.004262  MOTHERSUMI.NS
#
# [5 rows x 9 columns]

# %%
readdf.describe()
# Out:
#           Unnamed: 0           High  ...        Volume      Adj Close
# count  174852.000000  174852.000000  ...  1.748520e+05  174852.000000
# mean    87425.500000     976.833413  ...  2.971122e+06     898.918991
# std     50475.568972    2793.386199  ...  2.631016e+07    2678.537401
# min         0.000000       0.234110  ...  0.000000e+00      -0.367059
# 25%     43712.750000      67.831223  ...  1.049738e+05      37.664346
# 50%     87425.500000     213.399994  ...  5.390820e+05     177.573563
# 75%    131138.250000     731.977478  ...  2.047290e+06     662.949951
# max    174851.000000   36370.000000  ...  3.072938e+09   35388.832031
#
# [8 rows x 7 columns]
