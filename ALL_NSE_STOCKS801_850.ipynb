# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa801 = data.DataReader('WELSPUNIND.NS', 'yahoo', start_date, end_date)
panel_dataa802 = data.DataReader('MAHINDCIE.NS', 'yahoo', start_date, end_date)
panel_dataa803 = data.DataReader('EMAMILTD.NS', 'yahoo', start_date, end_date)
panel_dataa804 = data.DataReader('AXISBANK.NS', 'yahoo', start_date, end_date)
panel_dataa805 = data.DataReader('ULTRACEMCO.NS', 'yahoo', start_date, end_date)
panel_dataa806 = data.DataReader('SRHHYPOLTD.NS', 'yahoo', start_date, end_date)
panel_dataa807 = data.DataReader('HDFC.NS', 'yahoo', start_date, end_date)
panel_dataa808 = data.DataReader('DELTACORP.NS', 'yahoo', start_date, end_date)
panel_dataa809 = data.DataReader('IRCON.NS', 'yahoo', start_date, end_date)
panel_dataa810 = data.DataReader('CASTROLIND.NS', 'yahoo', start_date, end_date)
panel_dataa811 = data.DataReader('DEEPAKNTR.NS', 'yahoo', start_date, end_date)
panel_dataa812 = data.DataReader('POLYCAB.NS', 'yahoo', start_date, end_date)
panel_dataa813 = data.DataReader('IFBIND.NS', 'yahoo', start_date, end_date)
panel_dataa814 = data.DataReader('APCOTEXIND.NS', 'yahoo', start_date, end_date)
panel_dataa815 = data.DataReader('GICHSGFIN.NS', 'yahoo', start_date, end_date)
panel_dataa816 = data.DataReader('JKTYRE.NS', 'yahoo', start_date, end_date)
panel_dataa817 = data.DataReader('ASTEC.NS', 'yahoo', start_date, end_date)
panel_dataa818 = data.DataReader('THYROCARE.NS', 'yahoo', start_date, end_date)
panel_dataa819 = data.DataReader('GMRINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa820 = data.DataReader('PETRONET.NS', 'yahoo', start_date, end_date)
panel_dataa821 = data.DataReader('ASAHIINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa822 = data.DataReader('GEECEE.NS', 'yahoo', start_date, end_date)
panel_dataa823 = data.DataReader('GUJGASLTD.NS', 'yahoo', start_date, end_date)
panel_dataa824 = data.DataReader('DHFL.NS', 'yahoo', start_date, end_date)
panel_dataa825 = data.DataReader('UGARSUGAR.NS', 'yahoo', start_date, end_date)
panel_dataa826 = data.DataReader('EIDPARRY.NS', 'yahoo', start_date, end_date)
panel_dataa827 = data.DataReader('BOSCHLTD.NS', 'yahoo', start_date, end_date)
panel_dataa828 = data.DataReader('IRCTC.NS', 'yahoo', start_date, end_date)
panel_dataa829 = data.DataReader('ABCAPITAL.NS', 'yahoo', start_date, end_date)
panel_dataa830 = data.DataReader('AJANTPHARM.NS', 'yahoo', start_date, end_date)
panel_dataa831 = data.DataReader('POKARNA.NS', 'yahoo', start_date, end_date)
panel_dataa832 = data.DataReader('SBILIFE.NS', 'yahoo', start_date, end_date)
panel_dataa833 = data.DataReader('TATACONSUM.NS', 'yahoo', start_date, end_date)
panel_dataa834 = data.DataReader('PNBHOUSING.NS', 'yahoo', start_date, end_date)
panel_dataa835 = data.DataReader('WELENT.NS', 'yahoo', start_date, end_date)
panel_dataa836 = data.DataReader('KCPSUGIND.NS', 'yahoo', start_date, end_date)
panel_dataa837 = data.DataReader('MEGASOFT.NS', 'yahoo', start_date, end_date)
panel_dataa838 = data.DataReader('APOLLO.NS', 'yahoo', start_date, end_date)
panel_dataa839 = data.DataReader('PRAKASH.NS', 'yahoo', start_date, end_date)
panel_dataa840 = data.DataReader('SHREECEM.NS', 'yahoo', start_date, end_date)
panel_dataa841 = data.DataReader('MCDOWELL-N.NS', 'yahoo', start_date, end_date)
panel_dataa842 = data.DataReader('PGHH.NS', 'yahoo', start_date, end_date)
panel_dataa843 = data.DataReader('CHOLAHLDNG.NS', 'yahoo', start_date, end_date)
panel_dataa844 = data.DataReader('GUJALKALI.NS', 'yahoo', start_date, end_date)
panel_dataa845 = data.DataReader('PODDARMENT.NS', 'yahoo', start_date, end_date)
panel_dataa846 = data.DataReader('SIYSIL.NS', 'yahoo', start_date, end_date)
panel_dataa847 = data.DataReader('HINDPETRO.NS', 'yahoo', start_date, end_date)
panel_dataa848 = data.DataReader('SAIL.NS', 'yahoo', start_date, end_date)
panel_dataa849 = data.DataReader('BSE.NS', 'yahoo', start_date, end_date)
panel_dataa850 = data.DataReader('POWERINDIA.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa801['SYMBOL']='WELSPUNIND.NS'
panel_dataa802['SYMBOL']='MAHINDCIE.NS'
panel_dataa803['SYMBOL']='EMAMILTD.NS'
panel_dataa804['SYMBOL']='AXISBANK.NS'
panel_dataa805['SYMBOL']='ULTRACEMCO.NS'
panel_dataa806['SYMBOL']='SRHHYPOLTD.NS'
panel_dataa807['SYMBOL']='HDFC.NS'
panel_dataa808['SYMBOL']='DELTACORP.NS'
panel_dataa809['SYMBOL']='IRCON.NS'
panel_dataa810['SYMBOL']='CASTROLIND.NS'
panel_dataa811['SYMBOL']='DEEPAKNTR.NS'
panel_dataa812['SYMBOL']='POLYCAB.NS'
panel_dataa813['SYMBOL']='IFBIND.NS'
panel_dataa814['SYMBOL']='APCOTEXIND.NS'
panel_dataa815['SYMBOL']='GICHSGFIN.NS'
panel_dataa816['SYMBOL']='JKTYRE.NS'
panel_dataa817['SYMBOL']='ASTEC.NS'
panel_dataa818['SYMBOL']='THYROCARE.NS'
panel_dataa819['SYMBOL']='GMRINFRA.NS'
panel_dataa820['SYMBOL']='PETRONET.NS'
panel_dataa821['SYMBOL']='ASAHIINDIA.NS'
panel_dataa822['SYMBOL']='GEECEE.NS'
panel_dataa823['SYMBOL']='GUJGASLTD.NS'
panel_dataa824['SYMBOL']='DHFL.NS'
panel_dataa825['SYMBOL']='UGARSUGAR.NS'
panel_dataa826['SYMBOL']='EIDPARRY.NS'
panel_dataa827['SYMBOL']='BOSCHLTD.NS'
panel_dataa828['SYMBOL']='IRCTC.NS'
panel_dataa829['SYMBOL']='ABCAPITAL.NS'
panel_dataa830['SYMBOL']='AJANTPHARM.NS'
panel_dataa831['SYMBOL']='POKARNA.NS'
panel_dataa832['SYMBOL']='SBILIFE.NS'
panel_dataa833['SYMBOL']='TATACONSUM.NS'
panel_dataa834['SYMBOL']='PNBHOUSING.NS'
panel_dataa835['SYMBOL']='WELENT.NS'
panel_dataa836['SYMBOL']='KCPSUGIND.NS'
panel_dataa837['SYMBOL']='MEGASOFT.NS'
panel_dataa838['SYMBOL']='APOLLO.NS'
panel_dataa839['SYMBOL']='PRAKASH.NS'
panel_dataa840['SYMBOL']='SHREECEM.NS'
panel_dataa841['SYMBOL']='MCDOWELL-N.NS'
panel_dataa842['SYMBOL']='PGHH.NS'
panel_dataa843['SYMBOL']='CHOLAHLDNG.NS'
panel_dataa844['SYMBOL']='GUJALKALI.NS'
panel_dataa845['SYMBOL']='PODDARMENT.NS'
panel_dataa846['SYMBOL']='SIYSIL.NS'
panel_dataa847['SYMBOL']='HINDPETRO.NS'
panel_dataa848['SYMBOL']='SAIL.NS'
panel_dataa849['SYMBOL']='BSE.NS'
panel_dataa850['SYMBOL']='POWERINDIA.NS'

# %%
finall = pd.concat([panel_dataa801,
panel_dataa802,
panel_dataa803,
panel_dataa804,
panel_dataa805,
panel_dataa806,
panel_dataa807,
panel_dataa808,
panel_dataa809,
panel_dataa810,
panel_dataa811,
panel_dataa812,
panel_dataa813,
panel_dataa814,
panel_dataa815,
panel_dataa816,
panel_dataa817,
panel_dataa818,
panel_dataa819,
panel_dataa820,
panel_dataa821,
panel_dataa822,
panel_dataa823,
panel_dataa824,
panel_dataa825,
panel_dataa826,
panel_dataa827,
panel_dataa828,
panel_dataa829,
panel_dataa830,
panel_dataa831,
panel_dataa832,
panel_dataa833,
panel_dataa834,
panel_dataa835,
panel_dataa836,
panel_dataa837,
panel_dataa838,
panel_dataa839,
panel_dataa840,
panel_dataa841,
panel_dataa842,
panel_dataa843,
panel_dataa844,
panel_dataa845,
panel_dataa846,
panel_dataa847,
panel_dataa848,
panel_dataa849,
panel_dataa850])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_801_TO_850_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_801_TO_850_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_801_TO_850_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  ...   Adj Close         SYMBOL
# 0                0  2003-12-04  ...    2.411336  WELSPUNIND.NS
# 1                1  2003-12-05  ...    2.653396  WELSPUNIND.NS
# 2                2  2003-12-08  ...    2.919779  WELSPUNIND.NS
# 3                3  2003-12-09  ...    2.990428  WELSPUNIND.NS
# 4                4  2003-12-10  ...    2.845655  WELSPUNIND.NS
# ...            ...         ...  ...         ...            ...
# 153321      153321  2020-08-10  ...  926.099976  POWERINDIA.NS
# 153322      153322  2020-08-11  ...  944.650024  POWERINDIA.NS
# 153323      153323  2020-08-12  ...  907.450012  POWERINDIA.NS
# 153324      153324  2020-08-13  ...  904.450012  POWERINDIA.NS
# 153325      153325  2020-08-14  ...  909.200012  POWERINDIA.NS
#
# [153326 rows x 9 columns]
