# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa551 = data.DataReader('DABUR.NS', 'yahoo', start_date, end_date)
panel_dataa552 = data.DataReader('MAHSEAMLES.NS', 'yahoo', start_date, end_date)
panel_dataa553 = data.DataReader('JBCHEPHARM.NS', 'yahoo', start_date, end_date)
panel_dataa554 = data.DataReader('SOLARINDS.NS', 'yahoo', start_date, end_date)
panel_dataa555 = data.DataReader('BANCOINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa556 = data.DataReader('MUTHOOTFIN.NS', 'yahoo', start_date, end_date)
panel_dataa557 = data.DataReader('SHOPERSTOP.NS', 'yahoo', start_date, end_date)
panel_dataa558 = data.DataReader('TECHM.NS', 'yahoo', start_date, end_date)
panel_dataa559 = data.DataReader('ICICIBANK.NS', 'yahoo', start_date, end_date)
panel_dataa560 = data.DataReader('HUDCO.NS', 'yahoo', start_date, end_date)
panel_dataa561 = data.DataReader('SCI.NS', 'yahoo', start_date, end_date)
panel_dataa562 = data.DataReader('APOLLOTYRE.NS', 'yahoo', start_date, end_date)
panel_dataa563 = data.DataReader('INDIACEM.NS', 'yahoo', start_date, end_date)
panel_dataa564 = data.DataReader('KSCL.NS', 'yahoo', start_date, end_date)
panel_dataa565 = data.DataReader('VIPIND.NS', 'yahoo', start_date, end_date)
panel_dataa566 = data.DataReader('GPPL.NS', 'yahoo', start_date, end_date)
panel_dataa567 = data.DataReader('LGBBROSLTD.NS', 'yahoo', start_date, end_date)
panel_dataa568 = data.DataReader('AARTIIND.NS', 'yahoo', start_date, end_date)
panel_dataa569 = data.DataReader('COALINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa570 = data.DataReader('SCHAND.NS', 'yahoo', start_date, end_date)
panel_dataa571 = data.DataReader('SGL.NS', 'yahoo', start_date, end_date)
panel_dataa572 = data.DataReader('MRF.NS', 'yahoo', start_date, end_date)
panel_dataa573 = data.DataReader('SUBROS.NS', 'yahoo', start_date, end_date)
panel_dataa574 = data.DataReader('BALAMINES.NS', 'yahoo', start_date, end_date)
panel_dataa575 = data.DataReader('TATAMETALI.NS', 'yahoo', start_date, end_date)
panel_dataa576 = data.DataReader('NEWGEN.NS', 'yahoo', start_date, end_date)
panel_dataa577 = data.DataReader('HEG.NS', 'yahoo', start_date, end_date)
panel_dataa578 = data.DataReader('VGUARD.NS', 'yahoo', start_date, end_date)
panel_dataa579 = data.DataReader('A2ZINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa580 = data.DataReader('HDFCBANK.NS', 'yahoo', start_date, end_date)
panel_dataa581 = data.DataReader('VINYLINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa582 = data.DataReader('THEMISMED.NS', 'yahoo', start_date, end_date)
panel_dataa583 = data.DataReader('MRPL.NS', 'yahoo', start_date, end_date)
panel_dataa584 = data.DataReader('GNA.NS', 'yahoo', start_date, end_date)
panel_dataa585 = data.DataReader('TATACHEM.NS', 'yahoo', start_date, end_date)
panel_dataa586 = data.DataReader('QUESS.NS', 'yahoo', start_date, end_date)
panel_dataa587 = data.DataReader('NMDC.NS', 'yahoo', start_date, end_date)
panel_dataa588 = data.DataReader('CESC.NS', 'yahoo', start_date, end_date)
panel_dataa589 = data.DataReader('SDBL.NS', 'yahoo', start_date, end_date)
panel_dataa590 = data.DataReader('SCHNEIDER.NS', 'yahoo', start_date, end_date)
panel_dataa591 = data.DataReader('SHK.NS', 'yahoo', start_date, end_date)
panel_dataa592 = data.DataReader('NEULANDLAB.NS', 'yahoo', start_date, end_date)
panel_dataa593 = data.DataReader('CENTENKA.NS', 'yahoo', start_date, end_date)
panel_dataa594 = data.DataReader('RAMKY.NS', 'yahoo', start_date, end_date)
panel_dataa595 = data.DataReader('JSWENERGY.NS', 'yahoo', start_date, end_date)
panel_dataa596 = data.DataReader('METROPOLIS.NS', 'yahoo', start_date, end_date)
panel_dataa597 = data.DataReader('OAL.NS', 'yahoo', start_date, end_date)
panel_dataa598 = data.DataReader('ORIENTABRA.NS', 'yahoo', start_date, end_date)
panel_dataa599 = data.DataReader('TATAINVEST.NS', 'yahoo', start_date, end_date)
panel_dataa600 = data.DataReader('TATASTLLP.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa551['SYMBOL']='DABUR.NS'
panel_dataa552['SYMBOL']='MAHSEAMLES.NS'
panel_dataa553['SYMBOL']='JBCHEPHARM.NS'
panel_dataa554['SYMBOL']='SOLARINDS.NS'
panel_dataa555['SYMBOL']='BANCOINDIA.NS'
panel_dataa556['SYMBOL']='MUTHOOTFIN.NS'
panel_dataa557['SYMBOL']='SHOPERSTOP.NS'
panel_dataa558['SYMBOL']='TECHM.NS'
panel_dataa559['SYMBOL']='ICICIBANK.NS'
panel_dataa560['SYMBOL']='HUDCO.NS'
panel_dataa561['SYMBOL']='SCI.NS'
panel_dataa562['SYMBOL']='APOLLOTYRE.NS'
panel_dataa563['SYMBOL']='INDIACEM.NS'
panel_dataa564['SYMBOL']='KSCL.NS'
panel_dataa565['SYMBOL']='VIPIND.NS'
panel_dataa566['SYMBOL']='GPPL.NS'
panel_dataa567['SYMBOL']='LGBBROSLTD.NS'
panel_dataa568['SYMBOL']='AARTIIND.NS'
panel_dataa569['SYMBOL']='COALINDIA.NS'
panel_dataa570['SYMBOL']='SCHAND.NS'
panel_dataa571['SYMBOL']='SGL.NS'
panel_dataa572['SYMBOL']='MRF.NS'
panel_dataa573['SYMBOL']='SUBROS.NS'
panel_dataa574['SYMBOL']='BALAMINES.NS'
panel_dataa575['SYMBOL']='TATAMETALI.NS'
panel_dataa576['SYMBOL']='NEWGEN.NS'
panel_dataa577['SYMBOL']='HEG.NS'
panel_dataa578['SYMBOL']='VGUARD.NS'
panel_dataa579['SYMBOL']='A2ZINFRA.NS'
panel_dataa580['SYMBOL']='HDFCBANK.NS'
panel_dataa581['SYMBOL']='VINYLINDIA.NS'
panel_dataa582['SYMBOL']='THEMISMED.NS'
panel_dataa583['SYMBOL']='MRPL.NS'
panel_dataa584['SYMBOL']='GNA.NS'
panel_dataa585['SYMBOL']='TATACHEM.NS'
panel_dataa586['SYMBOL']='QUESS.NS'
panel_dataa587['SYMBOL']='NMDC.NS'
panel_dataa588['SYMBOL']='CESC.NS'
panel_dataa589['SYMBOL']='SDBL.NS'
panel_dataa590['SYMBOL']='SCHNEIDER.NS'
panel_dataa591['SYMBOL']='SHK.NS'
panel_dataa592['SYMBOL']='NEULANDLAB.NS'
panel_dataa593['SYMBOL']='CENTENKA.NS'
panel_dataa594['SYMBOL']='RAMKY.NS'
panel_dataa595['SYMBOL']='JSWENERGY.NS'
panel_dataa596['SYMBOL']='METROPOLIS.NS'
panel_dataa597['SYMBOL']='OAL.NS'
panel_dataa598['SYMBOL']='ORIENTABRA.NS'
panel_dataa599['SYMBOL']='TATAINVEST.NS'
panel_dataa600['SYMBOL']='TATASTLLP.NS'

# %%
finall = pd.concat([panel_dataa551,
panel_dataa552,
panel_dataa553,
panel_dataa554,
panel_dataa555,
panel_dataa556,
panel_dataa557,
panel_dataa558,
panel_dataa559,
panel_dataa560,
panel_dataa561,
panel_dataa562,
panel_dataa563,
panel_dataa564,
panel_dataa565,
panel_dataa566,
panel_dataa567,
panel_dataa568,
panel_dataa569,
panel_dataa570,
panel_dataa571,
panel_dataa572,
panel_dataa573,
panel_dataa574,
panel_dataa575,
panel_dataa576,
panel_dataa577,
panel_dataa578,
panel_dataa579,
panel_dataa580,
panel_dataa581,
panel_dataa582,
panel_dataa583,
panel_dataa584,
panel_dataa585,
panel_dataa586,
panel_dataa587,
panel_dataa588,
panel_dataa589,
panel_dataa590,
panel_dataa591,
panel_dataa592,
panel_dataa593,
panel_dataa594,
panel_dataa595,
panel_dataa596,
panel_dataa597,
panel_dataa598,
panel_dataa599,
panel_dataa600])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_551_TO_600_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_551_TO_600_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_551_TO_600_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...     Volume   Adj Close        SYMBOL
# 0                0  2002-07-01    8.675000  ...  2331240.0    3.838814      DABUR.NS
# 1                1  2002-07-02    8.615000  ...   925272.0    3.838814      DABUR.NS
# 2                2  2002-07-03    8.640000  ...  1304064.0    3.838814      DABUR.NS
# 3                3  2002-07-04    8.665000  ...  1589202.0    3.827636      DABUR.NS
# 4                4  2002-07-05    9.000000  ...  3139716.0    3.941658      DABUR.NS
# ...            ...         ...         ...  ...        ...         ...           ...
# 163014      163014  2020-08-10  291.899994  ...    60372.0  284.000000  TATASTLLP.NS
# 163015      163015  2020-08-11  309.000000  ...   154822.0  302.950012  TATASTLLP.NS
# 163016      163016  2020-08-12  323.000000  ...   143365.0  316.149994  TATASTLLP.NS
# 163017      163017  2020-08-13  322.700012  ...    59430.0  315.500000  TATASTLLP.NS
# ...
