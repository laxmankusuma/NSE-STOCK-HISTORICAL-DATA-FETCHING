# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa1051 = data.DataReader('CARERATING.NS', 'yahoo', start_date, end_date)
panel_dataa1052 = data.DataReader('GRAVITA.NS', 'yahoo', start_date, end_date)
panel_dataa1053 = data.DataReader('MARICO.NS', 'yahoo', start_date, end_date)
panel_dataa1054 = data.DataReader('HESTERBIO.NS', 'yahoo', start_date, end_date)
panel_dataa1055 = data.DataReader('DOLAT.NS', 'yahoo', start_date, end_date)
panel_dataa1056 = data.DataReader('RAMCOCEM.NS', 'yahoo', start_date, end_date)
panel_dataa1057 = data.DataReader('LUMAXIND.NS', 'yahoo', start_date, end_date)
panel_dataa1058 = data.DataReader('FORTIS.NS', 'yahoo', start_date, end_date)
panel_dataa1059 = data.DataReader('SCHAEFFLER.NS', 'yahoo', start_date, end_date)
panel_dataa1060 = data.DataReader('IGARASHI.NS', 'yahoo', start_date, end_date)
panel_dataa1061 = data.DataReader('GHCL.NS', 'yahoo', start_date, end_date)
panel_dataa1062 = data.DataReader('EDELWEISS.NS', 'yahoo', start_date, end_date)
panel_dataa1063 = data.DataReader('KAYA.NS', 'yahoo', start_date, end_date)
panel_dataa1064 = data.DataReader('GODREJCP.NS', 'yahoo', start_date, end_date)
panel_dataa1065 = data.DataReader('BAJAJCON.NS', 'yahoo', start_date, end_date)
panel_dataa1066 = data.DataReader('INFY.NS', 'yahoo', start_date, end_date)
panel_dataa1067 = data.DataReader('HNDFDS.NS', 'yahoo', start_date, end_date)
panel_dataa1068 = data.DataReader('NATCOPHARM.NS', 'yahoo', start_date, end_date)
panel_dataa1069 = data.DataReader('CRISIL.NS', 'yahoo', start_date, end_date)
panel_dataa1070 = data.DataReader('ECLERX.NS', 'yahoo', start_date, end_date)
panel_dataa1071 = data.DataReader('ORISSAMINE.NS', 'yahoo', start_date, end_date)
panel_dataa1072 = data.DataReader('ACCELYA.NS', 'yahoo', start_date, end_date)
panel_dataa1073 = data.DataReader('DRREDDY.NS', 'yahoo', start_date, end_date)
panel_dataa1074 = data.DataReader('3MINDIA.NS', 'yahoo', start_date, end_date)
#panel_dataa1075 = data.DataReader('SATIN-RE.NS', 'yahoo', start_date, end_date)
panel_dataa1076 = data.DataReader('BAGFILMS.NS', 'yahoo', start_date, end_date)
panel_dataa1077 = data.DataReader('KILITCH.NS', 'yahoo', start_date, end_date)
panel_dataa1078 = data.DataReader('SUPERSPIN.NS', 'yahoo', start_date, end_date)
panel_dataa1079 = data.DataReader('SHREDIGCEM.NS', 'yahoo', start_date, end_date)
panel_dataa1080 = data.DataReader('BLUECOAST.NS', 'yahoo', start_date, end_date)
panel_dataa1081 = data.DataReader('MANINDS.NS', 'yahoo', start_date, end_date)
panel_dataa1082 = data.DataReader('KABRAEXTRU.NS', 'yahoo', start_date, end_date)
panel_dataa1083 = data.DataReader('DIAPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa1084 = data.DataReader('FDC.NS', 'yahoo', start_date, end_date)
panel_dataa1085 = data.DataReader('SASTASUNDR.NS', 'yahoo', start_date, end_date)
panel_dataa1086 = data.DataReader('MANALIPETC.NS', 'yahoo', start_date, end_date)
panel_dataa1087 = data.DataReader('RAMANEWS.NS', 'yahoo', start_date, end_date)
panel_dataa1088 = data.DataReader('ORBTEXP.NS', 'yahoo', start_date, end_date)
panel_dataa1089 = data.DataReader('LAKSHVILAS.NS', 'yahoo', start_date, end_date)
panel_dataa1090 = data.DataReader('VIVIDHA.NS', 'yahoo', start_date, end_date)
panel_dataa1091 = data.DataReader('NILKAMAL.NS', 'yahoo', start_date, end_date)
panel_dataa1092 = data.DataReader('HAVISHA.NS', 'yahoo', start_date, end_date)
panel_dataa1093 = data.DataReader('ENDURANCE.NS', 'yahoo', start_date, end_date)
panel_dataa1094 = data.DataReader('CELEBRITY.NS', 'yahoo', start_date, end_date)
panel_dataa1095 = data.DataReader('IL&FSTRANS.NS', 'yahoo', start_date, end_date)
panel_dataa1096 = data.DataReader('SUNDRMFAST.NS', 'yahoo', start_date, end_date)
panel_dataa1097 = data.DataReader('J&KBANK.NS', 'yahoo', start_date, end_date)
panel_dataa1098 = data.DataReader('SUNDARAM.NS', 'yahoo', start_date, end_date)
panel_dataa1099 = data.DataReader('NDTV.NS', 'yahoo', start_date, end_date)
panel_dataa1100 = data.DataReader('UVSL.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1051['SYMBOL']='CARERATING.NS'
panel_dataa1052['SYMBOL']='GRAVITA.NS'
panel_dataa1053['SYMBOL']='MARICO.NS'
panel_dataa1054['SYMBOL']='HESTERBIO.NS'
panel_dataa1055['SYMBOL']='DOLAT.NS'
panel_dataa1056['SYMBOL']='RAMCOCEM.NS'
panel_dataa1057['SYMBOL']='LUMAXIND.NS'
panel_dataa1058['SYMBOL']='FORTIS.NS'
panel_dataa1059['SYMBOL']='SCHAEFFLER.NS'
panel_dataa1060['SYMBOL']='IGARASHI.NS'
panel_dataa1061['SYMBOL']='GHCL.NS'
panel_dataa1062['SYMBOL']='EDELWEISS.NS'
panel_dataa1063['SYMBOL']='KAYA.NS'
panel_dataa1064['SYMBOL']='GODREJCP.NS'
panel_dataa1065['SYMBOL']='BAJAJCON.NS'
panel_dataa1066['SYMBOL']='INFY.NS'
panel_dataa1067['SYMBOL']='HNDFDS.NS'
panel_dataa1068['SYMBOL']='NATCOPHARM.NS'
panel_dataa1069['SYMBOL']='CRISIL.NS'
panel_dataa1070['SYMBOL']='ECLERX.NS'
panel_dataa1071['SYMBOL']='ORISSAMINE.NS'
panel_dataa1072['SYMBOL']='ACCELYA.NS'
panel_dataa1073['SYMBOL']='DRREDDY.NS'
panel_dataa1074['SYMBOL']='3MINDIA.NS'
#panel_dataa1075['SYMBOL']='SATIN-RE.NS'
panel_dataa1076['SYMBOL']='BAGFILMS.NS'
panel_dataa1077['SYMBOL']='KILITCH.NS'
panel_dataa1078['SYMBOL']='SUPERSPIN.NS'
panel_dataa1079['SYMBOL']='SHREDIGCEM.NS'
panel_dataa1080['SYMBOL']='BLUECOAST.NS'
panel_dataa1081['SYMBOL']='MANINDS.NS'
panel_dataa1082['SYMBOL']='KABRAEXTRU.NS'
panel_dataa1083['SYMBOL']='DIAPOWER.NS'
panel_dataa1084['SYMBOL']='FDC.NS'
panel_dataa1085['SYMBOL']='SASTASUNDR.NS'
panel_dataa1086['SYMBOL']='MANALIPETC.NS'
panel_dataa1087['SYMBOL']='RAMANEWS.NS'
panel_dataa1088['SYMBOL']='ORBTEXP.NS'
panel_dataa1089['SYMBOL']='LAKSHVILAS.NS'
panel_dataa1090['SYMBOL']='VIVIDHA.NS'
panel_dataa1091['SYMBOL']='NILKAMAL.NS'
panel_dataa1092['SYMBOL']='HAVISHA.NS'
panel_dataa1093['SYMBOL']='ENDURANCE.NS'
panel_dataa1094['SYMBOL']='CELEBRITY.NS'
panel_dataa1095['SYMBOL']='IL&FSTRANS.NS'
panel_dataa1096['SYMBOL']='SUNDRMFAST.NS'
panel_dataa1097['SYMBOL']='J&KBANK.NS'
panel_dataa1098['SYMBOL']='SUNDARAM.NS'
panel_dataa1099['SYMBOL']='NDTV.NS'
panel_dataa1100['SYMBOL']='UVSL.NS'

# %%
finall = pd.concat([panel_dataa1051,
panel_dataa1052,
panel_dataa1053,
panel_dataa1054,
panel_dataa1055,
panel_dataa1056,
panel_dataa1057,
panel_dataa1058,
panel_dataa1059,
panel_dataa1060,
panel_dataa1061,
panel_dataa1062,
panel_dataa1063,
panel_dataa1064,
panel_dataa1065,
panel_dataa1066,
panel_dataa1067,
panel_dataa1068,
panel_dataa1069,
panel_dataa1070,
panel_dataa1071,
panel_dataa1072,
panel_dataa1073,
panel_dataa1074,
#panel_dataa1075,
panel_dataa1076,
panel_dataa1077,
panel_dataa1078,
panel_dataa1079,
panel_dataa1080,
panel_dataa1081,
panel_dataa1082,
panel_dataa1083,
panel_dataa1084,
panel_dataa1085,
panel_dataa1086,
panel_dataa1087,
panel_dataa1088,
panel_dataa1089,
panel_dataa1090,
panel_dataa1091,
panel_dataa1092,
panel_dataa1093,
panel_dataa1094,
panel_dataa1095,
panel_dataa1096,
panel_dataa1097,
panel_dataa1098,
panel_dataa1099,
panel_dataa1100])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1051_TO_1100_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1051_TO_1100_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1051_TO_1100_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  ...   Adj Close         SYMBOL
# 0                0  2012-12-26  ...  737.550903  CARERATING.NS
# 1                1  2012-12-27  ...  747.144775  CARERATING.NS
# 2                2  2012-12-28  ...  741.108643  CARERATING.NS
# 3                3  2012-12-31  ...  731.355042  CARERATING.NS
# 4                4  2013-01-01  ...  734.672913  CARERATING.NS
# ...            ...         ...  ...         ...            ...
# 167190      167190  2020-08-10  ...    0.550000        UVSL.NS
# 167191      167191  2020-08-11  ...    0.550000        UVSL.NS
# 167192      167192  2020-08-12  ...    0.550000        UVSL.NS
# 167193      167193  2020-08-13  ...    0.550000        UVSL.NS
# 167194      167194  2020-08-14  ...    0.550000        UVSL.NS
#
# [167195 rows x 9 columns]
