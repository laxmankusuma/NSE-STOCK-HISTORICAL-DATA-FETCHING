# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa1101 = data.DataReader('MBLINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa1102 = data.DataReader('VENUSREM.NS', 'yahoo', start_date, end_date)
panel_dataa1103 = data.DataReader('KRIDHANINF.NS', 'yahoo', start_date, end_date)
panel_dataa1104 = data.DataReader('FSL.NS', 'yahoo', start_date, end_date)
panel_dataa1105 = data.DataReader('GTLINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa1106 = data.DataReader('LOTUSEYE.NS', 'yahoo', start_date, end_date)
panel_dataa1107 = data.DataReader('INDOWIND.NS', 'yahoo', start_date, end_date)
panel_dataa1108 = data.DataReader('KAMATHOTEL.NS', 'yahoo', start_date, end_date)
panel_dataa1109 = data.DataReader('FCL.NS', 'yahoo', start_date, end_date)
panel_dataa1110 = data.DataReader('GREENPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa1111 = data.DataReader('ARCHIES.NS', 'yahoo', start_date, end_date)
panel_dataa1112 = data.DataReader('CGCL.NS', 'yahoo', start_date, end_date)
panel_dataa1113 = data.DataReader('CKFSL.NS', 'yahoo', start_date, end_date)
panel_dataa1114 = data.DataReader('NITINFIRE.NS', 'yahoo', start_date, end_date)
panel_dataa1115 = data.DataReader('SEAMECLTD.NS', 'yahoo', start_date, end_date)
panel_dataa1116 = data.DataReader('GUFICBIO.NS', 'yahoo', start_date, end_date)
panel_dataa1117 = data.DataReader('SITINET.NS', 'yahoo', start_date, end_date)
panel_dataa1118 = data.DataReader('FCONSUMER.NS', 'yahoo', start_date, end_date)
panel_dataa1119 = data.DataReader('HIMATSEIDE.NS', 'yahoo', start_date, end_date)
panel_dataa1120 = data.DataReader('KECL.NS', 'yahoo', start_date, end_date)
panel_dataa1121 = data.DataReader('ANUP.NS', 'yahoo', start_date, end_date)
panel_dataa1122 = data.DataReader('SAKAR.NS', 'yahoo', start_date, end_date)
panel_dataa1123 = data.DataReader('SPLIL.NS', 'yahoo', start_date, end_date)
panel_dataa1124 = data.DataReader('VICEROY.NS', 'yahoo', start_date, end_date)
panel_dataa1125 = data.DataReader('CENTRALBK.NS', 'yahoo', start_date, end_date)
panel_dataa1126 = data.DataReader('SPYL.NS', 'yahoo', start_date, end_date)
panel_dataa1127 = data.DataReader('ANDHRACEMT.NS', 'yahoo', start_date, end_date)
panel_dataa1128 = data.DataReader('TCNSBRANDS.NS', 'yahoo', start_date, end_date)
panel_dataa1129 = data.DataReader('UNITECH.NS', 'yahoo', start_date, end_date)
panel_dataa1130 = data.DataReader('GOKUL.NS', 'yahoo', start_date, end_date)
panel_dataa1131 = data.DataReader('DNAMEDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1132 = data.DataReader('KOTARISUG.NS', 'yahoo', start_date, end_date)
panel_dataa1133 = data.DataReader('SWARAJENG.NS', 'yahoo', start_date, end_date)
panel_dataa1134 = data.DataReader('DHANBANK.NS', 'yahoo', start_date, end_date)
panel_dataa1135 = data.DataReader('KSERASERA.NS', 'yahoo', start_date, end_date)
panel_dataa1136 = data.DataReader('ARIHANTSUP.NS', 'yahoo', start_date, end_date)
panel_dataa1137 = data.DataReader('FRETAIL.NS', 'yahoo', start_date, end_date)
panel_dataa1138 = data.DataReader('63MOONS.NS', 'yahoo', start_date, end_date)
panel_dataa1139 = data.DataReader('RAJRAYON.NS', 'yahoo', start_date, end_date)
panel_dataa1140 = data.DataReader('HCL-INSYS.NS', 'yahoo', start_date, end_date)
panel_dataa1141 = data.DataReader('FILATEX.NS', 'yahoo', start_date, end_date)
panel_dataa1142 = data.DataReader('SARLAPOLY.NS', 'yahoo', start_date, end_date)
panel_dataa1143 = data.DataReader('JPINFRATEC.NS', 'yahoo', start_date, end_date)
panel_dataa1144 = data.DataReader('CREATIVEYE.NS', 'yahoo', start_date, end_date)
panel_dataa1145 = data.DataReader('SANDHAR.NS', 'yahoo', start_date, end_date)
panel_dataa1146 = data.DataReader('OILCOUNTUB.NS', 'yahoo', start_date, end_date)
panel_dataa1147 = data.DataReader('GAMMNINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa1148 = data.DataReader('METKORE.NS', 'yahoo', start_date, end_date)
panel_dataa1149 = data.DataReader('SELAN.NS', 'yahoo', start_date, end_date)
panel_dataa1150 = data.DataReader('IGPL.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1101['SYMBOL']='MBLINFRA.NS'
panel_dataa1102['SYMBOL']='VENUSREM.NS'
panel_dataa1103['SYMBOL']='KRIDHANINF.NS'
panel_dataa1104['SYMBOL']='FSL.NS'
panel_dataa1105['SYMBOL']='GTLINFRA.NS'
panel_dataa1106['SYMBOL']='LOTUSEYE.NS'
panel_dataa1107['SYMBOL']='INDOWIND.NS'
panel_dataa1108['SYMBOL']='KAMATHOTEL.NS'
panel_dataa1109['SYMBOL']='FCL.NS'
panel_dataa1110['SYMBOL']='GREENPOWER.NS'
panel_dataa1111['SYMBOL']='ARCHIES.NS'
panel_dataa1112['SYMBOL']='CGCL.NS'
panel_dataa1113['SYMBOL']='CKFSL.NS'
panel_dataa1114['SYMBOL']='NITINFIRE.NS'
panel_dataa1115['SYMBOL']='SEAMECLTD.NS'
panel_dataa1116['SYMBOL']='GUFICBIO.NS'
panel_dataa1117['SYMBOL']='SITINET.NS'
panel_dataa1118['SYMBOL']='FCONSUMER.NS'
panel_dataa1119['SYMBOL']='HIMATSEIDE.NS'
panel_dataa1120['SYMBOL']='KECL.NS'
panel_dataa1121['SYMBOL']='ANUP.NS'
panel_dataa1122['SYMBOL']='SAKAR.NS'
panel_dataa1123['SYMBOL']='SPLIL.NS'
panel_dataa1124['SYMBOL']='VICEROY.NS'
panel_dataa1125['SYMBOL']='CENTRALBK.NS'
panel_dataa1126['SYMBOL']='SPYL.NS'
panel_dataa1127['SYMBOL']='ANDHRACEMT.NS'
panel_dataa1128['SYMBOL']='TCNSBRANDS.NS'
panel_dataa1129['SYMBOL']='UNITECH.NS'
panel_dataa1130['SYMBOL']='GOKUL.NS'
panel_dataa1131['SYMBOL']='DNAMEDIA.NS'
panel_dataa1132['SYMBOL']='KOTARISUG.NS'
panel_dataa1133['SYMBOL']='SWARAJENG.NS'
panel_dataa1134['SYMBOL']='DHANBANK.NS'
panel_dataa1135['SYMBOL']='KSERASERA.NS'
panel_dataa1136['SYMBOL']='ARIHANTSUP.NS'
panel_dataa1137['SYMBOL']='FRETAIL.NS'
panel_dataa1138['SYMBOL']='63MOONS.NS'
panel_dataa1139['SYMBOL']='RAJRAYON.NS'
panel_dataa1140['SYMBOL']='HCL-INSYS.NS'
panel_dataa1141['SYMBOL']='FILATEX.NS'
panel_dataa1142['SYMBOL']='SARLAPOLY.NS'
panel_dataa1143['SYMBOL']='JPINFRATEC.NS'
panel_dataa1144['SYMBOL']='CREATIVEYE.NS'
panel_dataa1145['SYMBOL']='SANDHAR.NS'
panel_dataa1146['SYMBOL']='OILCOUNTUB.NS'
panel_dataa1147['SYMBOL']='GAMMNINFRA.NS'
panel_dataa1148['SYMBOL']='METKORE.NS'
panel_dataa1149['SYMBOL']='SELAN.NS'
panel_dataa1150['SYMBOL']='IGPL.NS'

# %%
finall = pd.concat([panel_dataa1101,
panel_dataa1102,
panel_dataa1103,
panel_dataa1104,
panel_dataa1105,
panel_dataa1106,
panel_dataa1107,
panel_dataa1108,
panel_dataa1109,
panel_dataa1110,
panel_dataa1111,
panel_dataa1112,
panel_dataa1113,
panel_dataa1114,
panel_dataa1115,
panel_dataa1116,
panel_dataa1117,
panel_dataa1118,
panel_dataa1119,
panel_dataa1120,
panel_dataa1121,
panel_dataa1122,
panel_dataa1123,
panel_dataa1124,
panel_dataa1125,
panel_dataa1126,
panel_dataa1127,
panel_dataa1128,
panel_dataa1129,
panel_dataa1130,
panel_dataa1131,
panel_dataa1132,
panel_dataa1133,
panel_dataa1134,
panel_dataa1135,
panel_dataa1136,
panel_dataa1137,
panel_dataa1138,
panel_dataa1139,
panel_dataa1140,
panel_dataa1141,
panel_dataa1142,
panel_dataa1143,
panel_dataa1144,
panel_dataa1145,
panel_dataa1146,
panel_dataa1147,
panel_dataa1148,
panel_dataa1149,
panel_dataa1150])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1101_TO_1150_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1101_TO_1150_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1101_TO_1150_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...      Volume   Adj Close       SYMBOL
# 0                0  2010-01-11  109.699997  ...  16904532.0   83.133232  MBLINFRA.NS
# 1                1  2010-01-12  103.949997  ...   3013622.0   76.552605  MBLINFRA.NS
# 2                2  2010-01-13   96.400002  ...   1780188.0   76.371483  MBLINFRA.NS
# 3                3  2010-01-14   97.250000  ...    595966.0   76.150116  MBLINFRA.NS
# 4                4  2010-01-15   96.400002  ...    462946.0   74.318810  MBLINFRA.NS
# ...            ...         ...         ...  ...         ...         ...          ...
# 140783      140783  2020-08-10  205.000000  ...     66087.0  191.206650      IGPL.NS
# 140784      140784  2020-08-11  196.250000  ...     32267.0  182.103928      IGPL.NS
# 140785      140785  2020-08-12  194.000000  ...     36423.0  191.008759      IGPL.NS
# 140786      140786  2020-08-13  198.250000  ...     27028.0  187.051056      IGPL.NS
# ...
