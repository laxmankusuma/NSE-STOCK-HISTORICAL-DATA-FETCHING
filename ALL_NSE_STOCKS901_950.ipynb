# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa901 = data.DataReader('SASKEN.NS', 'yahoo', start_date, end_date)
panel_dataa902 = data.DataReader('HATSUN.NS', 'yahoo', start_date, end_date)
panel_dataa903 = data.DataReader('VMART.NS', 'yahoo', start_date, end_date)
panel_dataa904 = data.DataReader('TMRVL.NS', 'yahoo', start_date, end_date)
panel_dataa905 = data.DataReader('FINPIPE.NS', 'yahoo', start_date, end_date)
panel_dataa906 = data.DataReader('VTL.NS', 'yahoo', start_date, end_date)
panel_dataa907 = data.DataReader('HERITGFOOD.NS', 'yahoo', start_date, end_date)
panel_dataa908 = data.DataReader('ZYDUSWELL.NS', 'yahoo', start_date, end_date)
panel_dataa909 = data.DataReader('SUNCLAYLTD.NS', 'yahoo', start_date, end_date)
panel_dataa910 = data.DataReader('CESCVENT.NS', 'yahoo', start_date, end_date)
panel_dataa911 = data.DataReader('IDFCFIRSTB.NS', 'yahoo', start_date, end_date)
panel_dataa912 = data.DataReader('WESTLIFE.NS', 'yahoo', start_date, end_date)
panel_dataa913 = data.DataReader('SSWL.NS', 'yahoo', start_date, end_date)
panel_dataa914 = data.DataReader('HARRMALAYA.NS', 'yahoo', start_date, end_date)
panel_dataa915 = data.DataReader('ABB.NS', 'yahoo', start_date, end_date)
panel_dataa916 = data.DataReader('NHPC.NS', 'yahoo', start_date, end_date)
panel_dataa917 = data.DataReader('ASAHISONG.NS', 'yahoo', start_date, end_date)
panel_dataa918 = data.DataReader('BINDALAGRO.NS', 'yahoo', start_date, end_date)
panel_dataa919 = data.DataReader('RITES.NS', 'yahoo', start_date, end_date)
panel_dataa920 = data.DataReader('DREDGECORP.NS', 'yahoo', start_date, end_date)
panel_dataa921 = data.DataReader('GDL.NS', 'yahoo', start_date, end_date)
panel_dataa922 = data.DataReader('MPHASIS.NS', 'yahoo', start_date, end_date)
panel_dataa923 = data.DataReader('ADANIGAS.NS', 'yahoo', start_date, end_date)
panel_dataa924 = data.DataReader('HCG.NS', 'yahoo', start_date, end_date)
panel_dataa925 = data.DataReader('RAJESHEXPO.NS', 'yahoo', start_date, end_date)
panel_dataa926 = data.DataReader('GIPCL.NS', 'yahoo', start_date, end_date)
panel_dataa927 = data.DataReader('AGROPHOS.NS', 'yahoo', start_date, end_date)
panel_dataa928 = data.DataReader('UBL.NS', 'yahoo', start_date, end_date)
panel_dataa929 = data.DataReader('NEOGEN.NS', 'yahoo', start_date, end_date)
panel_dataa930 = data.DataReader('LTI.NS', 'yahoo', start_date, end_date)
panel_dataa931 = data.DataReader('AMBUJACEM.NS', 'yahoo', start_date, end_date)
panel_dataa932 = data.DataReader('MANAPPURAM.NS', 'yahoo', start_date, end_date)
panel_dataa933 = data.DataReader('APOLLOHOSP.NS', 'yahoo', start_date, end_date)
panel_dataa934 = data.DataReader('BATAINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa935 = data.DataReader('HSCL.NS', 'yahoo', start_date, end_date)
panel_dataa936 = data.DataReader('AVANTIFEED.NS', 'yahoo', start_date, end_date)
panel_dataa937 = data.DataReader('TATAELXSI.NS', 'yahoo', start_date, end_date)
panel_dataa938 = data.DataReader('BBTC.NS', 'yahoo', start_date, end_date)
panel_dataa939 = data.DataReader('BANKINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa940 = data.DataReader('JKPAPER.NS', 'yahoo', start_date, end_date)
panel_dataa941 = data.DataReader('MAHABANK.NS', 'yahoo', start_date, end_date)
panel_dataa942 = data.DataReader('BHARATWIRE.NS', 'yahoo', start_date, end_date)
panel_dataa943 = data.DataReader('BHARATFORG.NS', 'yahoo', start_date, end_date)
panel_dataa944 = data.DataReader('JUBILANT.NS', 'yahoo', start_date, end_date)
panel_dataa945 = data.DataReader('STARPAPER.NS', 'yahoo', start_date, end_date)
panel_dataa946 = data.DataReader('TTKHLTCARE.NS', 'yahoo', start_date, end_date)
panel_dataa947 = data.DataReader('TIMESGTY.NS', 'yahoo', start_date, end_date)
panel_dataa948 = data.DataReader('GODREJAGRO.NS', 'yahoo', start_date, end_date)
panel_dataa949 = data.DataReader('SKIPPER.NS', 'yahoo', start_date, end_date)
panel_dataa950 = data.DataReader('RPGLIFE.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa901['SYMBOL']='SASKEN.NS'
panel_dataa902['SYMBOL']='HATSUN.NS'
panel_dataa903['SYMBOL']='VMART.NS'
panel_dataa904['SYMBOL']='TMRVL.NS'
panel_dataa905['SYMBOL']='FINPIPE.NS'
panel_dataa906['SYMBOL']='VTL.NS'
panel_dataa907['SYMBOL']='HERITGFOOD.NS'
panel_dataa908['SYMBOL']='ZYDUSWELL.NS'
panel_dataa909['SYMBOL']='SUNCLAYLTD.NS'
panel_dataa910['SYMBOL']='CESCVENT.NS'
panel_dataa911['SYMBOL']='IDFCFIRSTB.NS'
panel_dataa912['SYMBOL']='WESTLIFE.NS'
panel_dataa913['SYMBOL']='SSWL.NS'
panel_dataa914['SYMBOL']='HARRMALAYA.NS'
panel_dataa915['SYMBOL']='ABB.NS'
panel_dataa916['SYMBOL']='NHPC.NS'
panel_dataa917['SYMBOL']='ASAHISONG.NS'
panel_dataa918['SYMBOL']='BINDALAGRO.NS'
panel_dataa919['SYMBOL']='RITES.NS'
panel_dataa920['SYMBOL']='DREDGECORP.NS'
panel_dataa921['SYMBOL']='GDL.NS'
panel_dataa922['SYMBOL']='MPHASIS.NS'
panel_dataa923['SYMBOL']='ADANIGAS.NS'
panel_dataa924['SYMBOL']='HCG.NS'
panel_dataa925['SYMBOL']='RAJESHEXPO.NS'
panel_dataa926['SYMBOL']='GIPCL.NS'
panel_dataa927['SYMBOL']='AGROPHOS.NS'
panel_dataa928['SYMBOL']='UBL.NS'
panel_dataa929['SYMBOL']='NEOGEN.NS'
panel_dataa930['SYMBOL']='LTI.NS'
panel_dataa931['SYMBOL']='AMBUJACEM.NS'
panel_dataa932['SYMBOL']='MANAPPURAM.NS'
panel_dataa933['SYMBOL']='APOLLOHOSP.NS'
panel_dataa934['SYMBOL']='BATAINDIA.NS'
panel_dataa935['SYMBOL']='HSCL.NS'
panel_dataa936['SYMBOL']='AVANTIFEED.NS'
panel_dataa937['SYMBOL']='TATAELXSI.NS'
panel_dataa938['SYMBOL']='BBTC.NS'
panel_dataa939['SYMBOL']='BANKINDIA.NS'
panel_dataa940['SYMBOL']='JKPAPER.NS'
panel_dataa941['SYMBOL']='MAHABANK.NS'
panel_dataa942['SYMBOL']='BHARATWIRE.NS'
panel_dataa943['SYMBOL']='BHARATFORG.NS'
panel_dataa944['SYMBOL']='JUBILANT.NS'
panel_dataa945['SYMBOL']='STARPAPER.NS'
panel_dataa946['SYMBOL']='TTKHLTCARE.NS'
panel_dataa947['SYMBOL']='TIMESGTY.NS'
panel_dataa948['SYMBOL']='GODREJAGRO.NS'
panel_dataa949['SYMBOL']='SKIPPER.NS'
panel_dataa950['SYMBOL']='RPGLIFE.NS'

# %%
finall = pd.concat([panel_dataa901,
panel_dataa902,
panel_dataa903,
panel_dataa904,
panel_dataa905,
panel_dataa906,
panel_dataa907,
panel_dataa908,
panel_dataa909,
panel_dataa910,
panel_dataa911,
panel_dataa912,
panel_dataa913,
panel_dataa914,
panel_dataa915,
panel_dataa916,
panel_dataa917,
panel_dataa918,
panel_dataa919,
panel_dataa920,
panel_dataa921,
panel_dataa922,
panel_dataa923,
panel_dataa924,
panel_dataa925,
panel_dataa926,
panel_dataa927,
panel_dataa928,
panel_dataa929,
panel_dataa930,
panel_dataa931,
panel_dataa932,
panel_dataa933,
panel_dataa934,
panel_dataa935,
panel_dataa936,
panel_dataa937,
panel_dataa938,
panel_dataa939,
panel_dataa940,
panel_dataa941,
panel_dataa942,
panel_dataa943,
panel_dataa944,
panel_dataa945,
panel_dataa946,
panel_dataa947,
panel_dataa948,
panel_dataa949,
panel_dataa950])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_901_TO_950_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_901_TO_950_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_901_TO_950_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...      Volume   Adj Close      SYMBOL
# 0                0  2005-09-09  624.000000  ...  17000416.0  288.568054   SASKEN.NS
# 1                1  2005-09-12  469.000000  ...   6299905.0  272.978149   SASKEN.NS
# 2                2  2005-09-13  473.700012  ...   7495786.0  288.971771   SASKEN.NS
# 3                3  2005-09-14  472.049988  ...   2717404.0  281.114655   SASKEN.NS
# 4                4  2005-09-15  461.700012  ...   1490425.0  280.710938   SASKEN.NS
# ...            ...         ...         ...  ...         ...         ...         ...
# 150822      150822  2020-08-10  417.649994  ...    613981.0  403.799988  RPGLIFE.NS
# 150823      150823  2020-08-11  409.000000  ...    147534.0  389.299988  RPGLIFE.NS
# 150824      150824  2020-08-12  392.000000  ...     82019.0  377.750000  RPGLIFE.NS
# 150825      150825  2020-08-13  390.000000  ...     95362.0  378.000000  RPGLIFE.NS
# ...
