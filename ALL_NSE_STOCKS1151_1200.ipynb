# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa1151 = data.DataReader('RUCHIRA.NS', 'yahoo', start_date, end_date)
panel_dataa1152 = data.DataReader('SHRIRAMEPC.NS', 'yahoo', start_date, end_date)
panel_dataa1153 = data.DataReader('PANAMAPET.NS', 'yahoo', start_date, end_date)
panel_dataa1154 = data.DataReader('ANIKINDS.NS', 'yahoo', start_date, end_date)
panel_dataa1155 = data.DataReader('UCOBANK.NS', 'yahoo', start_date, end_date)
panel_dataa1156 = data.DataReader('IVC.NS', 'yahoo', start_date, end_date)
panel_dataa1157 = data.DataReader('AROGRANITE.NS', 'yahoo', start_date, end_date)
panel_dataa1158 = data.DataReader('GREENPLY.NS', 'yahoo', start_date, end_date)
panel_dataa1159 = data.DataReader('ESABINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1160 = data.DataReader('SOUTHBANK.NS', 'yahoo', start_date, end_date)
panel_dataa1161 = data.DataReader('KUANTUM.NS', 'yahoo', start_date, end_date)
panel_dataa1162 = data.DataReader('LSIL.NS', 'yahoo', start_date, end_date)
panel_dataa1163 = data.DataReader('ORIENTHOT.NS', 'yahoo', start_date, end_date)
panel_dataa1164 = data.DataReader('ANKITMETAL.NS', 'yahoo', start_date, end_date)
panel_dataa1165 = data.DataReader('ASHIMASYN.NS', 'yahoo', start_date, end_date)
panel_dataa1166 = data.DataReader('BCG.NS', 'yahoo', start_date, end_date)
panel_dataa1167 = data.DataReader('UJJIVANSFB.NS', 'yahoo', start_date, end_date)
panel_dataa1168 = data.DataReader('IDBI.NS', 'yahoo', start_date, end_date)
panel_dataa1169 = data.DataReader('RUCHI.NS', 'yahoo', start_date, end_date)
panel_dataa1170 = data.DataReader('TIMKEN.NS', 'yahoo', start_date, end_date)
panel_dataa1171 = data.DataReader('FCSSOFT.NS', 'yahoo', start_date, end_date)
panel_dataa1172 = data.DataReader('ESSARSHPNG.NS', 'yahoo', start_date, end_date)
panel_dataa1173 = data.DataReader('TRENT.NS', 'yahoo', start_date, end_date)
panel_dataa1174 = data.DataReader('INDIGO.NS', 'yahoo', start_date, end_date)
panel_dataa1175 = data.DataReader('DYNPRO.NS', 'yahoo', start_date, end_date)
panel_dataa1176 = data.DataReader('VRLLOG.NS', 'yahoo', start_date, end_date)
panel_dataa1177 = data.DataReader('MAHSCOOTER.NS', 'yahoo', start_date, end_date)
panel_dataa1178 = data.DataReader('WHIRLPOOL.NS', 'yahoo', start_date, end_date)
panel_dataa1179 = data.DataReader('VIMTALABS.NS', 'yahoo', start_date, end_date)
panel_dataa1180 = data.DataReader('BERGEPAINT.NS', 'yahoo', start_date, end_date)
panel_dataa1181 = data.DataReader('TATAMOTORS.NS', 'yahoo', start_date, end_date)
panel_dataa1182 = data.DataReader('WABCOINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1183 = data.DataReader('5PAISA.NS', 'yahoo', start_date, end_date)
panel_dataa1184 = data.DataReader('TATASTEEL.NS', 'yahoo', start_date, end_date)
panel_dataa1185 = data.DataReader('UNIVPHOTO.NS', 'yahoo', start_date, end_date)
panel_dataa1186 = data.DataReader('SHREYANIND.NS', 'yahoo', start_date, end_date)
panel_dataa1187 = data.DataReader('INFRATEL.NS', 'yahoo', start_date, end_date)
panel_dataa1188 = data.DataReader('VENKEYS.NS', 'yahoo', start_date, end_date)
panel_dataa1189 = data.DataReader('ATLASCYCLE.NS', 'yahoo', start_date, end_date)
panel_dataa1190 = data.DataReader('GULFPETRO.NS', 'yahoo', start_date, end_date)
panel_dataa1191 = data.DataReader('RSWM.NS', 'yahoo', start_date, end_date)
panel_dataa1192 = data.DataReader('GUJAPOLLO.NS', 'yahoo', start_date, end_date)
panel_dataa1193 = data.DataReader('LAMBODHARA.NS', 'yahoo', start_date, end_date)
panel_dataa1194 = data.DataReader('INFIBEAM.NS', 'yahoo', start_date, end_date)
panel_dataa1195 = data.DataReader('FACT.NS', 'yahoo', start_date, end_date)
panel_dataa1196 = data.DataReader('RELIANCE.NS', 'yahoo', start_date, end_date)
panel_dataa1197 = data.DataReader('AGARIND.NS', 'yahoo', start_date, end_date)
panel_dataa1198 = data.DataReader('THANGAMAYL.NS', 'yahoo', start_date, end_date)
panel_dataa1199 = data.DataReader('AVTNPL.NS', 'yahoo', start_date, end_date)
panel_dataa1200 = data.DataReader('CAMLINFINE.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1151['SYMBOL']='RUCHIRA.NS'
panel_dataa1152['SYMBOL']='SHRIRAMEPC.NS'
panel_dataa1153['SYMBOL']='PANAMAPET.NS'
panel_dataa1154['SYMBOL']='ANIKINDS.NS'
panel_dataa1155['SYMBOL']='UCOBANK.NS'
panel_dataa1156['SYMBOL']='IVC.NS'
panel_dataa1157['SYMBOL']='AROGRANITE.NS'
panel_dataa1158['SYMBOL']='GREENPLY.NS'
panel_dataa1159['SYMBOL']='ESABINDIA.NS'
panel_dataa1160['SYMBOL']='SOUTHBANK.NS'
panel_dataa1161['SYMBOL']='KUANTUM.NS'
panel_dataa1162['SYMBOL']='LSIL.NS'
panel_dataa1163['SYMBOL']='ORIENTHOT.NS'
panel_dataa1164['SYMBOL']='ANKITMETAL.NS'
panel_dataa1165['SYMBOL']='ASHIMASYN.NS'
panel_dataa1166['SYMBOL']='BCG.NS'
panel_dataa1167['SYMBOL']='UJJIVANSFB.NS'
panel_dataa1168['SYMBOL']='IDBI.NS'
panel_dataa1169['SYMBOL']='RUCHI.NS'
panel_dataa1170['SYMBOL']='TIMKEN.NS'
panel_dataa1171['SYMBOL']='FCSSOFT.NS'
panel_dataa1172['SYMBOL']='ESSARSHPNG.NS'
panel_dataa1173['SYMBOL']='TRENT.NS'
panel_dataa1174['SYMBOL']='INDIGO.NS'
panel_dataa1175['SYMBOL']='DYNPRO.NS'
panel_dataa1176['SYMBOL']='VRLLOG.NS'
panel_dataa1177['SYMBOL']='MAHSCOOTER.NS'
panel_dataa1178['SYMBOL']='WHIRLPOOL.NS'
panel_dataa1179['SYMBOL']='VIMTALABS.NS'
panel_dataa1180['SYMBOL']='BERGEPAINT.NS'
panel_dataa1181['SYMBOL']='TATAMOTORS.NS'
panel_dataa1182['SYMBOL']='WABCOINDIA.NS'
panel_dataa1183['SYMBOL']='5PAISA.NS'
panel_dataa1184['SYMBOL']='TATASTEEL.NS'
panel_dataa1185['SYMBOL']='UNIVPHOTO.NS'
panel_dataa1186['SYMBOL']='SHREYANIND.NS'
panel_dataa1187['SYMBOL']='INFRATEL.NS'
panel_dataa1188['SYMBOL']='VENKEYS.NS'
panel_dataa1189['SYMBOL']='ATLASCYCLE.NS'
panel_dataa1190['SYMBOL']='GULFPETRO.NS'
panel_dataa1191['SYMBOL']='RSWM.NS'
panel_dataa1192['SYMBOL']='GUJAPOLLO.NS'
panel_dataa1193['SYMBOL']='LAMBODHARA.NS'
panel_dataa1194['SYMBOL']='INFIBEAM.NS'
panel_dataa1195['SYMBOL']='FACT.NS'
panel_dataa1196['SYMBOL']='RELIANCE.NS'
panel_dataa1197['SYMBOL']='AGARIND.NS'
panel_dataa1198['SYMBOL']='THANGAMAYL.NS'
panel_dataa1199['SYMBOL']='AVTNPL.NS'
panel_dataa1200['SYMBOL']='CAMLINFINE.NS'

# %%
finall = pd.concat([panel_dataa1151,
panel_dataa1152,
panel_dataa1153,
panel_dataa1154,
panel_dataa1155,
panel_dataa1156,
panel_dataa1157,
panel_dataa1158,
panel_dataa1159,
panel_dataa1160,
panel_dataa1161,
panel_dataa1162,
panel_dataa1163,
panel_dataa1164,
panel_dataa1165,
panel_dataa1166,
panel_dataa1167,
panel_dataa1168,
panel_dataa1169,
panel_dataa1170,
panel_dataa1171,
panel_dataa1172,
panel_dataa1173,
panel_dataa1174,
panel_dataa1175,
panel_dataa1176,
panel_dataa1177,
panel_dataa1178,
panel_dataa1179,
panel_dataa1180,
panel_dataa1181,
panel_dataa1182,
panel_dataa1183,
panel_dataa1184,
panel_dataa1185,
panel_dataa1186,
panel_dataa1187,
panel_dataa1188,
panel_dataa1189,
panel_dataa1190,
panel_dataa1191,
panel_dataa1192,
panel_dataa1193,
panel_dataa1194,
panel_dataa1195,
panel_dataa1196,
panel_dataa1197,
panel_dataa1198,
panel_dataa1199,
panel_dataa1200])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1151_TO_1200_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1151_TO_1200_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1151_TO_1200_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date       High  ...     Volume  Adj Close         SYMBOL
# 0                0  2006-12-20  24.500000  ...  3901755.0  16.961161     RUCHIRA.NS
# 1                1  2006-12-21  23.250000  ...  1917300.0  18.008646     RUCHIRA.NS
# 2                2  2006-12-22  22.700001  ...   360900.0  17.726629     RUCHIRA.NS
# 3                3  2006-12-26  24.200001  ...  1273300.0  18.774111     RUCHIRA.NS
# 4                4  2006-12-27  23.900000  ...   300500.0  18.411526     RUCHIRA.NS
# ...            ...         ...        ...  ...        ...        ...            ...
# 154791      154791  2020-08-10  84.000000  ...  1208379.0  84.000000  CAMLINFINE.NS
# 154792      154792  2020-08-11  88.199997  ...   375698.0  88.199997  CAMLINFINE.NS
# 154793      154793  2020-08-12  92.599998  ...   951943.0  92.599998  CAMLINFINE.NS
# 154794      154794  2020-08-13  97.199997  ...  1586188.0  91.949997  CAMLINFINE.NS
# ...
