# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa401 = data.DataReader('ASHIANA.NS', 'yahoo', start_date, end_date)
panel_dataa402 = data.DataReader('JIYAECO.NS', 'yahoo', start_date, end_date)
panel_dataa403 = data.DataReader('VSTIND.NS', 'yahoo', start_date, end_date)
panel_dataa404 = data.DataReader('LAOPALA.NS', 'yahoo', start_date, end_date)
panel_dataa405 = data.DataReader('VINATIORGA.NS', 'yahoo', start_date, end_date)
panel_dataa406 = data.DataReader('ICIL.NS', 'yahoo', start_date, end_date)
panel_dataa407 = data.DataReader('SANCO.NS', 'yahoo', start_date, end_date)
panel_dataa408 = data.DataReader('INDRAMEDCO.NS', 'yahoo', start_date, end_date)
panel_dataa409 = data.DataReader('NESCO.NS', 'yahoo', start_date, end_date)
panel_dataa410 = data.DataReader('ARMANFIN.NS', 'yahoo', start_date, end_date)
panel_dataa411 = data.DataReader('MANGCHEFER.NS', 'yahoo', start_date, end_date)
panel_dataa412 = data.DataReader('ATFL.NS', 'yahoo', start_date, end_date)
panel_dataa413 = data.DataReader('JKLAKSHMI.NS', 'yahoo', start_date, end_date)
panel_dataa414 = data.DataReader('UNIPLY.NS', 'yahoo', start_date, end_date)
panel_dataa415 = data.DataReader('NAVINFLUOR.NS', 'yahoo', start_date, end_date)
panel_dataa416 = data.DataReader('VOLTAMP.NS', 'yahoo', start_date, end_date)
panel_dataa417 = data.DataReader('DCW.NS', 'yahoo', start_date, end_date)
panel_dataa418 = data.DataReader('INDHOTEL.NS', 'yahoo', start_date, end_date)
panel_dataa419 = data.DataReader('PATELENG.NS', 'yahoo', start_date, end_date)
panel_dataa420 = data.DataReader('CAPACITE.NS', 'yahoo', start_date, end_date)
panel_dataa421 = data.DataReader('ASAL.NS', 'yahoo', start_date, end_date)
panel_dataa422 = data.DataReader('MARKSANS.NS', 'yahoo', start_date, end_date)
panel_dataa423 = data.DataReader('IBREALEST.NS', 'yahoo', start_date, end_date)
panel_dataa424 = data.DataReader('MINDACORP.NS', 'yahoo', start_date, end_date)
panel_dataa425 = data.DataReader('ASTRAL.NS', 'yahoo', start_date, end_date)
panel_dataa426 = data.DataReader('RATNAMANI.NS', 'yahoo', start_date, end_date)
panel_dataa427 = data.DataReader('KAMDHENU.NS', 'yahoo', start_date, end_date)
panel_dataa428 = data.DataReader('SRTRANSFIN.NS', 'yahoo', start_date, end_date)
panel_dataa429 = data.DataReader('ENGINERSIN.NS', 'yahoo', start_date, end_date)
panel_dataa430 = data.DataReader('SHREERAMA.NS', 'yahoo', start_date, end_date)
panel_dataa431 = data.DataReader('IIFL.NS', 'yahoo', start_date, end_date)
panel_dataa432 = data.DataReader('KEC.NS', 'yahoo', start_date, end_date)
panel_dataa433 = data.DataReader('PROZONINTU.NS', 'yahoo', start_date, end_date)
panel_dataa434 = data.DataReader('JAYBARMARU.NS', 'yahoo', start_date, end_date)
panel_dataa435 = data.DataReader('HEIDELBERG.NS', 'yahoo', start_date, end_date)
panel_dataa436 = data.DataReader('MSTCLTD.NS', 'yahoo', start_date, end_date)
panel_dataa437 = data.DataReader('CERA.NS', 'yahoo', start_date, end_date)
panel_dataa438 = data.DataReader('SHAKTIPUMP.NS', 'yahoo', start_date, end_date)
panel_dataa439 = data.DataReader('SOTL.NS', 'yahoo', start_date, end_date)
panel_dataa440 = data.DataReader('OMAXAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa441 = data.DataReader('JETAIRWAYS.NS', 'yahoo', start_date, end_date)
panel_dataa442 = data.DataReader('AARTIDRUGS.NS', 'yahoo', start_date, end_date)
panel_dataa443 = data.DataReader('UNICHEMLAB.NS', 'yahoo', start_date, end_date)
panel_dataa444 = data.DataReader('KHADIM.NS', 'yahoo', start_date, end_date)
panel_dataa445 = data.DataReader('SUTLEJTEX.NS', 'yahoo', start_date, end_date)
panel_dataa446 = data.DataReader('EICHERMOT.NS', 'yahoo', start_date, end_date)
panel_dataa447 = data.DataReader('UNIVCABLES.NS', 'yahoo', start_date, end_date)
panel_dataa448 = data.DataReader('ERIS.NS', 'yahoo', start_date, end_date)
panel_dataa449 = data.DataReader('NIITLTD.NS', 'yahoo', start_date, end_date)
panel_dataa450 = data.DataReader('JUBLINDS.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa401['SYMBOL']='ASHIANA.NS'
panel_dataa402['SYMBOL']='JIYAECO.NS'
panel_dataa403['SYMBOL']='VSTIND.NS'
panel_dataa404['SYMBOL']='LAOPALA.NS'
panel_dataa405['SYMBOL']='VINATIORGA.NS'
panel_dataa406['SYMBOL']='ICIL.NS'
panel_dataa407['SYMBOL']='SANCO.NS'
panel_dataa408['SYMBOL']='INDRAMEDCO.NS'
panel_dataa409['SYMBOL']='NESCO.NS'
panel_dataa410['SYMBOL']='ARMANFIN.NS'
panel_dataa411['SYMBOL']='MANGCHEFER.NS'
panel_dataa412['SYMBOL']='ATFL.NS'
panel_dataa413['SYMBOL']='JKLAKSHMI.NS'
panel_dataa414['SYMBOL']='UNIPLY.NS'
panel_dataa415['SYMBOL']='NAVINFLUOR.NS'
panel_dataa416['SYMBOL']='VOLTAMP.NS'
panel_dataa417['SYMBOL']='DCW.NS'
panel_dataa418['SYMBOL']='INDHOTEL.NS'
panel_dataa419['SYMBOL']='PATELENG.NS'
panel_dataa420['SYMBOL']='CAPACITE.NS'
panel_dataa421['SYMBOL']='ASAL.NS'
panel_dataa422['SYMBOL']='MARKSANS.NS'
panel_dataa423['SYMBOL']='IBREALEST.NS'
panel_dataa424['SYMBOL']='MINDACORP.NS'
panel_dataa425['SYMBOL']='ASTRAL.NS'
panel_dataa426['SYMBOL']='RATNAMANI.NS'
panel_dataa427['SYMBOL']='KAMDHENU.NS'
panel_dataa428['SYMBOL']='SRTRANSFIN.NS'
panel_dataa429['SYMBOL']='ENGINERSIN.NS'
panel_dataa430['SYMBOL']='SHREERAMA.NS'
panel_dataa431['SYMBOL']='IIFL.NS'
panel_dataa432['SYMBOL']='KEC.NS'
panel_dataa433['SYMBOL']='PROZONINTU.NS'
panel_dataa434['SYMBOL']='JAYBARMARU.NS'
panel_dataa435['SYMBOL']='HEIDELBERG.NS'
panel_dataa436['SYMBOL']='MSTCLTD.NS'
panel_dataa437['SYMBOL']='CERA.NS'
panel_dataa438['SYMBOL']='SHAKTIPUMP.NS'
panel_dataa439['SYMBOL']='SOTL.NS'
panel_dataa440['SYMBOL']='OMAXAUTO.NS'
panel_dataa441['SYMBOL']='JETAIRWAYS.NS'
panel_dataa442['SYMBOL']='AARTIDRUGS.NS'
panel_dataa443['SYMBOL']='UNICHEMLAB.NS'
panel_dataa444['SYMBOL']='KHADIM.NS'
panel_dataa445['SYMBOL']='SUTLEJTEX.NS'
panel_dataa446['SYMBOL']='EICHERMOT.NS'
panel_dataa447['SYMBOL']='UNIVCABLES.NS'
panel_dataa448['SYMBOL']='ERIS.NS'
panel_dataa449['SYMBOL']='NIITLTD.NS'
panel_dataa450['SYMBOL']='JUBLINDS.NS'

# %%
finall = pd.concat([panel_dataa401,
panel_dataa402,
panel_dataa403,
panel_dataa404,
panel_dataa405,
panel_dataa406,
panel_dataa407,
panel_dataa408,
panel_dataa409,
panel_dataa410,
panel_dataa411,
panel_dataa412,
panel_dataa413,
panel_dataa414,
panel_dataa415,
panel_dataa416,
panel_dataa417,
panel_dataa418,
panel_dataa419,
panel_dataa420,
panel_dataa421,
panel_dataa422,
panel_dataa423,
panel_dataa424,
panel_dataa425,
panel_dataa426,
panel_dataa427,
panel_dataa428,
panel_dataa429,
panel_dataa430,
panel_dataa431,
panel_dataa432,
panel_dataa433,
panel_dataa434,
panel_dataa435,
panel_dataa436,
panel_dataa437,
panel_dataa438,
panel_dataa439,
panel_dataa440,
panel_dataa441,
panel_dataa442,
panel_dataa443,
panel_dataa444,
panel_dataa445,
panel_dataa446,
panel_dataa447,
panel_dataa448,
panel_dataa449,
panel_dataa450])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_401_TO_450_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_401_TO_450_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_401_TO_450_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...    Volume   Adj Close       SYMBOL
# 0                0  2011-06-29   30.200001  ...  758510.0   22.908348   ASHIANA.NS
# 1                1  2011-06-30   28.330000  ...   34035.0   22.639795   ASHIANA.NS
# 2                2  2011-07-01   29.600000  ...   70425.0   23.901178   ASHIANA.NS
# 3                3  2011-07-04   30.000000  ...   32655.0   23.827936   ASHIANA.NS
# 4                4  2011-07-05   32.560001  ...  271095.0   24.560352   ASHIANA.NS
# ...            ...         ...         ...  ...       ...         ...          ...
# 169686      169686  2020-08-10  144.699997  ...   82232.0  135.699997  JUBLINDS.NS
# 169687      169687  2020-08-11  144.000000  ...   49881.0  138.750000  JUBLINDS.NS
# 169688      169688  2020-08-12  162.000000  ...  180176.0  157.149994  JUBLINDS.NS
# 169689      169689  2020-08-13  187.899994  ...  899625.0  178.600006  JUBLINDS.NS
# ...
