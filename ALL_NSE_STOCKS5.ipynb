# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa201 = data.DataReader('TCIFINANCE.NS', 'yahoo', start_date, end_date)
panel_dataa202 = data.DataReader('DGCONTENT.NS', 'yahoo', start_date, end_date)
panel_dataa203 = data.DataReader('OSWALAGRO.NS', 'yahoo', start_date, end_date)
panel_dataa204 = data.DataReader('FINCABLES.NS', 'yahoo', start_date, end_date)
panel_dataa205 = data.DataReader('BRNL.NS', 'yahoo', start_date, end_date)
panel_dataa206 = data.DataReader('DBREALTY.NS', 'yahoo', start_date, end_date)
panel_dataa207 = data.DataReader('PNCINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa208 = data.DataReader('ADVANIHOTR.NS', 'yahoo', start_date, end_date)
panel_dataa209 = data.DataReader('TIPSINDLTD.NS', 'yahoo', start_date, end_date)
panel_dataa210 = data.DataReader('PPAP.NS', 'yahoo', start_date, end_date)
panel_dataa211 = data.DataReader('POWERMECH.NS', 'yahoo', start_date, end_date)
panel_dataa212 = data.DataReader('ANANTRAJ.NS', 'yahoo', start_date, end_date)
panel_dataa213 = data.DataReader('UFLEX.NS', 'yahoo', start_date, end_date)
panel_dataa214 = data.DataReader('SORILINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa215 = data.DataReader('MSPL.NS', 'yahoo', start_date, end_date)
panel_dataa216 = data.DataReader('DPSCLTD.NS', 'yahoo', start_date, end_date)
panel_dataa217 = data.DataReader('CENTUM.NS', 'yahoo', start_date, end_date)
panel_dataa218 = data.DataReader('PIONDIST.NS', 'yahoo', start_date, end_date)
panel_dataa219 = data.DataReader('SJVN.NS', 'yahoo', start_date, end_date)
panel_dataa220 = data.DataReader('SADBHAV.NS', 'yahoo', start_date, end_date)
panel_dataa221 = data.DataReader('TIJARIA.NS', 'yahoo', start_date, end_date)
panel_dataa222 = data.DataReader('CINELINE.NS', 'yahoo', start_date, end_date)
panel_dataa223 = data.DataReader('GTPL.NS', 'yahoo', start_date, end_date)
panel_dataa224 = data.DataReader('INTENTECH.NS', 'yahoo', start_date, end_date)
panel_dataa225 = data.DataReader('TNPETRO.NS', 'yahoo', start_date, end_date)
panel_dataa226 = data.DataReader('GALAXYSURF.NS', 'yahoo', start_date, end_date)
panel_dataa227 = data.DataReader('JPPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa228 = data.DataReader('URJA.NS', 'yahoo', start_date, end_date)
panel_dataa229 = data.DataReader('NECLIFE.NS', 'yahoo', start_date, end_date)
panel_dataa230 = data.DataReader('ADVENZYMES.NS', 'yahoo', start_date, end_date)
panel_dataa231 = data.DataReader('AMBER.NS', 'yahoo', start_date, end_date)
panel_dataa232 = data.DataReader('CIMMCO.NS', 'yahoo', start_date, end_date)
panel_dataa233 = data.DataReader('NRAIL.NS', 'yahoo', start_date, end_date)
panel_dataa234 = data.DataReader('ZENTEC.NS', 'yahoo', start_date, end_date)
panel_dataa235 = data.DataReader('SHIVAMAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa236 = data.DataReader('WALCHANNAG.NS', 'yahoo', start_date, end_date)
panel_dataa237 = data.DataReader('MIRCELECTR.NS', 'yahoo', start_date, end_date)
panel_dataa238 = data.DataReader('TINPLATE.NS', 'yahoo', start_date, end_date)
panel_dataa239 = data.DataReader('PUNJLLOYD.NS', 'yahoo', start_date, end_date)
panel_dataa240 = data.DataReader('PPL.NS', 'yahoo', start_date, end_date)
panel_dataa241 = data.DataReader('MAHASTEEL.NS', 'yahoo', start_date, end_date)
panel_dataa242 = data.DataReader('MINDTECK.NS', 'yahoo', start_date, end_date)
panel_dataa243 = data.DataReader('GOKULAGRO.NS', 'yahoo', start_date, end_date)
panel_dataa244 = data.DataReader('SUDARSCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa245 = data.DataReader('UTTAMSUGAR.NS', 'yahoo', start_date, end_date)
panel_dataa246 = data.DataReader('ATULAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa247 = data.DataReader('ZEELEARN.NS', 'yahoo', start_date, end_date)
panel_dataa248 = data.DataReader('KAUSHALYA.NS', 'yahoo', start_date, end_date)
panel_dataa249 = data.DataReader('SIMPLEXINF.NS', 'yahoo', start_date, end_date)
panel_dataa250 = data.DataReader('ADHUNIKIND.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa201['SYMBOL']='TCIFINANCE.NS'
panel_dataa202['SYMBOL']='DGCONTENT.NS'
panel_dataa203['SYMBOL']='OSWALAGRO.NS'
panel_dataa204['SYMBOL']='FINCABLES.NS'
panel_dataa205['SYMBOL']='BRNL.NS'
panel_dataa206['SYMBOL']='DBREALTY.NS'
panel_dataa207['SYMBOL']='PNCINFRA.NS'
panel_dataa208['SYMBOL']='ADVANIHOTR.NS'
panel_dataa209['SYMBOL']='TIPSINDLTD.NS'
panel_dataa210['SYMBOL']='PPAP.NS'
panel_dataa211['SYMBOL']='POWERMECH.NS'
panel_dataa212['SYMBOL']='ANANTRAJ.NS'
panel_dataa213['SYMBOL']='UFLEX.NS'
panel_dataa214['SYMBOL']='SORILINFRA.NS'
panel_dataa215['SYMBOL']='MSPL.NS'
panel_dataa216['SYMBOL']='DPSCLTD.NS'
panel_dataa217['SYMBOL']='CENTUM.NS'
panel_dataa218['SYMBOL']='PIONDIST.NS'
panel_dataa219['SYMBOL']='SJVN.NS'
panel_dataa220['SYMBOL']='SADBHAV.NS'
panel_dataa221['SYMBOL']='TIJARIA.NS'
panel_dataa222['SYMBOL']='CINELINE.NS'
panel_dataa223['SYMBOL']='GTPL.NS'
panel_dataa224['SYMBOL']='INTENTECH.NS'
panel_dataa225['SYMBOL']='TNPETRO.NS'
panel_dataa226['SYMBOL']='GALAXYSURF.NS'
panel_dataa227['SYMBOL']='JPPOWER.NS'
panel_dataa228['SYMBOL']='URJA.NS'
panel_dataa229['SYMBOL']='NECLIFE.NS'
panel_dataa230['SYMBOL']='ADVENZYMES.NS'
panel_dataa231['SYMBOL']='AMBER.NS'
panel_dataa232['SYMBOL']='CIMMCO.NS'
panel_dataa233['SYMBOL']='NRAIL.NS'
panel_dataa234['SYMBOL']='ZENTEC.NS'
panel_dataa235['SYMBOL']='SHIVAMAUTO.NS'
panel_dataa236['SYMBOL']='WALCHANNAG.NS'
panel_dataa237['SYMBOL']='MIRCELECTR.NS'
panel_dataa238['SYMBOL']='TINPLATE.NS'
panel_dataa239['SYMBOL']='PUNJLLOYD.NS'
panel_dataa240['SYMBOL']='PPL.NS'
panel_dataa241['SYMBOL']='MAHASTEEL.NS'
panel_dataa242['SYMBOL']='MINDTECK.NS'
panel_dataa243['SYMBOL']='GOKULAGRO.NS'
panel_dataa244['SYMBOL']='SUDARSCHEM.NS'
panel_dataa245['SYMBOL']='UTTAMSUGAR.NS'
panel_dataa246['SYMBOL']='ATULAUTO.NS'
panel_dataa247['SYMBOL']='ZEELEARN.NS'
panel_dataa248['SYMBOL']='KAUSHALYA.NS'
panel_dataa249['SYMBOL']='SIMPLEXINF.NS'
panel_dataa250['SYMBOL']='ADHUNIKIND.NS'

# %%
finall = pd.concat([panel_dataa201,
panel_dataa202,
panel_dataa203,
panel_dataa204,
panel_dataa205,
panel_dataa206,
panel_dataa207,
panel_dataa208,
panel_dataa209,
panel_dataa210,
panel_dataa211,
panel_dataa212,
panel_dataa213,
panel_dataa214,
panel_dataa215,
panel_dataa216,
panel_dataa217,
panel_dataa218,
panel_dataa219,
panel_dataa220,
panel_dataa221,
panel_dataa222,
panel_dataa223,
panel_dataa224,
panel_dataa225,
panel_dataa226,
panel_dataa227,
panel_dataa228,
panel_dataa229,
panel_dataa230,
panel_dataa231,
panel_dataa232,
panel_dataa233,
panel_dataa234,
panel_dataa235,
panel_dataa236,
panel_dataa237,
panel_dataa238,
panel_dataa239,
panel_dataa240,
panel_dataa241,
panel_dataa242,
panel_dataa243,
panel_dataa244,
panel_dataa245,
panel_dataa246,
panel_dataa247,
panel_dataa248,
panel_dataa249,
panel_dataa250])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_201_TO_250_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_201_TO_250_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_201_TO_250_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date       High  ...   Volume  Adj Close         SYMBOL
# 0                0  2003-05-23   4.000000  ...    100.0   4.000000  TCIFINANCE.NS
# 1                1  2003-08-12   4.000000  ...    100.0   4.000000  TCIFINANCE.NS
# 2                2  2003-08-20   4.500000  ...   1900.0   4.500000  TCIFINANCE.NS
# 3                3  2003-08-25   4.200000  ...    400.0   4.150000  TCIFINANCE.NS
# 4                4  2003-08-26   5.000000  ...   1000.0   5.000000  TCIFINANCE.NS
# ...            ...         ...        ...  ...      ...        ...            ...
# 125773      125773  2020-08-10  19.200001  ...   8671.0  18.950001  ADHUNIKIND.NS
# 125774      125774  2020-08-11  19.650000  ...   8933.0  19.299999  ADHUNIKIND.NS
# 125775      125775  2020-08-12  19.850000  ...  18755.0  19.450001  ADHUNIKIND.NS
# 125776      125776  2020-08-13  19.750000  ...  13602.0  19.549999  ADHUNIKIND.NS
# ...
