# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa701 = data.DataReader('CADILAHC.NS', 'yahoo', start_date, end_date)
panel_dataa702 = data.DataReader('CIPLA.NS', 'yahoo', start_date, end_date)
panel_dataa703 = data.DataReader('PFC.NS', 'yahoo', start_date, end_date)
panel_dataa704 = data.DataReader('HINDZINC.NS', 'yahoo', start_date, end_date)
panel_dataa705 = data.DataReader('VISAKAIND.NS', 'yahoo', start_date, end_date)
panel_dataa706 = data.DataReader('PNB.NS', 'yahoo', start_date, end_date)
panel_dataa707 = data.DataReader('TCS.NS', 'yahoo', start_date, end_date)
panel_dataa708 = data.DataReader('HIKAL.NS', 'yahoo', start_date, end_date)
panel_dataa709 = data.DataReader('HINDCOPPER.NS', 'yahoo', start_date, end_date)
panel_dataa710 = data.DataReader('SARDAEN.NS', 'yahoo', start_date, end_date)
panel_dataa711 = data.DataReader('WABAG.NS', 'yahoo', start_date, end_date)
panel_dataa712 = data.DataReader('ITDC.NS', 'yahoo', start_date, end_date)
panel_dataa713 = data.DataReader('MAHEPC.NS', 'yahoo', start_date, end_date)
panel_dataa714 = data.DataReader('PCJEWELLER.NS', 'yahoo', start_date, end_date)
panel_dataa715 = data.DataReader('PRABHAT.NS', 'yahoo', start_date, end_date)
panel_dataa716 = data.DataReader('NIITTECH.NS', 'yahoo', start_date, end_date)
panel_dataa717 = data.DataReader('POLYMED.NS', 'yahoo', start_date, end_date)
panel_dataa718 = data.DataReader('GILLETTE.NS', 'yahoo', start_date, end_date)
panel_dataa719 = data.DataReader('GRANULES.NS', 'yahoo', start_date, end_date)
panel_dataa720 = data.DataReader('ITDCEM.NS', 'yahoo', start_date, end_date)
panel_dataa721 = data.DataReader('MUNJALAU.NS', 'yahoo', start_date, end_date)
panel_dataa722 = data.DataReader('EVERESTIND.NS', 'yahoo', start_date, end_date)
panel_dataa723 = data.DataReader('GODREJPROP.NS', 'yahoo', start_date, end_date)
panel_dataa724 = data.DataReader('BFUTILITIE.NS', 'yahoo', start_date, end_date)
panel_dataa725 = data.DataReader('PEL.NS', 'yahoo', start_date, end_date)
panel_dataa726 = data.DataReader('SOMANYCERA.NS', 'yahoo', start_date, end_date)
panel_dataa727 = data.DataReader('TATAMTRDVR.NS', 'yahoo', start_date, end_date)
panel_dataa728 = data.DataReader('WSTCSTPAPR.NS', 'yahoo', start_date, end_date)
panel_dataa729 = data.DataReader('APLAPOLLO.NS', 'yahoo', start_date, end_date)
panel_dataa730 = data.DataReader('CONCOR.NS', 'yahoo', start_date, end_date)
panel_dataa731 = data.DataReader('ASTRAZEN.NS', 'yahoo', start_date, end_date)
panel_dataa732 = data.DataReader('SUNPHARMA.NS', 'yahoo', start_date, end_date)
panel_dataa733 = data.DataReader('JSL.NS', 'yahoo', start_date, end_date)
panel_dataa734 = data.DataReader('MONTECARLO.NS', 'yahoo', start_date, end_date)
panel_dataa735 = data.DataReader('ZODIACLOTH.NS', 'yahoo', start_date, end_date)
panel_dataa736 = data.DataReader('LINCOLN.NS', 'yahoo', start_date, end_date)
panel_dataa737 = data.DataReader('BAJAJ-AUTO.NS', 'yahoo', start_date, end_date)
panel_dataa738 = data.DataReader('JYOTHYLAB.NS', 'yahoo', start_date, end_date)
panel_dataa739 = data.DataReader('ALKEM.NS', 'yahoo', start_date, end_date)
panel_dataa740 = data.DataReader('ALEMBICLTD.NS', 'yahoo', start_date, end_date)
panel_dataa741 = data.DataReader('LOVABLE.NS', 'yahoo', start_date, end_date)
panel_dataa742 = data.DataReader('BASF.NS', 'yahoo', start_date, end_date)
panel_dataa743 = data.DataReader('ASTRAMICRO.NS', 'yahoo', start_date, end_date)
panel_dataa744 = data.DataReader('DCBBANK.NS', 'yahoo', start_date, end_date)
panel_dataa745 = data.DataReader('RAYMOND.NS', 'yahoo', start_date, end_date)
panel_dataa746 = data.DataReader('BLUESTARCO.NS', 'yahoo', start_date, end_date)
panel_dataa747 = data.DataReader('BEPL.NS', 'yahoo', start_date, end_date)
panel_dataa748 = data.DataReader('GLOBALVECT.NS', 'yahoo', start_date, end_date)
panel_dataa749 = data.DataReader('BAJAJHIND.NS', 'yahoo', start_date, end_date)
panel_dataa750 = data.DataReader('BAJAJFINSV.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa701['SYMBOL']='CADILAHC.NS'
panel_dataa702['SYMBOL']='CIPLA.NS'
panel_dataa703['SYMBOL']='PFC.NS'
panel_dataa704['SYMBOL']='HINDZINC.NS'
panel_dataa705['SYMBOL']='VISAKAIND.NS'
panel_dataa706['SYMBOL']='PNB.NS'
panel_dataa707['SYMBOL']='TCS.NS'
panel_dataa708['SYMBOL']='HIKAL.NS'
panel_dataa709['SYMBOL']='HINDCOPPER.NS'
panel_dataa710['SYMBOL']='SARDAEN.NS'
panel_dataa711['SYMBOL']='WABAG.NS'
panel_dataa712['SYMBOL']='ITDC.NS'
panel_dataa713['SYMBOL']='MAHEPC.NS'
panel_dataa714['SYMBOL']='PCJEWELLER.NS'
panel_dataa715['SYMBOL']='PRABHAT.NS'
panel_dataa716['SYMBOL']='NIITTECH.NS'
panel_dataa717['SYMBOL']='POLYMED.NS'
panel_dataa718['SYMBOL']='GILLETTE.NS'
panel_dataa719['SYMBOL']='GRANULES.NS'
panel_dataa720['SYMBOL']='ITDCEM.NS'
panel_dataa721['SYMBOL']='MUNJALAU.NS'
panel_dataa722['SYMBOL']='EVERESTIND.NS'
panel_dataa723['SYMBOL']='GODREJPROP.NS'
panel_dataa724['SYMBOL']='BFUTILITIE.NS'
panel_dataa725['SYMBOL']='PEL.NS'
panel_dataa726['SYMBOL']='SOMANYCERA.NS'
panel_dataa727['SYMBOL']='TATAMTRDVR.NS'
panel_dataa728['SYMBOL']='WSTCSTPAPR.NS'
panel_dataa729['SYMBOL']='APLAPOLLO.NS'
panel_dataa730['SYMBOL']='CONCOR.NS'
panel_dataa731['SYMBOL']='ASTRAZEN.NS'
panel_dataa732['SYMBOL']='SUNPHARMA.NS'
panel_dataa733['SYMBOL']='JSL.NS'
panel_dataa734['SYMBOL']='MONTECARLO.NS'
panel_dataa735['SYMBOL']='ZODIACLOTH.NS'
panel_dataa736['SYMBOL']='LINCOLN.NS'
panel_dataa737['SYMBOL']='BAJAJ-AUTO.NS'
panel_dataa738['SYMBOL']='JYOTHYLAB.NS'
panel_dataa739['SYMBOL']='ALKEM.NS'
panel_dataa740['SYMBOL']='ALEMBICLTD.NS'
panel_dataa741['SYMBOL']='LOVABLE.NS'
panel_dataa742['SYMBOL']='BASF.NS'
panel_dataa743['SYMBOL']='ASTRAMICRO.NS'
panel_dataa744['SYMBOL']='DCBBANK.NS'
panel_dataa745['SYMBOL']='RAYMOND.NS'
panel_dataa746['SYMBOL']='BLUESTARCO.NS'
panel_dataa747['SYMBOL']='BEPL.NS'
panel_dataa748['SYMBOL']='GLOBALVECT.NS'
panel_dataa749['SYMBOL']='BAJAJHIND.NS'
panel_dataa750['SYMBOL']='BAJAJFINSV.NS'

# %%
finall = pd.concat([panel_dataa701,
panel_dataa702,
panel_dataa703,
panel_dataa704,
panel_dataa705,
panel_dataa706,
panel_dataa707,
panel_dataa708,
panel_dataa709,
panel_dataa710,
panel_dataa711,
panel_dataa712,
panel_dataa713,
panel_dataa714,
panel_dataa715,
panel_dataa716,
panel_dataa717,
panel_dataa718,
panel_dataa719,
panel_dataa720,
panel_dataa721,
panel_dataa722,
panel_dataa723,
panel_dataa724,
panel_dataa725,
panel_dataa726,
panel_dataa727,
panel_dataa728,
panel_dataa729,
panel_dataa730,
panel_dataa731,
panel_dataa732,
panel_dataa733,
panel_dataa734,
panel_dataa735,
panel_dataa736,
panel_dataa737,
panel_dataa738,
panel_dataa739,
panel_dataa740,
panel_dataa741,
panel_dataa742,
panel_dataa743,
panel_dataa744,
panel_dataa745,
panel_dataa746,
panel_dataa747,
panel_dataa748,
panel_dataa749,
panel_dataa750])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_701_TO_750_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_701_TO_750_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_701_TO_750_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  ...    Adj Close         SYMBOL
# 0                0  2002-07-01  ...     1.899885    CADILAHC.NS
# 1                1  2002-07-02  ...     1.914079    CADILAHC.NS
# 2                2  2002-07-03  ...     1.928838    CADILAHC.NS
# 3                3  2002-07-04  ...     1.941045    CADILAHC.NS
# 4                4  2002-07-05  ...     1.933097    CADILAHC.NS
# ...            ...         ...  ...          ...            ...
# 175495      175495  2020-08-10  ...  6402.799805  BAJAJFINSV.NS
# 175496      175496  2020-08-11  ...  6440.350098  BAJAJFINSV.NS
# 175497      175497  2020-08-12  ...  6357.200195  BAJAJFINSV.NS
# 175498      175498  2020-08-13  ...  6350.000000  BAJAJFINSV.NS
# 175499      175499  2020-08-14  ...  6246.700195  BAJAJFINSV.NS
#
# [175500 rows x 9 columns]
