# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa651 = data.DataReader('IIFLSEC.NS', 'yahoo', start_date, end_date)
panel_dataa652 = data.DataReader('GABRIEL.NS', 'yahoo', start_date, end_date)
panel_dataa653 = data.DataReader('NAGAFERT.NS', 'yahoo', start_date, end_date)
panel_dataa654 = data.DataReader('REDINGTON.NS', 'yahoo', start_date, end_date)
panel_dataa655 = data.DataReader('LUPIN.NS', 'yahoo', start_date, end_date)
panel_dataa656 = data.DataReader('TATAPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa657 = data.DataReader('GMBREW.NS', 'yahoo', start_date, end_date)
panel_dataa658 = data.DataReader('NETWORK18.NS', 'yahoo', start_date, end_date)
panel_dataa659 = data.DataReader('SBIN.NS', 'yahoo', start_date, end_date)
panel_dataa660 = data.DataReader('TRITURBINE.NS', 'yahoo', start_date, end_date)
panel_dataa661 = data.DataReader('TALBROAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa662 = data.DataReader('REPCOHOME.NS', 'yahoo', start_date, end_date)
panel_dataa663 = data.DataReader('IBVENTURES.NS', 'yahoo', start_date, end_date)
panel_dataa664 = data.DataReader('SHRIRAMCIT.NS', 'yahoo', start_date, end_date)
panel_dataa665 = data.DataReader('MINDAIND.NS', 'yahoo', start_date, end_date)
panel_dataa666 = data.DataReader('RICOAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa667 = data.DataReader('IOLCP.NS', 'yahoo', start_date, end_date)
panel_dataa668 = data.DataReader('DIVISLAB.NS', 'yahoo', start_date, end_date)
panel_dataa669 = data.DataReader('CLEDUCATE.NS', 'yahoo', start_date, end_date)
panel_dataa670 = data.DataReader('LUXIND.NS', 'yahoo', start_date, end_date)
panel_dataa671 = data.DataReader('SIEMENS.NS', 'yahoo', start_date, end_date)
panel_dataa672 = data.DataReader('INOXLEISUR.NS', 'yahoo', start_date, end_date)
panel_dataa673 = data.DataReader('SUNFLAG.NS', 'yahoo', start_date, end_date)
panel_dataa674 = data.DataReader('PUNJABCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa675 = data.DataReader('ASIANPAINT.NS', 'yahoo', start_date, end_date)
panel_dataa676 = data.DataReader('UJJIVAN.NS', 'yahoo', start_date, end_date)
panel_dataa677 = data.DataReader('KOTAKBANK.NS', 'yahoo', start_date, end_date)
panel_dataa678 = data.DataReader('IOB.NS', 'yahoo', start_date, end_date)
panel_dataa679 = data.DataReader('KRBL.NS', 'yahoo', start_date, end_date)
panel_dataa680 = data.DataReader('RUPA.NS', 'yahoo', start_date, end_date)
panel_dataa681 = data.DataReader('GEPIL.NS', 'yahoo', start_date, end_date)
panel_dataa682 = data.DataReader('OIL.NS', 'yahoo', start_date, end_date)
panel_dataa683 = data.DataReader('KIRIINDUS.NS', 'yahoo', start_date, end_date)
panel_dataa684 = data.DataReader('MAYURUNIQ.NS', 'yahoo', start_date, end_date)
panel_dataa685 = data.DataReader('MHRIL.NS', 'yahoo', start_date, end_date)
panel_dataa686 = data.DataReader('DOLLAR.NS', 'yahoo', start_date, end_date)
panel_dataa687 = data.DataReader('FINEORG.NS', 'yahoo', start_date, end_date)
panel_dataa688 = data.DataReader('FEDERALBNK.NS', 'yahoo', start_date, end_date)
panel_dataa689 = data.DataReader('DAAWAT.NS', 'yahoo', start_date, end_date)
panel_dataa690 = data.DataReader('TATACOFFEE.NS', 'yahoo', start_date, end_date)
panel_dataa691 = data.DataReader('KALPATPOWR.NS', 'yahoo', start_date, end_date)
panel_dataa692 = data.DataReader('CHENNPETRO.NS', 'yahoo', start_date, end_date)
panel_dataa693 = data.DataReader('JUBLFOOD.NS', 'yahoo', start_date, end_date)
panel_dataa694 = data.DataReader('KTKBANK.NS', 'yahoo', start_date, end_date)
panel_dataa695 = data.DataReader('OMAXE.NS', 'yahoo', start_date, end_date)
panel_dataa696 = data.DataReader('RELCAPITAL.NS', 'yahoo', start_date, end_date)
panel_dataa697 = data.DataReader('JINDALSAW.NS', 'yahoo', start_date, end_date)
panel_dataa698 = data.DataReader('MAHLIFE.NS', 'yahoo', start_date, end_date)
panel_dataa699 = data.DataReader('CANFINHOME.NS', 'yahoo', start_date, end_date)
panel_dataa700 = data.DataReader('BIOCON.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa651['SYMBOL']='IIFLSEC.NS'
panel_dataa652['SYMBOL']='GABRIEL.NS'
panel_dataa653['SYMBOL']='NAGAFERT.NS'
panel_dataa654['SYMBOL']='REDINGTON.NS'
panel_dataa655['SYMBOL']='LUPIN.NS'
panel_dataa656['SYMBOL']='TATAPOWER.NS'
panel_dataa657['SYMBOL']='GMBREW.NS'
panel_dataa658['SYMBOL']='NETWORK18.NS'
panel_dataa659['SYMBOL']='SBIN.NS'
panel_dataa660['SYMBOL']='TRITURBINE.NS'
panel_dataa661['SYMBOL']='TALBROAUTO.NS'
panel_dataa662['SYMBOL']='REPCOHOME.NS'
panel_dataa663['SYMBOL']='IBVENTURES.NS'
panel_dataa664['SYMBOL']='SHRIRAMCIT.NS'
panel_dataa665['SYMBOL']='MINDAIND.NS'
panel_dataa666['SYMBOL']='RICOAUTO.NS'
panel_dataa667['SYMBOL']='IOLCP.NS'
panel_dataa668['SYMBOL']='DIVISLAB.NS'
panel_dataa669['SYMBOL']='CLEDUCATE.NS'
panel_dataa670['SYMBOL']='LUXIND.NS'
panel_dataa671['SYMBOL']='SIEMENS.NS'
panel_dataa672['SYMBOL']='INOXLEISUR.NS'
panel_dataa673['SYMBOL']='SUNFLAG.NS'
panel_dataa674['SYMBOL']='PUNJABCHEM.NS'
panel_dataa675['SYMBOL']='ASIANPAINT.NS'
panel_dataa676['SYMBOL']='UJJIVAN.NS'
panel_dataa677['SYMBOL']='KOTAKBANK.NS'
panel_dataa678['SYMBOL']='IOB.NS'
panel_dataa679['SYMBOL']='KRBL.NS'
panel_dataa680['SYMBOL']='RUPA.NS'
panel_dataa681['SYMBOL']='GEPIL.NS'
panel_dataa682['SYMBOL']='OIL.NS'
panel_dataa683['SYMBOL']='KIRIINDUS.NS'
panel_dataa684['SYMBOL']='MAYURUNIQ.NS'
panel_dataa685['SYMBOL']='MHRIL.NS'
panel_dataa686['SYMBOL']='DOLLAR.NS'
panel_dataa687['SYMBOL']='FINEORG.NS'
panel_dataa688['SYMBOL']='FEDERALBNK.NS'
panel_dataa689['SYMBOL']='DAAWAT.NS'
panel_dataa690['SYMBOL']='TATACOFFEE.NS'
panel_dataa691['SYMBOL']='KALPATPOWR.NS'
panel_dataa692['SYMBOL']='CHENNPETRO.NS'
panel_dataa693['SYMBOL']='JUBLFOOD.NS'
panel_dataa694['SYMBOL']='KTKBANK.NS'
panel_dataa695['SYMBOL']='OMAXE.NS'
panel_dataa696['SYMBOL']='RELCAPITAL.NS'
panel_dataa697['SYMBOL']='JINDALSAW.NS'
panel_dataa698['SYMBOL']='MAHLIFE.NS'
panel_dataa699['SYMBOL']='CANFINHOME.NS'
panel_dataa700['SYMBOL']='BIOCON.NS'

# %%
finall = pd.concat([panel_dataa651,
panel_dataa652,
panel_dataa653,
panel_dataa654,
panel_dataa655,
panel_dataa656,
panel_dataa657,
panel_dataa658,
panel_dataa659,
panel_dataa660,
panel_dataa661,
panel_dataa662,
panel_dataa663,
panel_dataa664,
panel_dataa665,
panel_dataa666,
panel_dataa667,
panel_dataa668,
panel_dataa669,
panel_dataa670,
panel_dataa671,
panel_dataa672,
panel_dataa673,
panel_dataa674,
panel_dataa675,
panel_dataa676,
panel_dataa677,
panel_dataa678,
panel_dataa679,
panel_dataa680,
panel_dataa681,
panel_dataa682,
panel_dataa683,
panel_dataa684,
panel_dataa685,
panel_dataa686,
panel_dataa687,
panel_dataa688,
panel_dataa689,
panel_dataa690,
panel_dataa691,
panel_dataa692,
panel_dataa693,
panel_dataa694,
panel_dataa695,
panel_dataa696,
panel_dataa697,
panel_dataa698,
panel_dataa699,
panel_dataa700])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_651_TO_700_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_651_TO_700_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_651_TO_700_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...     Volume   Adj Close      SYMBOL
# 0                0  2019-09-20   23.100000  ...    73482.0   22.314953  IIFLSEC.NS
# 1                1  2019-09-23   24.250000  ...    20530.0   23.425871  IIFLSEC.NS
# 2                2  2019-09-24   25.450001  ...    11034.0   24.585089  IIFLSEC.NS
# 3                3  2019-09-25   26.700001  ...   272034.0   25.792608  IIFLSEC.NS
# 4                4  2019-09-26   28.000000  ...   141567.0   27.048428  IIFLSEC.NS
# ...            ...         ...         ...  ...        ...         ...         ...
# 176012      176012  2020-08-10  414.500000  ...  7027651.0  412.450012   BIOCON.NS
# 176013      176013  2020-08-11  417.000000  ...  5384749.0  407.549988   BIOCON.NS
# 176014      176014  2020-08-12  407.799988  ...  5536052.0  396.600006   BIOCON.NS
# 176015      176015  2020-08-13  401.100006  ...  4016926.0  393.250000   BIOCON.NS
# ...
