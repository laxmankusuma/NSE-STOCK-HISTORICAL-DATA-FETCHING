# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa951 = data.DataReader('DEVIT.NS', 'yahoo', start_date, end_date)
panel_dataa952 = data.DataReader('MOIL.NS', 'yahoo', start_date, end_date)
panel_dataa953 = data.DataReader('BHARTIARTL.NS', 'yahoo', start_date, end_date)
panel_dataa954 = data.DataReader('EXIDEIND.NS', 'yahoo', start_date, end_date)
panel_dataa955 = data.DataReader('MFSL.NS', 'yahoo', start_date, end_date)
panel_dataa956 = data.DataReader('PVR.NS', 'yahoo', start_date, end_date)
panel_dataa957 = data.DataReader('KSL.NS', 'yahoo', start_date, end_date)
panel_dataa958 = data.DataReader('AKSHARCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa959 = data.DataReader('APEX.NS', 'yahoo', start_date, end_date)
panel_dataa960 = data.DataReader('SRF.NS', 'yahoo', start_date, end_date)
panel_dataa961 = data.DataReader('SANOFI.NS', 'yahoo', start_date, end_date)
panel_dataa962 = data.DataReader('SURYAROSNI.NS', 'yahoo', start_date, end_date)
panel_dataa963 = data.DataReader('POWERGRID.NS', 'yahoo', start_date, end_date)
panel_dataa964 = data.DataReader('UNIONBANK.NS', 'yahoo', start_date, end_date)
panel_dataa965 = data.DataReader('TCI.NS', 'yahoo', start_date, end_date)
panel_dataa966 = data.DataReader('MASTEK.NS', 'yahoo', start_date, end_date)
panel_dataa967 = data.DataReader('BAYERCROP.NS', 'yahoo', start_date, end_date)
panel_dataa968 = data.DataReader('LIBERTSHOE.NS', 'yahoo', start_date, end_date)
panel_dataa969 = data.DataReader('MOTILALOFS.NS', 'yahoo', start_date, end_date)
panel_dataa970 = data.DataReader('GMMPFAUDLR.NS', 'yahoo', start_date, end_date)
panel_dataa971 = data.DataReader('HINDUNILVR.NS', 'yahoo', start_date, end_date)
panel_dataa972 = data.DataReader('LTTS.NS', 'yahoo', start_date, end_date)
panel_dataa973 = data.DataReader('AFFLE.NS', 'yahoo', start_date, end_date)
panel_dataa974 = data.DataReader('ADANIGREEN.NS', 'yahoo', start_date, end_date)
panel_dataa975 = data.DataReader('HEROMOTOCO.NS', 'yahoo', start_date, end_date)
panel_dataa976 = data.DataReader('PFIZER.NS', 'yahoo', start_date, end_date)
panel_dataa977 = data.DataReader('RELAXO.NS', 'yahoo', start_date, end_date)
panel_dataa978 = data.DataReader('PIIND.NS', 'yahoo', start_date, end_date)
panel_dataa979 = data.DataReader('NELCAST.NS', 'yahoo', start_date, end_date)
panel_dataa980 = data.DataReader('CCL.NS', 'yahoo', start_date, end_date)
panel_dataa981 = data.DataReader('TORNTPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa982 = data.DataReader('AIAENG.NS', 'yahoo', start_date, end_date)
panel_dataa983 = data.DataReader('NATIONALUM.NS', 'yahoo', start_date, end_date)
panel_dataa984 = data.DataReader('RML.NS', 'yahoo', start_date, end_date)
panel_dataa985 = data.DataReader('HCLTECH.NS', 'yahoo', start_date, end_date)
panel_dataa986 = data.DataReader('BALKRISIND.NS', 'yahoo', start_date, end_date)
panel_dataa987 = data.DataReader('EVEREADY.NS', 'yahoo', start_date, end_date)
panel_dataa988 = data.DataReader('GET&D.NS', 'yahoo', start_date, end_date)
panel_dataa989 = data.DataReader('ALANKIT.NS', 'yahoo', start_date, end_date)
panel_dataa990 = data.DataReader('RADIOCITY.NS', 'yahoo', start_date, end_date)
panel_dataa991 = data.DataReader('MINDTREE.NS', 'yahoo', start_date, end_date)
panel_dataa992 = data.DataReader('TRIVENI.NS', 'yahoo', start_date, end_date)
panel_dataa993 = data.DataReader('GLAXO.NS', 'yahoo', start_date, end_date)
panel_dataa994 = data.DataReader('BORORENEW.NS', 'yahoo', start_date, end_date)
panel_dataa995 = data.DataReader('MADRASFERT.NS', 'yahoo', start_date, end_date)
panel_dataa996 = data.DataReader('SBICARD.NS', 'yahoo', start_date, end_date)
panel_dataa997 = data.DataReader('PRINCEPIPE.NS', 'yahoo', start_date, end_date)
panel_dataa998 = data.DataReader('GREAVESCOT.NS', 'yahoo', start_date, end_date)
panel_dataa999 = data.DataReader('BUTTERFLY.NS', 'yahoo', start_date, end_date)
panel_dataa1000 = data.DataReader('CARBORUNIV.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa951['SYMBOL']='DEVIT.NS'
panel_dataa952['SYMBOL']='MOIL.NS'
panel_dataa953['SYMBOL']='BHARTIARTL.NS'
panel_dataa954['SYMBOL']='EXIDEIND.NS'
panel_dataa955['SYMBOL']='MFSL.NS'
panel_dataa956['SYMBOL']='PVR.NS'
panel_dataa957['SYMBOL']='KSL.NS'
panel_dataa958['SYMBOL']='AKSHARCHEM.NS'
panel_dataa959['SYMBOL']='APEX.NS'
panel_dataa960['SYMBOL']='SRF.NS'
panel_dataa961['SYMBOL']='SANOFI.NS'
panel_dataa962['SYMBOL']='SURYAROSNI.NS'
panel_dataa963['SYMBOL']='POWERGRID.NS'
panel_dataa964['SYMBOL']='UNIONBANK.NS'
panel_dataa965['SYMBOL']='TCI.NS'
panel_dataa966['SYMBOL']='MASTEK.NS'
panel_dataa967['SYMBOL']='BAYERCROP.NS'
panel_dataa968['SYMBOL']='LIBERTSHOE.NS'
panel_dataa969['SYMBOL']='MOTILALOFS.NS'
panel_dataa970['SYMBOL']='GMMPFAUDLR.NS'
panel_dataa971['SYMBOL']='HINDUNILVR.NS'
panel_dataa972['SYMBOL']='LTTS.NS'
panel_dataa973['SYMBOL']='AFFLE.NS'
panel_dataa974['SYMBOL']='ADANIGREEN.NS'
panel_dataa975['SYMBOL']='HEROMOTOCO.NS'
panel_dataa976['SYMBOL']='PFIZER.NS'
panel_dataa977['SYMBOL']='RELAXO.NS'
panel_dataa978['SYMBOL']='PIIND.NS'
panel_dataa979['SYMBOL']='NELCAST.NS'
panel_dataa980['SYMBOL']='CCL.NS'
panel_dataa981['SYMBOL']='TORNTPOWER.NS'
panel_dataa982['SYMBOL']='AIAENG.NS'
panel_dataa983['SYMBOL']='NATIONALUM.NS'
panel_dataa984['SYMBOL']='RML.NS'
panel_dataa985['SYMBOL']='HCLTECH.NS'
panel_dataa986['SYMBOL']='BALKRISIND.NS'
panel_dataa987['SYMBOL']='EVEREADY.NS'
panel_dataa988['SYMBOL']='GET&D.NS'
panel_dataa989['SYMBOL']='ALANKIT.NS'
panel_dataa990['SYMBOL']='RADIOCITY.NS'
panel_dataa991['SYMBOL']='MINDTREE.NS'
panel_dataa992['SYMBOL']='TRIVENI.NS'
panel_dataa993['SYMBOL']='GLAXO.NS'
panel_dataa994['SYMBOL']='BORORENEW.NS'
panel_dataa995['SYMBOL']='MADRASFERT.NS'
panel_dataa996['SYMBOL']='SBICARD.NS'
panel_dataa997['SYMBOL']='PRINCEPIPE.NS'
panel_dataa998['SYMBOL']='GREAVESCOT.NS'
panel_dataa999['SYMBOL']='BUTTERFLY.NS'
panel_dataa1000['SYMBOL']='CARBORUNIV.NS'

# %%
finall = pd.concat([panel_dataa951,
panel_dataa952,
panel_dataa953,
panel_dataa954,
panel_dataa955,
panel_dataa956,
panel_dataa957,
panel_dataa958,
panel_dataa959,
panel_dataa960,
panel_dataa961,
panel_dataa962,
panel_dataa963,
panel_dataa964,
panel_dataa965,
panel_dataa966,
panel_dataa967,
panel_dataa968,
panel_dataa969,
panel_dataa970,
panel_dataa971,
panel_dataa972,
panel_dataa973,
panel_dataa974,
panel_dataa975,
panel_dataa976,
panel_dataa977,
panel_dataa978,
panel_dataa979,
panel_dataa980,
panel_dataa981,
panel_dataa982,
panel_dataa983,
panel_dataa984,
panel_dataa985,
panel_dataa986,
panel_dataa987,
panel_dataa988,
panel_dataa989,
panel_dataa990,
panel_dataa991,
panel_dataa992,
panel_dataa993,
panel_dataa994,
panel_dataa995,
panel_dataa996,
panel_dataa997,
panel_dataa998,
panel_dataa999,
panel_dataa1000])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_951_TO_1000_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_951_TO_1000_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_951_TO_1000_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  ...   Adj Close         SYMBOL
# 0                0  2017-07-27  ...   52.378319       DEVIT.NS
# 1                1  2017-07-28  ...   50.616055       DEVIT.NS
# 2                2  2017-07-31  ...   49.832829       DEVIT.NS
# 3                3  2017-08-01  ...   47.727905       DEVIT.NS
# 4                4  2017-08-02  ...   52.378319       DEVIT.NS
# ...            ...         ...  ...         ...            ...
# 155207      155207  2020-08-10  ...  248.000000  CARBORUNIV.NS
# 155208      155208  2020-08-11  ...  251.949997  CARBORUNIV.NS
# 155209      155209  2020-08-12  ...  254.050003  CARBORUNIV.NS
# 155210      155210  2020-08-13  ...  257.200012  CARBORUNIV.NS
# 155211      155211  2020-08-14  ...  253.399994  CARBORUNIV.NS
#
# [155212 rows x 9 columns]
