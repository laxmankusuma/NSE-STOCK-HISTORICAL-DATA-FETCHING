# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

panel_dataa51 = data.DataReader('BANSWRAS.NS', 'yahoo', start_date, end_date)
panel_dataa52 = data.DataReader('V2RETAIL.NS', 'yahoo', start_date, end_date)
panel_dataa53 = data.DataReader('HIRECT.NS', 'yahoo', start_date, end_date)
panel_dataa54 = data.DataReader('SHARDAMOTR.NS', 'yahoo', start_date, end_date)
panel_dataa55 = data.DataReader('REMSONSIND.NS', 'yahoo', start_date, end_date)
panel_dataa56 = data.DataReader('BSL.NS', 'yahoo', start_date, end_date)
panel_dataa57 = data.DataReader('EIHOTEL.NS', 'yahoo', start_date, end_date)
panel_dataa58 = data.DataReader('HILTON.NS', 'yahoo', start_date, end_date)
panel_dataa59 = data.DataReader('JAYNECOIND.NS', 'yahoo', start_date, end_date)
panel_dataa60 = data.DataReader('INDSWFTLTD.NS', 'yahoo', start_date, end_date)
panel_dataa61 = data.DataReader('SURANASOL.NS', 'yahoo', start_date, end_date)
panel_dataa62 = data.DataReader('MANGALAM.NS', 'yahoo', start_date, end_date)
panel_dataa63 = data.DataReader('AARTISURF.NS', 'yahoo', start_date, end_date)
panel_dataa64 = data.DataReader('WELINV.NS', 'yahoo', start_date, end_date)
panel_dataa65 = data.DataReader('KALYANIFRG.NS', 'yahoo', start_date, end_date)
panel_dataa66 = data.DataReader('DYNAMATECH.NS', 'yahoo', start_date, end_date)
panel_dataa67 = data.DataReader('INDSWFTLAB.NS', 'yahoo', start_date, end_date)
panel_dataa68 = data.DataReader('KOHINOOR.NS', 'yahoo', start_date, end_date)
panel_dataa69 = data.DataReader('NITCO.NS', 'yahoo', start_date, end_date)
panel_dataa70 = data.DataReader('THOMASCOOK.NS', 'yahoo', start_date, end_date)
panel_dataa71 = data.DataReader('INFOBEAN.NS', 'yahoo', start_date, end_date)
panel_dataa72 = data.DataReader('BANG.NS', 'yahoo', start_date, end_date)
panel_dataa73 = data.DataReader('AURIONPRO.NS', 'yahoo', start_date, end_date)
panel_dataa74 = data.DataReader('JINDRILL.NS', 'yahoo', start_date, end_date)
panel_dataa75 = data.DataReader('OPTIEMUS.NS', 'yahoo', start_date, end_date)
panel_dataa76 = data.DataReader('HEXATRADEX.NS', 'yahoo', start_date, end_date)
panel_dataa77 = data.DataReader('MUKTAARTS.NS', 'yahoo', start_date, end_date)
panel_dataa78 = data.DataReader('GINNIFILA.NS', 'yahoo', start_date, end_date)
panel_dataa79 = data.DataReader('TARMAT.NS', 'yahoo', start_date, end_date)
panel_dataa80 = data.DataReader('BEDMUTHA.NS', 'yahoo', start_date, end_date)
panel_dataa81 = data.DataReader('KARDA.NS', 'yahoo', start_date, end_date)
panel_dataa82 = data.DataReader('CHEMBOND.NS', 'yahoo', start_date, end_date)
panel_dataa83 = data.DataReader('CGPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa84 = data.DataReader('KDDL.NS', 'yahoo', start_date, end_date)
panel_dataa85 = data.DataReader('SUPREMEINF.NS', 'yahoo', start_date, end_date)
panel_dataa86 = data.DataReader('BIOFILCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa87 = data.DataReader('RTNINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa88 = data.DataReader('VIKASMCORP.NS', 'yahoo', start_date, end_date)
panel_dataa89 = data.DataReader('SOMATEX.NS', 'yahoo', start_date, end_date)
panel_dataa90 = data.DataReader('INDORAMA.NS', 'yahoo', start_date, end_date)
panel_dataa91 = data.DataReader('VIKASECO.NS', 'yahoo', start_date, end_date)
panel_dataa92 = data.DataReader('VASWANI.NS', 'yahoo', start_date, end_date)
panel_dataa93 = data.DataReader('ELGIRUBCO.NS', 'yahoo', start_date, end_date)
panel_dataa94 = data.DataReader('GPIL.NS', 'yahoo', start_date, end_date)
panel_dataa95 = data.DataReader('COFFEEDAY.NS', 'yahoo', start_date, end_date)
panel_dataa96 = data.DataReader('VIVIMEDLAB.NS', 'yahoo', start_date, end_date)
panel_dataa97 = data.DataReader('MCLEODRUSS.NS', 'yahoo', start_date, end_date)
panel_dataa98 = data.DataReader('VIPCLOTHNG.NS', 'yahoo', start_date, end_date)
panel_dataa99 = data.DataReader('CCHHL.NS', 'yahoo', start_date, end_date)
panel_dataa100 = data.DataReader('RANEENGINE.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa51['SYMBOL']='BANSWRAS.NS'
panel_dataa52['SYMBOL']='V2RETAIL.NS'
panel_dataa53['SYMBOL']='HIRECT.NS'
panel_dataa54['SYMBOL']='SHARDAMOTR.NS'
panel_dataa55['SYMBOL']='REMSONSIND.NS'
panel_dataa56['SYMBOL']='BSL.NS'
panel_dataa57['SYMBOL']='EIHOTEL.NS'
panel_dataa58['SYMBOL']='HILTON.NS'
panel_dataa59['SYMBOL']='JAYNECOIND.NS'
panel_dataa60['SYMBOL']='INDSWFTLTD.NS'
panel_dataa61['SYMBOL']='SURANASOL.NS'
panel_dataa62['SYMBOL']='MANGALAM.NS'
panel_dataa63['SYMBOL']='AARTISURF.NS'
panel_dataa64['SYMBOL']='WELINV.NS'
panel_dataa65['SYMBOL']='KALYANIFRG.NS'
panel_dataa66['SYMBOL']='DYNAMATECH.NS'
panel_dataa67['SYMBOL']='INDSWFTLAB.NS'
panel_dataa68['SYMBOL']='KOHINOOR.NS'
panel_dataa69['SYMBOL']='NITCO.NS'
panel_dataa70['SYMBOL']='THOMASCOOK.NS'
panel_dataa71['SYMBOL']='INFOBEAN.NS'
panel_dataa72['SYMBOL']='BANG.NS'
panel_dataa73['SYMBOL']='AURIONPRO.NS'
panel_dataa74['SYMBOL']='JINDRILL.NS'
panel_dataa75['SYMBOL']='OPTIEMUS.NS'
panel_dataa76['SYMBOL']='HEXATRADEX.NS'
panel_dataa77['SYMBOL']='MUKTAARTS.NS'
panel_dataa78['SYMBOL']='GINNIFILA.NS'
panel_dataa79['SYMBOL']='TARMAT.NS'
panel_dataa80['SYMBOL']='BEDMUTHA.NS'
panel_dataa81['SYMBOL']='KARDA.NS'
panel_dataa82['SYMBOL']='CHEMBOND.NS'
panel_dataa83['SYMBOL']='CGPOWER.NS'
panel_dataa84['SYMBOL']='KDDL.NS'
panel_dataa85['SYMBOL']='SUPREMEINF.NS'
panel_dataa86['SYMBOL']='BIOFILCHEM.NS'
panel_dataa87['SYMBOL']='RTNINFRA.NS'
panel_dataa88['SYMBOL']='VIKASMCORP.NS'
panel_dataa89['SYMBOL']='SOMATEX.NS'
panel_dataa90['SYMBOL']='INDORAMA.NS'
panel_dataa91['SYMBOL']='VIKASECO.NS'
panel_dataa92['SYMBOL']='VASWANI.NS'
panel_dataa93['SYMBOL']='ELGIRUBCO.NS'
panel_dataa94['SYMBOL']='GPIL.NS'
panel_dataa95['SYMBOL']='COFFEEDAY.NS'
panel_dataa96['SYMBOL']='VIVIMEDLAB.NS'
panel_dataa97['SYMBOL']='MCLEODRUSS.NS'
panel_dataa98['SYMBOL']='VIPCLOTHNG.NS'
panel_dataa99['SYMBOL']='CCHHL.NS'
panel_dataa100['SYMBOL']='RANEENGINE.NS'

# %%
finall = pd.concat([panel_dataa51,
panel_dataa52,
panel_dataa53,
panel_dataa54,
panel_dataa55,
panel_dataa56,
panel_dataa57,
panel_dataa58,
panel_dataa59,
panel_dataa60,
panel_dataa61,
panel_dataa62,
panel_dataa63,
panel_dataa64,
panel_dataa65,
panel_dataa66,
panel_dataa67,
panel_dataa68,
panel_dataa69,
panel_dataa70,
panel_dataa71,
panel_dataa72,
panel_dataa73,
panel_dataa74,
panel_dataa75,
panel_dataa76,
panel_dataa77,
panel_dataa78,
panel_dataa79,
panel_dataa80,
panel_dataa81,
panel_dataa82,
panel_dataa83,
panel_dataa84,
panel_dataa85,
panel_dataa86,
panel_dataa87,
panel_dataa88,
panel_dataa89,
panel_dataa90,
panel_dataa91,
panel_dataa92,
panel_dataa93,
panel_dataa94,
panel_dataa95,
panel_dataa96,
panel_dataa97,
panel_dataa98,
panel_dataa99,
panel_dataa100])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_51_TO_100_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_51_TO_100_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_51_TO_100_start_to_15082020.csv")

# %%
readdf
# Out:
#         Unnamed: 0        Date        High  ...   Volume   Adj Close         SYMBOL
# 0                0  2007-04-11   77.949997  ...  50504.0   49.061367    BANSWRAS.NS
# 1                1  2007-04-12   70.800003  ...   6384.0   46.462776    BANSWRAS.NS
# 2                2  2007-04-13   73.000000  ...   5757.0   47.225025    BANSWRAS.NS
# 3                3  2007-04-16   68.800003  ...   6366.0   46.081650    BANSWRAS.NS
# 4                4  2007-04-17   68.849998  ...   3108.0   46.428131    BANSWRAS.NS
# ...            ...         ...         ...  ...      ...         ...            ...
# 147211      147211  2020-08-10  194.649994  ...   1338.0  192.000000  RANEENGINE.NS
# 147212      147212  2020-08-11  194.500000  ...   1161.0  190.399994  RANEENGINE.NS
# 147213      147213  2020-08-12  194.000000  ...    808.0  190.149994  RANEENGINE.NS
# 147214      147214  2020-08-13  204.199997  ...  14353.0  194.649994  RANEENGINE.NS
# ...
