# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa451 = data.DataReader('ASPINWALL.NS', 'yahoo', start_date, end_date)
panel_dataa452 = data.DataReader('MAITHANALL.NS', 'yahoo', start_date, end_date)
panel_dataa453 = data.DataReader('ASIANTILES.NS', 'yahoo', start_date, end_date)
panel_dataa454 = data.DataReader('WELCORP.NS', 'yahoo', start_date, end_date)
panel_dataa455 = data.DataReader('SMLISUZU.NS', 'yahoo', start_date, end_date)
panel_dataa456 = data.DataReader('TAKE.NS', 'yahoo', start_date, end_date)
panel_dataa457 = data.DataReader('JBMA.NS', 'yahoo', start_date, end_date)
panel_dataa458 = data.DataReader('SMSPHARMA.NS', 'yahoo', start_date, end_date)
panel_dataa459 = data.DataReader('ESCORTS.NS', 'yahoo', start_date, end_date)
panel_dataa460 = data.DataReader('CUPID.NS', 'yahoo', start_date, end_date)
panel_dataa461 = data.DataReader('SAKSOFT.NS', 'yahoo', start_date, end_date)
panel_dataa462 = data.DataReader('INDNIPPON.NS', 'yahoo', start_date, end_date)
panel_dataa463 = data.DataReader('OFSS.NS', 'yahoo', start_date, end_date)
panel_dataa464 = data.DataReader('PTC.NS', 'yahoo', start_date, end_date)
panel_dataa465 = data.DataReader('GSFC.NS', 'yahoo', start_date, end_date)
panel_dataa466 = data.DataReader('SHIRPUR-G.NS', 'yahoo', start_date, end_date)
panel_dataa467 = data.DataReader('STERTOOLS.NS', 'yahoo', start_date, end_date)
panel_dataa468 = data.DataReader('BEL.NS', 'yahoo', start_date, end_date)
panel_dataa469 = data.DataReader('PREMIERPOL.NS', 'yahoo', start_date, end_date)
panel_dataa470 = data.DataReader('CSBBANK.NS', 'yahoo', start_date, end_date)
panel_dataa471 = data.DataReader('ORIENTPPR.NS', 'yahoo', start_date, end_date)
panel_dataa472 = data.DataReader('MENONBE.NS', 'yahoo', start_date, end_date)
panel_dataa473 = data.DataReader('KESORAMIND.NS', 'yahoo', start_date, end_date)
panel_dataa474 = data.DataReader('TAJGVK.NS', 'yahoo', start_date, end_date)
panel_dataa475 = data.DataReader('ASALCBR.NS', 'yahoo', start_date, end_date)
panel_dataa476 = data.DataReader('OBEROIRLTY.NS', 'yahoo', start_date, end_date)
panel_dataa477 = data.DataReader('VOLTAS.NS', 'yahoo', start_date, end_date)
panel_dataa478 = data.DataReader('KWALITY.NS', 'yahoo', start_date, end_date)
panel_dataa479 = data.DataReader('FEL.NS', 'yahoo', start_date, end_date)
panel_dataa480 = data.DataReader('IDFC.NS', 'yahoo', start_date, end_date)
panel_dataa481 = data.DataReader('TERASOFT.NS', 'yahoo', start_date, end_date)
panel_dataa482 = data.DataReader('TEAMLEASE.NS', 'yahoo', start_date, end_date)
panel_dataa483 = data.DataReader('TRIDENT.NS', 'yahoo', start_date, end_date)
panel_dataa484 = data.DataReader('TWL.NS', 'yahoo', start_date, end_date)
panel_dataa485 = data.DataReader('HIL.NS', 'yahoo', start_date, end_date)
panel_dataa486 = data.DataReader('BHEL.NS', 'yahoo', start_date, end_date)
panel_dataa487 = data.DataReader('IBULHSGFIN.NS', 'yahoo', start_date, end_date)
panel_dataa488 = data.DataReader('CLNINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa489 = data.DataReader('ASHOKLEY.NS', 'yahoo', start_date, end_date)
panel_dataa490 = data.DataReader('DEEPAKFERT.NS', 'yahoo', start_date, end_date)
panel_dataa491 = data.DataReader('INDIANB.NS', 'yahoo', start_date, end_date)
panel_dataa492 = data.DataReader('LAURUSLABS.NS', 'yahoo', start_date, end_date)
panel_dataa493 = data.DataReader('MEGH.NS', 'yahoo', start_date, end_date)
panel_dataa494 = data.DataReader('DLF.NS', 'yahoo', start_date, end_date)
panel_dataa495 = data.DataReader('COCHINSHIP.NS', 'yahoo', start_date, end_date)
panel_dataa496 = data.DataReader('HSIL.NS', 'yahoo', start_date, end_date)
panel_dataa497 = data.DataReader('HEXAWARE.NS', 'yahoo', start_date, end_date)
panel_dataa498 = data.DataReader('DIGJAMLTD.NS', 'yahoo', start_date, end_date)
panel_dataa499 = data.DataReader('M&MFIN.NS', 'yahoo', start_date, end_date)
panel_dataa500 = data.DataReader('ZEEL.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa451['SYMBOL']='ASPINWALL.NS'
panel_dataa452['SYMBOL']='MAITHANALL.NS'
panel_dataa453['SYMBOL']='ASIANTILES.NS'
panel_dataa454['SYMBOL']='WELCORP.NS'
panel_dataa455['SYMBOL']='SMLISUZU.NS'
panel_dataa456['SYMBOL']='TAKE.NS'
panel_dataa457['SYMBOL']='JBMA.NS'
panel_dataa458['SYMBOL']='SMSPHARMA.NS'
panel_dataa459['SYMBOL']='ESCORTS.NS'
panel_dataa460['SYMBOL']='CUPID.NS'
panel_dataa461['SYMBOL']='SAKSOFT.NS'
panel_dataa462['SYMBOL']='INDNIPPON.NS'
panel_dataa463['SYMBOL']='OFSS.NS'
panel_dataa464['SYMBOL']='PTC.NS'
panel_dataa465['SYMBOL']='GSFC.NS'
panel_dataa466['SYMBOL']='SHIRPUR-G.NS'
panel_dataa467['SYMBOL']='STERTOOLS.NS'
panel_dataa468['SYMBOL']='BEL.NS'
panel_dataa469['SYMBOL']='PREMIERPOL.NS'
panel_dataa470['SYMBOL']='CSBBANK.NS'
panel_dataa471['SYMBOL']='ORIENTPPR.NS'
panel_dataa472['SYMBOL']='MENONBE.NS'
panel_dataa473['SYMBOL']='KESORAMIND.NS'
panel_dataa474['SYMBOL']='TAJGVK.NS'
panel_dataa475['SYMBOL']='ASALCBR.NS'
panel_dataa476['SYMBOL']='OBEROIRLTY.NS'
panel_dataa477['SYMBOL']='VOLTAS.NS'
panel_dataa478['SYMBOL']='KWALITY.NS'
panel_dataa479['SYMBOL']='FEL.NS'
panel_dataa480['SYMBOL']='IDFC.NS'
panel_dataa481['SYMBOL']='TERASOFT.NS'
panel_dataa482['SYMBOL']='TEAMLEASE.NS'
panel_dataa483['SYMBOL']='TRIDENT.NS'
panel_dataa484['SYMBOL']='TWL.NS'
panel_dataa485['SYMBOL']='HIL.NS'
panel_dataa486['SYMBOL']='BHEL.NS'
panel_dataa487['SYMBOL']='IBULHSGFIN.NS'
panel_dataa488['SYMBOL']='CLNINDIA.NS'
panel_dataa489['SYMBOL']='ASHOKLEY.NS'
panel_dataa490['SYMBOL']='DEEPAKFERT.NS'
panel_dataa491['SYMBOL']='INDIANB.NS'
panel_dataa492['SYMBOL']='LAURUSLABS.NS'
panel_dataa493['SYMBOL']='MEGH.NS'
panel_dataa494['SYMBOL']='DLF.NS'
panel_dataa495['SYMBOL']='COCHINSHIP.NS'
panel_dataa496['SYMBOL']='HSIL.NS'
panel_dataa497['SYMBOL']='HEXAWARE.NS'
panel_dataa498['SYMBOL']='DIGJAMLTD.NS'
panel_dataa499['SYMBOL']='M&MFIN.NS'
panel_dataa500['SYMBOL']='ZEEL.NS'

# %%
finall = pd.concat([panel_dataa451,
panel_dataa452,
panel_dataa453,
panel_dataa454,
panel_dataa455,
panel_dataa456,
panel_dataa457,
panel_dataa458,
panel_dataa459,
panel_dataa460,
panel_dataa461,
panel_dataa462,
panel_dataa463,
panel_dataa464,
panel_dataa465,
panel_dataa466,
panel_dataa467,
panel_dataa468,
panel_dataa469,
panel_dataa470,
panel_dataa471,
panel_dataa472,
panel_dataa473,
panel_dataa474,
panel_dataa475,
panel_dataa476,
panel_dataa477,
panel_dataa478,
panel_dataa479,
panel_dataa480,
panel_dataa481,
panel_dataa482,
panel_dataa483,
panel_dataa484,
panel_dataa485,
panel_dataa486,
panel_dataa487,
panel_dataa488,
panel_dataa489,
panel_dataa490,
panel_dataa491,
panel_dataa492,
panel_dataa493,
panel_dataa494,
panel_dataa495,
panel_dataa496,
panel_dataa497,
panel_dataa498,
panel_dataa499,
panel_dataa500])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_451_TO_500_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_451_TO_500_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_451_TO_500_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  ...   Adj Close        SYMBOL
# 0                0  2016-06-14  ...  158.262146  ASPINWALL.NS
# 1                1  2016-06-15  ...  166.175247  ASPINWALL.NS
# 2                2  2016-06-16  ...  174.465195  ASPINWALL.NS
# 3                3  2016-06-17  ...  183.179016  ASPINWALL.NS
# 4                4  2016-06-20  ...  192.316757  ASPINWALL.NS
# ...            ...         ...  ...         ...           ...
# 172619      172619  2020-08-10  ...  151.199997       ZEEL.NS
# 172620      172620  2020-08-11  ...  159.750000       ZEEL.NS
# 172621      172621  2020-08-12  ...  161.250000       ZEEL.NS
# 172622      172622  2020-08-13  ...  162.300003       ZEEL.NS
# 172623      172623  2020-08-14  ...  161.199997       ZEEL.NS
#
# [172624 rows x 9 columns]
