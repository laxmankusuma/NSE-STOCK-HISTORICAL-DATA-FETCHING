# %%
pip install pandas-datareader

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
import datetime
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['TCS.NS', 'LUPIN.NS']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '1970-01-01'
end_date = '2020-08-14'
#start_date = datetime.datetime.strptime('14-08-20', '%d-%m-%y').date()
#end_date = datetime.datetime.strptime('14-08-20', '%d-%m-%y').date()
#User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data1 = data.DataReader('^NSEI', 'yahoo', start_date, end_date)
panel_data1['SYMBOL']='^NSEI'
panel_data2 = data.DataReader('JSWSTEEL.NS', 'yahoo', start_date, end_date)
panel_data2['SYMBOL']='JSWSTEEL'
panel_data3 = data.DataReader('COALINDIA.NS', 'yahoo', start_date, end_date)
panel_data3['SYMBOL']='COALINDIA'
panel_data4 = data.DataReader('SUNPHARMA.NS', 'yahoo', start_date, end_date)
panel_data4['SYMBOL']='SUNPHARMA'
panel_data5 = data.DataReader('CIPLA.NS', 'yahoo', start_date, end_date)
panel_data5['SYMBOL']='CIPLA'
panel_data6 = data.DataReader('NTPC.NS', 'yahoo', start_date, end_date)
panel_data6['SYMBOL']='NTPC'
panel_data7 = data.DataReader('TITAN.NS', 'yahoo', start_date, end_date)
panel_data7['SYMBOL']='TITAN'
panel_data8 = data.DataReader('TATASTEEL.NS', 'yahoo', start_date, end_date)
panel_data8['SYMBOL']='TATASTEEL'
panel_data9 = data.DataReader('SHREECEM.NS', 'yahoo', start_date, end_date)
panel_data9['SYMBOL']='SHREECEM'
panel_data10 = data.DataReader('INFY.NS', 'yahoo', start_date, end_date)
panel_data10['SYMBOL']='INFY'
panel_data11 = data.DataReader('ADANIPORTS.NS', 'yahoo', start_date, end_date)
panel_data11['SYMBOL']='ADANIPORTS'
panel_data12 = data.DataReader('DRREDDY.NS', 'yahoo', start_date, end_date)
panel_data12['SYMBOL']='DRREDDY'
panel_data13 = data.DataReader('HINDALCO.NS', 'yahoo', start_date, end_date)
panel_data13['SYMBOL']='HINDALCO'
panel_data14 = data.DataReader('WIPRO.NS', 'yahoo', start_date, end_date)
panel_data14['SYMBOL']='WIPRO'
panel_data15 = data.DataReader('BRITANNIA.NS', 'yahoo', start_date, end_date)
panel_data15['SYMBOL']='BRITANNIA'
panel_data16 = data.DataReader('ASIANPAINT.NS', 'yahoo', start_date, end_date)
panel_data16['SYMBOL']='ASIANPAINT'
panel_data17 = data.DataReader('TCS.NS', 'yahoo', start_date, end_date)
panel_data17['SYMBOL']='TCS'
panel_data18 = data.DataReader('RELIANCE.NS', 'yahoo', start_date, end_date)
panel_data18['SYMBOL']='RELIANCE'
panel_data19 = data.DataReader('HEROMOTOCO.NS', 'yahoo', start_date, end_date)
panel_data19['SYMBOL']='HEROMOTOCO'
panel_data20 = data.DataReader('TECHM.NS', 'yahoo', start_date, end_date)
panel_data20['SYMBOL']='TECHM'
panel_data21 = data.DataReader('NESTLEIND.NS', 'yahoo', start_date, end_date)
panel_data21['SYMBOL']='NESTLEIND'
panel_data22 = data.DataReader('ZEEL.NS', 'yahoo', start_date, end_date)
panel_data22['SYMBOL']='ZEEL'
panel_data23 = data.DataReader('UPL.NS', 'yahoo', start_date, end_date)
panel_data23['SYMBOL']='UPL'
panel_data24 = data.DataReader('GRASIM.NS', 'yahoo', start_date, end_date)
panel_data24['SYMBOL']='GRASIM'
panel_data25 = data.DataReader('HDFC.NS', 'yahoo', start_date, end_date)
panel_data25['SYMBOL']='HDFC'
panel_data26 = data.DataReader('LT.NS', 'yahoo', start_date, end_date)
panel_data26['SYMBOL']='LT'
panel_data27 = data.DataReader('ULTRACEMCO.NS', 'yahoo', start_date, end_date)
panel_data27['SYMBOL']='ULTRACEMCO'
panel_data28 = data.DataReader('HINDUNILVR.NS', 'yahoo', start_date, end_date)
panel_data28['SYMBOL']='HINDUNILVR'
panel_data29 = data.DataReader('BHARTIARTL.NS', 'yahoo', start_date, end_date)
panel_data29['SYMBOL']='BHARTIARTL'
panel_data30 = data.DataReader('BAJAJ-AUTO.NS', 'yahoo', start_date, end_date)
panel_data30['SYMBOL']='BAJAJ-AUTO'
panel_data31 = data.DataReader('GAIL.NS', 'yahoo', start_date, end_date)
panel_data31['SYMBOL']='GAIL'
panel_data32 = data.DataReader('INFRATEL.NS', 'yahoo', start_date, end_date)
panel_data32['SYMBOL']='INFRATEL'
panel_data33 = data.DataReader('BAJAJFINSV.NS', 'yahoo', start_date, end_date)
panel_data33['SYMBOL']='BAJAJFINSV'
panel_data34 = data.DataReader('ONGC.NS', 'yahoo', start_date, end_date)
panel_data34['SYMBOL']='ONGC'
panel_data35 = data.DataReader('POWERGRID.NS', 'yahoo', start_date, end_date)
panel_data35['SYMBOL']='POWERGRID'
panel_data36 = data.DataReader('ICICIBANK.NS', 'yahoo', start_date, end_date)
panel_data36['SYMBOL']='ICICIBANK'
panel_data37 = data.DataReader('MARUTI.NS', 'yahoo', start_date, end_date)
panel_data37['SYMBOL']='MARUTI'
panel_data38 = data.DataReader('BPCL.NS', 'yahoo', start_date, end_date)
panel_data38['SYMBOL']='BPCL'
panel_data39 = data.DataReader('HDFCLIFE.NS', 'yahoo', start_date, end_date)
panel_data39['SYMBOL']='HDFCLIFE'
panel_data40 = data.DataReader('KOTAKBANK.NS', 'yahoo', start_date, end_date)
panel_data40['SYMBOL']='KOTAKBANK'
panel_data41 = data.DataReader('INDUSINDBK.NS', 'yahoo', start_date, end_date)
panel_data41['SYMBOL']='INDUSINDBK'
panel_data42 = data.DataReader('IOC.NS', 'yahoo', start_date, end_date)
panel_data42['SYMBOL']='IOC'
panel_data43 = data.DataReader('HCLTECH.NS', 'yahoo', start_date, end_date)
panel_data43['SYMBOL']='HCLTECH'
panel_data44 = data.DataReader('HDFCBANK.NS', 'yahoo', start_date, end_date)
panel_data44['SYMBOL']='HDFCBANK'
panel_data45 = data.DataReader('ITC.NS', 'yahoo', start_date, end_date)
panel_data45['SYMBOL']='ITC'
panel_data46 = data.DataReader('SBIN.NS', 'yahoo', start_date, end_date)
panel_data46['SYMBOL']='SBIN'
panel_data47 = data.DataReader('BAJFINANCE.NS', 'yahoo', start_date, end_date)
panel_data47['SYMBOL']='BAJFINANCE'
panel_data48 = data.DataReader('AXISBANK.NS', 'yahoo', start_date, end_date)
panel_data48['SYMBOL']='AXISBANK'
panel_data49 = data.DataReader('M&M.NS', 'yahoo', start_date, end_date)
panel_data49['SYMBOL']='M&M'
panel_data50 = data.DataReader('TATAMOTORS.NS', 'yahoo', start_date, end_date)
panel_data50['SYMBOL']='TATAMOTORS'
panel_data51 = data.DataReader('EICHERMOT.NS', 'yahoo', start_date, end_date)
panel_data51['SYMBOL']='EICHERMOT'

# %%
panel_data1.reset_index().head()
# Out:
#         Date         High          Low  ...  Volume    Adj Close  SYMBOL
# 0 2007-09-17  4549.049805  4482.850098  ...     0.0  4494.649902   ^NSEI
# 1 2007-09-18  4551.799805  4481.549805  ...     0.0  4546.200195   ^NSEI
# 2 2007-09-19  4739.000000  4550.250000  ...     0.0  4732.350098   ^NSEI
# 3 2007-09-20  4760.850098  4721.149902  ...     0.0  4747.549805   ^NSEI
# 4 2007-09-21  4855.700195  4733.700195  ...     0.0  4837.549805   ^NSEI
#
# [5 rows x 8 columns]

# %%
finall = pd.concat([panel_data1,panel_data2,panel_data3,panel_data4,panel_data5,panel_data6,panel_data7,panel_data8,panel_data9,panel_data10,panel_data11,panel_data12,panel_data13,panel_data14,panel_data15,panel_data16,panel_data17,panel_data18,panel_data19,panel_data20,panel_data21,panel_data22,panel_data23,panel_data24,panel_data25,panel_data26,panel_data27,panel_data28,panel_data29,panel_data30,panel_data31,panel_data32,panel_data33,panel_data34,panel_data35,panel_data36
,panel_data37
,panel_data38
,panel_data39
,panel_data40
,panel_data41
,panel_data42
,panel_data43
,panel_data44
,panel_data45
,panel_data46
,panel_data47
,panel_data48,panel_data49,panel_data50,panel_data51])

# %%
finall.reset_index()
# Out:
#              Date          High  ...     Adj Close     SYMBOL
# 0      2007-09-17   4549.049805  ...   4494.649902      ^NSEI
# 1      2007-09-18   4551.799805  ...   4546.200195      ^NSEI
# 2      2007-09-19   4739.000000  ...   4732.350098      ^NSEI
# 3      2007-09-20   4760.850098  ...   4747.549805      ^NSEI
# 4      2007-09-21   4855.700195  ...   4837.549805      ^NSEI
# ...           ...           ...  ...           ...        ...
# 242276 2020-08-10  21999.000000  ...  21353.099609  EICHERMOT
# 242277 2020-08-11  21670.000000  ...  21442.699219  EICHERMOT
# 242278 2020-08-12  22339.900391  ...  22116.699219  EICHERMOT
# 242279 2020-08-13  22299.900391  ...  21672.900391  EICHERMOT
# 242280 2020-08-14  21750.199219  ...  20144.199219  EICHERMOT
#
# [242281 rows x 8 columns]

# %%
finall.reset_index().columns
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close',
#        'SYMBOL'],
#       dtype='object')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm  nifty50_start_to_15082020.csv

# %%
finall.reset_index().to_csv('nifty50_start_to_15082020.csv')

# %%
# !cp nifty50_start_to_15082020.csv "drive/My Drive/"

# %%
readdf = pd.read_csv("drive/My Drive/nifty50_start_to_15082020.csv")

# %%
readdf.head()
# Out:
#    Unnamed: 0        Date         High  ...  Volume    Adj Close  SYMBOL
# 0           0  2007-09-17  4549.049805  ...     0.0  4494.649902   ^NSEI
# 1           1  2007-09-18  4551.799805  ...     0.0  4546.200195   ^NSEI
# 2           2  2007-09-19  4739.000000  ...     0.0  4732.350098   ^NSEI
# 3           3  2007-09-20  4760.850098  ...     0.0  4747.549805   ^NSEI
# 4           4  2007-09-21  4855.700195  ...     0.0  4837.549805   ^NSEI
#
# [5 rows x 9 columns]

# %%
readdf.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'High', 'Low', 'Open', 'Close', 'Volume',
#        'Adj Close', 'SYMBOL'],
#       dtype='object')

# %%
# !ls
# Out:
# drive  nifty50_start_to_15082020.csv  sample_data
