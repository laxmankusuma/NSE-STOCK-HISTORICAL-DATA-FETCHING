# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

# %%
panel_dataa601 = data.DataReader('AVADHSUGAR.NS', 'yahoo', start_date, end_date)
panel_dataa602 = data.DataReader('DBCORP.NS', 'yahoo', start_date, end_date)
panel_dataa603 = data.DataReader('RCF.NS', 'yahoo', start_date, end_date)
panel_dataa604 = data.DataReader('TEXRAIL.NS', 'yahoo', start_date, end_date)
panel_dataa605 = data.DataReader('ANDHRSUGAR.NS', 'yahoo', start_date, end_date)
panel_dataa606 = data.DataReader('NTPC.NS', 'yahoo', start_date, end_date)
panel_dataa607 = data.DataReader('JSLHISAR.NS', 'yahoo', start_date, end_date)
panel_dataa608 = data.DataReader('IDEA.NS', 'yahoo', start_date, end_date)
panel_dataa609 = data.DataReader('AUROPHARMA.NS', 'yahoo', start_date, end_date)
panel_dataa610 = data.DataReader('KARURVYSYA.NS', 'yahoo', start_date, end_date)
panel_dataa611 = data.DataReader('INEOSSTYRO.NS', 'yahoo', start_date, end_date)
panel_dataa612 = data.DataReader('TIDEWATER.NS', 'yahoo', start_date, end_date)
panel_dataa613 = data.DataReader('SPECIALITY.NS', 'yahoo', start_date, end_date)
panel_dataa614 = data.DataReader('JUMPNET.NS', 'yahoo', start_date, end_date)
panel_dataa615 = data.DataReader('CENTURYPLY.NS', 'yahoo', start_date, end_date)
panel_dataa616 = data.DataReader('VEDL.NS', 'yahoo', start_date, end_date)
panel_dataa617 = data.DataReader('SHIL.NS', 'yahoo', start_date, end_date)
panel_dataa618 = data.DataReader('INGERRAND.NS', 'yahoo', start_date, end_date)
panel_dataa619 = data.DataReader('ARVINDFASN.NS', 'yahoo', start_date, end_date)
panel_dataa620 = data.DataReader('NLCINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa621 = data.DataReader('APCL.NS', 'yahoo', start_date, end_date)
panel_dataa622 = data.DataReader('MARUTI.NS', 'yahoo', start_date, end_date)
panel_dataa623 = data.DataReader('PERSISTENT.NS', 'yahoo', start_date, end_date)
panel_dataa624 = data.DataReader('AKZOINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa625 = data.DataReader('DIAMONDYD.NS', 'yahoo', start_date, end_date)
panel_dataa626 = data.DataReader('SICAL.NS', 'yahoo', start_date, end_date)
panel_dataa627 = data.DataReader('MTNL.NS', 'yahoo', start_date, end_date)
panel_dataa628 = data.DataReader('HATHWAY.NS', 'yahoo', start_date, end_date)
panel_dataa629 = data.DataReader('SOLARA.NS', 'yahoo', start_date, end_date)
panel_dataa630 = data.DataReader('TORNTPHARM.NS', 'yahoo', start_date, end_date)
panel_dataa631 = data.DataReader('ALBERTDAVD.NS', 'yahoo', start_date, end_date)
panel_dataa632 = data.DataReader('CYIENT.NS', 'yahoo', start_date, end_date)
panel_dataa633 = data.DataReader('ACE.NS', 'yahoo', start_date, end_date)
panel_dataa634 = data.DataReader('FAIRCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa635 = data.DataReader('DALBHARAT.NS', 'yahoo', start_date, end_date)
panel_dataa636 = data.DataReader('MAXVIL.NS', 'yahoo', start_date, end_date)
panel_dataa637 = data.DataReader('RENUKA.NS', 'yahoo', start_date, end_date)
panel_dataa638 = data.DataReader('RBLBANK.NS', 'yahoo', start_date, end_date)
panel_dataa639 = data.DataReader('TIMETECHNO.NS', 'yahoo', start_date, end_date)
#panel_dataa640 = data.DataReader('CONFIPET.NS', 'yahoo', start_date, end_date)
panel_dataa641 = data.DataReader('KEI.NS', 'yahoo', start_date, end_date)
panel_dataa642 = data.DataReader('DEN.NS', 'yahoo', start_date, end_date)
panel_dataa643 = data.DataReader('JMFINANCIL.NS', 'yahoo', start_date, end_date)
panel_dataa644 = data.DataReader('NUCLEUS.NS', 'yahoo', start_date, end_date)
panel_dataa645 = data.DataReader('TATASTLBSL.NS', 'yahoo', start_date, end_date)
panel_dataa646 = data.DataReader('APTECHT.NS', 'yahoo', start_date, end_date)
panel_dataa647 = data.DataReader('GATI.NS', 'yahoo', start_date, end_date)
panel_dataa648 = data.DataReader('FIEMIND.NS', 'yahoo', start_date, end_date)
panel_dataa649 = data.DataReader('TTKPRESTIG.NS', 'yahoo', start_date, end_date)
panel_dataa650 = data.DataReader('JAYSREETEA.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa601['SYMBOL']='AVADHSUGAR.NS'
panel_dataa602['SYMBOL']='DBCORP.NS'
panel_dataa603['SYMBOL']='RCF.NS'
panel_dataa604['SYMBOL']='TEXRAIL.NS'
panel_dataa605['SYMBOL']='ANDHRSUGAR.NS'
panel_dataa606['SYMBOL']='NTPC.NS'
panel_dataa607['SYMBOL']='JSLHISAR.NS'
panel_dataa608['SYMBOL']='IDEA.NS'
panel_dataa609['SYMBOL']='AUROPHARMA.NS'
panel_dataa610['SYMBOL']='KARURVYSYA.NS'
panel_dataa611['SYMBOL']='INEOSSTYRO.NS'
panel_dataa612['SYMBOL']='TIDEWATER.NS'
panel_dataa613['SYMBOL']='SPECIALITY.NS'
panel_dataa614['SYMBOL']='JUMPNET.NS'
panel_dataa615['SYMBOL']='CENTURYPLY.NS'
panel_dataa616['SYMBOL']='VEDL.NS'
panel_dataa617['SYMBOL']='SHIL.NS'
panel_dataa618['SYMBOL']='INGERRAND.NS'
panel_dataa619['SYMBOL']='ARVINDFASN.NS'
panel_dataa620['SYMBOL']='NLCINDIA.NS'
panel_dataa621['SYMBOL']='APCL.NS'
panel_dataa622['SYMBOL']='MARUTI.NS'
panel_dataa623['SYMBOL']='PERSISTENT.NS'
panel_dataa624['SYMBOL']='AKZOINDIA.NS'
panel_dataa625['SYMBOL']='DIAMONDYD.NS'
panel_dataa626['SYMBOL']='SICAL.NS'
panel_dataa627['SYMBOL']='MTNL.NS'
panel_dataa628['SYMBOL']='HATHWAY.NS'
panel_dataa629['SYMBOL']='SOLARA.NS'
panel_dataa630['SYMBOL']='TORNTPHARM.NS'
panel_dataa631['SYMBOL']='ALBERTDAVD.NS'
panel_dataa632['SYMBOL']='CYIENT.NS'
panel_dataa633['SYMBOL']='ACE.NS'
panel_dataa634['SYMBOL']='FAIRCHEM.NS'
panel_dataa635['SYMBOL']='DALBHARAT.NS'
panel_dataa636['SYMBOL']='MAXVIL.NS'
panel_dataa637['SYMBOL']='RENUKA.NS'
panel_dataa638['SYMBOL']='RBLBANK.NS'
panel_dataa639['SYMBOL']='TIMETECHNO.NS'
#panel_dataa640['SYMBOL']='CONFIPET.NS'
panel_dataa641['SYMBOL']='KEI.NS'
panel_dataa642['SYMBOL']='DEN.NS'
panel_dataa643['SYMBOL']='JMFINANCIL.NS'
panel_dataa644['SYMBOL']='NUCLEUS.NS'
panel_dataa645['SYMBOL']='TATASTLBSL.NS'
panel_dataa646['SYMBOL']='APTECHT.NS'
panel_dataa647['SYMBOL']='GATI.NS'
panel_dataa648['SYMBOL']='FIEMIND.NS'
panel_dataa649['SYMBOL']='TTKPRESTIG.NS'
panel_dataa650['SYMBOL']='JAYSREETEA.NS'

# %%
finall = pd.concat([panel_dataa601,
panel_dataa602,
panel_dataa603,
panel_dataa604,
panel_dataa605,
panel_dataa606,
panel_dataa607,
panel_dataa608,
panel_dataa609,
panel_dataa610,
panel_dataa611,
panel_dataa612,
panel_dataa613,
panel_dataa614,
panel_dataa615,
panel_dataa616,
panel_dataa617,
panel_dataa618,
panel_dataa619,
panel_dataa620,
panel_dataa621,
panel_dataa622,
panel_dataa623,
panel_dataa624,
panel_dataa625,
panel_dataa626,
panel_dataa627,
panel_dataa628,
panel_dataa629,
panel_dataa630,
panel_dataa631,
panel_dataa632,
panel_dataa633,
panel_dataa634,
panel_dataa635,
panel_dataa636,
panel_dataa637,
panel_dataa638,
panel_dataa639,
#panel_dataa640,
panel_dataa641,
panel_dataa642,
panel_dataa643,
panel_dataa644,
panel_dataa645,
panel_dataa646,
panel_dataa647,
panel_dataa648,
panel_dataa649,
panel_dataa650])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_601_TO_650_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_601_TO_650_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_601_TO_650_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...    Volume   Adj Close         SYMBOL
# 0                0  2017-07-28  220.175003  ...   17006.0  218.616302  AVADHSUGAR.NS
# 1                1  2017-07-31  231.175003  ...    8340.0  229.538422  AVADHSUGAR.NS
# 2                2  2017-08-01  242.725006  ...    8786.0  241.006653  AVADHSUGAR.NS
# 3                3  2017-08-02  254.850006  ...   15146.0  253.045822  AVADHSUGAR.NS
# 4                4  2017-08-03  267.575012  ...   10984.0  265.680725  AVADHSUGAR.NS
# ...            ...         ...         ...  ...       ...         ...            ...
# 149122      149122  2020-08-10   63.000000  ...  287703.0   61.799999  JAYSREETEA.NS
# 149123      149123  2020-08-11   64.500000  ...  157706.0   62.650002  JAYSREETEA.NS
# 149124      149124  2020-08-12   62.049999  ...   79974.0   61.099998  JAYSREETEA.NS
# 149125      149125  2020-08-13   62.500000  ...   76948.0   60.599998  JAYSREETEA.NS
# ...
