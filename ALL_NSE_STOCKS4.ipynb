# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

# %%
panel_dataa151 = data.DataReader('INTEGRA.NS', 'yahoo', start_date, end_date)
panel_dataa152 = data.DataReader('MAZDA.NS', 'yahoo', start_date, end_date)
panel_dataa153 = data.DataReader('BLKASHYAP.NS', 'yahoo', start_date, end_date)
panel_dataa154 = data.DataReader('RELINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa155 = data.DataReader('NIACL.NS', 'yahoo', start_date, end_date)
panel_dataa156 = data.DataReader('SPAL.NS', 'yahoo', start_date, end_date)
panel_dataa157 = data.DataReader('BANKA.NS', 'yahoo', start_date, end_date)
panel_dataa158 = data.DataReader('PLASTIBLEN.NS', 'yahoo', start_date, end_date)
panel_dataa159 = data.DataReader('GLENMARK.NS', 'yahoo', start_date, end_date)
panel_dataa160 = data.DataReader('MBECL.NS', 'yahoo', start_date, end_date)
panel_dataa161 = data.DataReader('VAISHALI.NS', 'yahoo', start_date, end_date)
panel_dataa162 = data.DataReader('INDOSOLAR.NS', 'yahoo', start_date, end_date)
panel_dataa163 = data.DataReader('BHANDARI.NS', 'yahoo', start_date, end_date)
panel_dataa164 = data.DataReader('BSELINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa165 = data.DataReader('ATLANTA.NS', 'yahoo', start_date, end_date)
panel_dataa166 = data.DataReader('MORARJEE.NS', 'yahoo', start_date, end_date)
panel_dataa167 = data.DataReader('SILINV.NS', 'yahoo', start_date, end_date)
panel_dataa168 = data.DataReader('RUBYMILLS.NS', 'yahoo', start_date, end_date)
panel_dataa169 = data.DataReader('SKIL.NS', 'yahoo', start_date, end_date)
panel_dataa170 = data.DataReader('DATAMATICS.NS', 'yahoo', start_date, end_date)
panel_dataa171 = data.DataReader('TECHNOE.NS', 'yahoo', start_date, end_date)
panel_dataa172 = data.DataReader('TECHNOFAB.NS', 'yahoo', start_date, end_date)
panel_dataa173 = data.DataReader('ORTINLABSS.NS', 'yahoo', start_date, end_date)
panel_dataa174 = data.DataReader('UMESLTD.NS', 'yahoo', start_date, end_date)
panel_dataa175 = data.DataReader('LAKPRE.NS', 'yahoo', start_date, end_date)
panel_dataa176 = data.DataReader('GTNIND.NS', 'yahoo', start_date, end_date)
panel_dataa177 = data.DataReader('GENUSPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa178 = data.DataReader('GAEL.NS', 'yahoo', start_date, end_date)
panel_dataa179 = data.DataReader('SAKUMA.NS', 'yahoo', start_date, end_date)
panel_dataa180 = data.DataReader('PARACABLES.NS', 'yahoo', start_date, end_date)
panel_dataa181 = data.DataReader('VIKASWSP.NS', 'yahoo', start_date, end_date)
panel_dataa182 = data.DataReader('COUNCODOS.NS', 'yahoo', start_date, end_date)
panel_dataa183 = data.DataReader('MPSLTD.NS', 'yahoo', start_date, end_date)
panel_dataa184 = data.DataReader('LASA.NS', 'yahoo', start_date, end_date)
panel_dataa185 = data.DataReader('ISFT.NS', 'yahoo', start_date, end_date)
panel_dataa186 = data.DataReader('RAMCOSYS.NS', 'yahoo', start_date, end_date)
panel_dataa187 = data.DataReader('MTEDUCARE.NS', 'yahoo', start_date, end_date)
panel_dataa188 = data.DataReader('RVNL.NS', 'yahoo', start_date, end_date)
panel_dataa189 = data.DataReader('ITI.NS', 'yahoo', start_date, end_date)
panel_dataa190 = data.DataReader('ALPHAGEO.NS', 'yahoo', start_date, end_date)
panel_dataa191 = data.DataReader('SALSTEEL.NS', 'yahoo', start_date, end_date)
panel_dataa192 = data.DataReader('ANSALHSG.NS', 'yahoo', start_date, end_date)
panel_dataa193 = data.DataReader('MASFIN.NS', 'yahoo', start_date, end_date)
panel_dataa194 = data.DataReader('RAMASTEEL.NS', 'yahoo', start_date, end_date)
panel_dataa195 = data.DataReader('JISLDVREQS.NS', 'yahoo', start_date, end_date)
panel_dataa196 = data.DataReader('SADBHIN.NS', 'yahoo', start_date, end_date)
panel_dataa197 = data.DataReader('WEBELSOLAR.NS', 'yahoo', start_date, end_date)
panel_dataa198 = data.DataReader('ESTER.NS', 'yahoo', start_date, end_date)
panel_dataa199 = data.DataReader('3IINFOTECH.NS', 'yahoo', start_date, end_date)
#panel_dataa200 = data.DataReader('EMAMIPAP.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa151['SYMBOL']='INTEGRA.NS'
panel_dataa152['SYMBOL']='MAZDA.NS'
panel_dataa153['SYMBOL']='BLKASHYAP.NS'
panel_dataa154['SYMBOL']='RELINFRA.NS'
panel_dataa155['SYMBOL']='NIACL.NS'
panel_dataa156['SYMBOL']='SPAL.NS'
panel_dataa157['SYMBOL']='BANKA.NS'
panel_dataa158['SYMBOL']='PLASTIBLEN.NS'
panel_dataa159['SYMBOL']='GLENMARK.NS'
panel_dataa160['SYMBOL']='MBECL.NS'
panel_dataa161['SYMBOL']='VAISHALI.NS'
panel_dataa162['SYMBOL']='INDOSOLAR.NS'
panel_dataa163['SYMBOL']='BHANDARI.NS'
panel_dataa164['SYMBOL']='BSELINFRA.NS'
panel_dataa165['SYMBOL']='ATLANTA.NS'
panel_dataa166['SYMBOL']='MORARJEE.NS'
panel_dataa167['SYMBOL']='SILINV.NS'
panel_dataa168['SYMBOL']='RUBYMILLS.NS'
panel_dataa169['SYMBOL']='SKIL.NS'
panel_dataa170['SYMBOL']='DATAMATICS.NS'
panel_dataa171['SYMBOL']='TECHNOE.NS'
panel_dataa172['SYMBOL']='TECHNOFAB.NS'
panel_dataa173['SYMBOL']='ORTINLABSS.NS'
panel_dataa174['SYMBOL']='UMESLTD.NS'
panel_dataa175['SYMBOL']='LAKPRE.NS'
panel_dataa176['SYMBOL']='GTNIND.NS'
panel_dataa177['SYMBOL']='GENUSPOWER.NS'
panel_dataa178['SYMBOL']='GAEL.NS'
panel_dataa179['SYMBOL']='SAKUMA.NS'
panel_dataa180['SYMBOL']='PARACABLES.NS'
panel_dataa181['SYMBOL']='VIKASWSP.NS'
panel_dataa182['SYMBOL']='COUNCODOS.NS'
panel_dataa183['SYMBOL']='MPSLTD.NS'
panel_dataa184['SYMBOL']='LASA.NS'
panel_dataa185['SYMBOL']='ISFT.NS'
panel_dataa186['SYMBOL']='RAMCOSYS.NS'
panel_dataa187['SYMBOL']='MTEDUCARE.NS'
panel_dataa188['SYMBOL']='RVNL.NS'
panel_dataa189['SYMBOL']='ITI.NS'
panel_dataa190['SYMBOL']='ALPHAGEO.NS'
panel_dataa191['SYMBOL']='SALSTEEL.NS'
panel_dataa192['SYMBOL']='ANSALHSG.NS'
panel_dataa193['SYMBOL']='MASFIN.NS'
panel_dataa194['SYMBOL']='RAMASTEEL.NS'
panel_dataa195['SYMBOL']='JISLDVREQS.NS'
panel_dataa196['SYMBOL']='SADBHIN.NS'
panel_dataa197['SYMBOL']='WEBELSOLAR.NS'
panel_dataa198['SYMBOL']='ESTER.NS'
panel_dataa199['SYMBOL']='3IINFOTECH.NS'
#panel_dataa200['SYMBOL']='EMAMIPAP.NS'

# %%
finall = pd.concat([panel_dataa151,
panel_dataa152,
panel_dataa153,
panel_dataa154,
panel_dataa155,
panel_dataa156,
panel_dataa157,
panel_dataa158,
panel_dataa159,
panel_dataa160,
panel_dataa161,
panel_dataa162,
panel_dataa163,
panel_dataa164,
panel_dataa165,
panel_dataa166,
panel_dataa167,
panel_dataa168,
panel_dataa169,
panel_dataa170,
panel_dataa171,
panel_dataa172,
panel_dataa173,
panel_dataa174,
panel_dataa175,
panel_dataa176,
panel_dataa177,
panel_dataa178,
panel_dataa179,
panel_dataa180,
panel_dataa181,
panel_dataa182,
panel_dataa183,
panel_dataa184,
panel_dataa185,
panel_dataa186,
panel_dataa187,
panel_dataa188,
panel_dataa189,
panel_dataa190,
panel_dataa191,
panel_dataa192,
panel_dataa193,
panel_dataa194,
panel_dataa195,
panel_dataa196,
panel_dataa197,
panel_dataa198,
panel_dataa199
#panel_dataa200
])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_151_TO_200_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_151_TO_200_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_151_TO_200_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  High  ...     Volume  Adj Close         SYMBOL
# 0                0  2013-08-20  6.65  ...      755.0       6.65     INTEGRA.NS
# 1                1  2013-08-21  6.35  ...       10.0       6.35     INTEGRA.NS
# 2                2  2013-08-22  6.35  ...        0.0       6.35     INTEGRA.NS
# 3                3  2013-08-23  6.05  ...        5.0       6.05     INTEGRA.NS
# 4                4  2013-08-26  5.75  ...      100.0       5.75     INTEGRA.NS
# ...            ...         ...   ...  ...        ...        ...            ...
# 136405      136405  2020-08-10  2.45  ...  6890786.0       2.45  3IINFOTECH.NS
# 136406      136406  2020-08-11  2.55  ...  9923625.0       2.55  3IINFOTECH.NS
# 136407      136407  2020-08-12  2.65  ...  8559647.0       2.65  3IINFOTECH.NS
# 136408      136408  2020-08-13  2.75  ...  5351486.0       2.75  3IINFOTECH.NS
# 136409      136409  2020-08-14  2.85  ...  1762073.0       2.85  3IINFOTECH.NS
#
# ...
