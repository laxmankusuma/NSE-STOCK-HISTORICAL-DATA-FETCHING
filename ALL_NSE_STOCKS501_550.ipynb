# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa501 = data.DataReader('VBL.NS', 'yahoo', start_date, end_date)
panel_dataa502 = data.DataReader('DONEAR.NS', 'yahoo', start_date, end_date)
panel_dataa503 = data.DataReader('BANDHANBNK.NS', 'yahoo', start_date, end_date)
panel_dataa504 = data.DataReader('MCX.NS', 'yahoo', start_date, end_date)
panel_dataa505 = data.DataReader('NAUKRI.NS', 'yahoo', start_date, end_date)
panel_dataa506 = data.DataReader('IRB.NS', 'yahoo', start_date, end_date)
panel_dataa507 = data.DataReader('ALICON.NS', 'yahoo', start_date, end_date)
panel_dataa508 = data.DataReader('DEEPIND.NS', 'yahoo', start_date, end_date)
panel_dataa509 = data.DataReader('ICICIGI.NS', 'yahoo', start_date, end_date)
panel_dataa510 = data.DataReader('HONAUT.NS', 'yahoo', start_date, end_date)
panel_dataa511 = data.DataReader('IFCI.NS', 'yahoo', start_date, end_date)
panel_dataa512 = data.DataReader('PFS.NS', 'yahoo', start_date, end_date)
panel_dataa513 = data.DataReader('MANAKSIA.NS', 'yahoo', start_date, end_date)
panel_dataa514 = data.DataReader('CAPLIPOINT.NS', 'yahoo', start_date, end_date)
panel_dataa515 = data.DataReader('GSCLCEMENT.NS', 'yahoo', start_date, end_date)
panel_dataa516 = data.DataReader('CUMMINSIND.NS', 'yahoo', start_date, end_date)
panel_dataa517 = data.DataReader('CIGNITITEC.NS', 'yahoo', start_date, end_date)
panel_dataa518 = data.DataReader('GSPL.NS', 'yahoo', start_date, end_date)
panel_dataa519 = data.DataReader('JINDALSTEL.NS', 'yahoo', start_date, end_date)
panel_dataa520 = data.DataReader('SIS.NS', 'yahoo', start_date, end_date)
panel_dataa521 = data.DataReader('SMSLIFE.NS', 'yahoo', start_date, end_date)
panel_dataa522 = data.DataReader('INDOCO.NS', 'yahoo', start_date, end_date)
panel_dataa523 = data.DataReader('LINDEINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa524 = data.DataReader('JTEKTINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa525 = data.DataReader('ROSSARI.NS', 'yahoo', start_date, end_date)
panel_dataa526 = data.DataReader('CUB.NS', 'yahoo', start_date, end_date)
panel_dataa527 = data.DataReader('INDIANHUME.NS', 'yahoo', start_date, end_date)
panel_dataa528 = data.DataReader('NAHARPOLY.NS', 'yahoo', start_date, end_date)
panel_dataa529 = data.DataReader('ZENSARTECH.NS', 'yahoo', start_date, end_date)
panel_dataa530 = data.DataReader('ARVIND.NS', 'yahoo', start_date, end_date)
panel_dataa531 = data.DataReader('RTNPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa532 = data.DataReader('BSOFT.NS', 'yahoo', start_date, end_date)
panel_dataa533 = data.DataReader('BAJAJELEC.NS', 'yahoo', start_date, end_date)
panel_dataa534 = data.DataReader('BPCL.NS', 'yahoo', start_date, end_date)
panel_dataa535 = data.DataReader('RECLTD.NS', 'yahoo', start_date, end_date)
panel_dataa536 = data.DataReader('SREINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa537 = data.DataReader('QUICKHEAL.NS', 'yahoo', start_date, end_date)
panel_dataa538 = data.DataReader('SWSOLAR.NS', 'yahoo', start_date, end_date)
panel_dataa539 = data.DataReader('SUMICHEM.NS', 'yahoo', start_date, end_date)
panel_dataa540 = data.DataReader('RPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa541 = data.DataReader('CHOLAFIN.NS', 'yahoo', start_date, end_date)
panel_dataa542 = data.DataReader('BOMDYEING.NS', 'yahoo', start_date, end_date)
panel_dataa543 = data.DataReader('KOKUYOCMLN.NS', 'yahoo', start_date, end_date)
panel_dataa544 = data.DataReader('HPL.NS', 'yahoo', start_date, end_date)
panel_dataa545 = data.DataReader('MMTC.NS', 'yahoo', start_date, end_date)
panel_dataa546 = data.DataReader('ADANITRANS.NS', 'yahoo', start_date, end_date)
panel_dataa547 = data.DataReader('BLISSGVS.NS', 'yahoo', start_date, end_date)
panel_dataa548 = data.DataReader('ABFRL.NS', 'yahoo', start_date, end_date)
panel_dataa549 = data.DataReader('KAJARIACER.NS', 'yahoo', start_date, end_date)
panel_dataa550 = data.DataReader('BANKBARODA.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa501['SYMBOL']='VBL.NS'
panel_dataa502['SYMBOL']='DONEAR.NS'
panel_dataa503['SYMBOL']='BANDHANBNK.NS'
panel_dataa504['SYMBOL']='MCX.NS'
panel_dataa505['SYMBOL']='NAUKRI.NS'
panel_dataa506['SYMBOL']='IRB.NS'
panel_dataa507['SYMBOL']='ALICON.NS'
panel_dataa508['SYMBOL']='DEEPIND.NS'
panel_dataa509['SYMBOL']='ICICIGI.NS'
panel_dataa510['SYMBOL']='HONAUT.NS'
panel_dataa511['SYMBOL']='IFCI.NS'
panel_dataa512['SYMBOL']='PFS.NS'
panel_dataa513['SYMBOL']='MANAKSIA.NS'
panel_dataa514['SYMBOL']='CAPLIPOINT.NS'
panel_dataa515['SYMBOL']='GSCLCEMENT.NS'
panel_dataa516['SYMBOL']='CUMMINSIND.NS'
panel_dataa517['SYMBOL']='CIGNITITEC.NS'
panel_dataa518['SYMBOL']='GSPL.NS'
panel_dataa519['SYMBOL']='JINDALSTEL.NS'
panel_dataa520['SYMBOL']='SIS.NS'
panel_dataa521['SYMBOL']='SMSLIFE.NS'
panel_dataa522['SYMBOL']='INDOCO.NS'
panel_dataa523['SYMBOL']='LINDEINDIA.NS'
panel_dataa524['SYMBOL']='JTEKTINDIA.NS'
panel_dataa525['SYMBOL']='ROSSARI.NS'
panel_dataa526['SYMBOL']='CUB.NS'
panel_dataa527['SYMBOL']='INDIANHUME.NS'
panel_dataa528['SYMBOL']='NAHARPOLY.NS'
panel_dataa529['SYMBOL']='ZENSARTECH.NS'
panel_dataa530['SYMBOL']='ARVIND.NS'
panel_dataa531['SYMBOL']='RTNPOWER.NS'
panel_dataa532['SYMBOL']='BSOFT.NS'
panel_dataa533['SYMBOL']='BAJAJELEC.NS'
panel_dataa534['SYMBOL']='BPCL.NS'
panel_dataa535['SYMBOL']='RECLTD.NS'
panel_dataa536['SYMBOL']='SREINFRA.NS'
panel_dataa537['SYMBOL']='QUICKHEAL.NS'
panel_dataa538['SYMBOL']='SWSOLAR.NS'
panel_dataa539['SYMBOL']='SUMICHEM.NS'
panel_dataa540['SYMBOL']='RPOWER.NS'
panel_dataa541['SYMBOL']='CHOLAFIN.NS'
panel_dataa542['SYMBOL']='BOMDYEING.NS'
panel_dataa543['SYMBOL']='KOKUYOCMLN.NS'
panel_dataa544['SYMBOL']='HPL.NS'
panel_dataa545['SYMBOL']='MMTC.NS'
panel_dataa546['SYMBOL']='ADANITRANS.NS'
panel_dataa547['SYMBOL']='BLISSGVS.NS'
panel_dataa548['SYMBOL']='ABFRL.NS'
panel_dataa549['SYMBOL']='KAJARIACER.NS'
panel_dataa550['SYMBOL']='BANKBARODA.NS'

# %%
finall = pd.concat([panel_dataa501,
panel_dataa502,
panel_dataa503,
panel_dataa504,
panel_dataa505,
panel_dataa506,
panel_dataa507,
panel_dataa508,
panel_dataa509,
panel_dataa510,
panel_dataa511,
panel_dataa512,
panel_dataa513,
panel_dataa514,
panel_dataa515,
panel_dataa516,
panel_dataa517,
panel_dataa518,
panel_dataa519,
panel_dataa520,
panel_dataa521,
panel_dataa522,
panel_dataa523,
panel_dataa524,
panel_dataa525,
panel_dataa526,
panel_dataa527,
panel_dataa528,
panel_dataa529,
panel_dataa530,
panel_dataa531,
panel_dataa532,
panel_dataa533,
panel_dataa534,
panel_dataa535,
panel_dataa536,
panel_dataa537,
panel_dataa538,
panel_dataa539,
panel_dataa540,
panel_dataa541,
panel_dataa542,
panel_dataa543,
panel_dataa544,
panel_dataa545,
panel_dataa546,
panel_dataa547,
panel_dataa548,
panel_dataa549,
panel_dataa550])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_501_TO_550_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_501_TO_550_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_501_TO_550_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date  ...   Adj Close         SYMBOL
# 0                0  2016-11-08  ...  300.263245         VBL.NS
# 1                1  2016-11-09  ...  283.829437         VBL.NS
# 2                2  2016-11-10  ...  285.136017         VBL.NS
# 3                3  2016-11-11  ...  287.946228         VBL.NS
# 4                4  2016-11-15  ...  286.279907         VBL.NS
# ...            ...         ...  ...         ...            ...
# 151299      151299  2020-08-10  ...   48.549999  BANKBARODA.NS
# 151300      151300  2020-08-11  ...   47.099998  BANKBARODA.NS
# 151301      151301  2020-08-12  ...   48.599998  BANKBARODA.NS
# 151302      151302  2020-08-13  ...   48.099998  BANKBARODA.NS
# 151303      151303  2020-08-14  ...   46.099998  BANKBARODA.NS
#
# [151304 rows x 9 columns]
