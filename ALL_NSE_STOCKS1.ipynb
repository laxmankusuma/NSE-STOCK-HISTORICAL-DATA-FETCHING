# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

#fetching data
panel_dataa1 = data.DataReader('PRESSMN.NS', 'yahoo', start_date, end_date)
panel_dataa2 = data.DataReader('GEEKAYWIRE.NS', 'yahoo', start_date, end_date)
panel_dataa3 = data.DataReader('HITECH.NS', 'yahoo', start_date, end_date)
panel_dataa4 = data.DataReader('MANINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa5 = data.DataReader('STEELCITY.NS', 'yahoo', start_date, end_date)
panel_dataa6 = data.DataReader('GAYAHWS.NS', 'yahoo', start_date, end_date)
panel_dataa7 = data.DataReader('SUJANAUNI.NS', 'yahoo', start_date, end_date)
panel_dataa8 = data.DataReader('STRTECH.NS', 'yahoo', start_date, end_date)
panel_dataa9 = data.DataReader('CCCL.NS', 'yahoo', start_date, end_date)
panel_dataa10 = data.DataReader('KAPSTON.NS', 'yahoo', start_date, end_date)
panel_dataa11 = data.DataReader('TRIGYN.NS', 'yahoo', start_date, end_date)
panel_dataa12 = data.DataReader('AARVI.NS', 'yahoo', start_date, end_date)
panel_dataa13 = data.DataReader('DSSL.NS', 'yahoo', start_date, end_date)
panel_dataa14 = data.DataReader('ASHOKA.NS', 'yahoo', start_date, end_date)
panel_dataa15 = data.DataReader('HFCL.NS', 'yahoo', start_date, end_date)
panel_dataa16 = data.DataReader('STAMPEDE.NS', 'yahoo', start_date, end_date)
panel_dataa17 = data.DataReader('VIJIFIN.NS', 'yahoo', start_date, end_date)
panel_dataa18 = data.DataReader('VHL.NS', 'yahoo', start_date, end_date)
panel_dataa19 = data.DataReader('BHARATGEAR.NS', 'yahoo', start_date, end_date)
panel_dataa20 = data.DataReader('VIPULLTD.NS', 'yahoo', start_date, end_date)
panel_dataa21 = data.DataReader('INDBANK.NS', 'yahoo', start_date, end_date)
panel_dataa22 = data.DataReader('CAPTRUST.NS', 'yahoo', start_date, end_date)
panel_dataa23 = data.DataReader('PRECOT.NS', 'yahoo', start_date, end_date)
panel_dataa24 = data.DataReader('PRAENG.NS', 'yahoo', start_date, end_date)
panel_dataa25 = data.DataReader('NDRAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa26 = data.DataReader('KIOCL.NS', 'yahoo', start_date, end_date)
panel_dataa27 = data.DataReader('MARATHON.NS', 'yahoo', start_date, end_date)
panel_dataa28 = data.DataReader('CMICABLES.NS', 'yahoo', start_date, end_date)
panel_dataa29 = data.DataReader('ASIANHOTNR.NS', 'yahoo', start_date, end_date)
panel_dataa30 = data.DataReader('ARIES.NS', 'yahoo', start_date, end_date)
panel_dataa31 = data.DataReader('MURUDCERA.NS', 'yahoo', start_date, end_date)
panel_dataa32 = data.DataReader('POLYPLEX.NS', 'yahoo', start_date, end_date)
panel_dataa33 = data.DataReader('VINDHYATEL.NS', 'yahoo', start_date, end_date)
panel_dataa34 = data.DataReader('MARALOVER.NS', 'yahoo', start_date, end_date)
panel_dataa35 = data.DataReader('ORIENTBELL.NS', 'yahoo', start_date, end_date)
panel_dataa36 = data.DataReader('BIRLACABLE.NS', 'yahoo', start_date, end_date)
panel_dataa37 = data.DataReader('ENIL.NS', 'yahoo', start_date, end_date)
panel_dataa38 = data.DataReader('VASCONEQ.NS', 'yahoo', start_date, end_date)
panel_dataa39 = data.DataReader('TEXINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa40 = data.DataReader('MATRIMONY.NS', 'yahoo', start_date, end_date)
panel_dataa41 = data.DataReader('AJMERA.NS', 'yahoo', start_date, end_date)
panel_dataa42 = data.DataReader('UNIENTER.NS', 'yahoo', start_date, end_date)
panel_dataa43 = data.DataReader('AMJLAND.NS', 'yahoo', start_date, end_date)
panel_dataa44 = data.DataReader('NAHARCAP.NS', 'yahoo', start_date, end_date)
panel_dataa45 = data.DataReader('JVLAGRO.NS', 'yahoo', start_date, end_date)
panel_dataa46 = data.DataReader('BILENERGY.NS', 'yahoo', start_date, end_date)
panel_dataa47 = data.DataReader('SATIA.NS', 'yahoo', start_date, end_date)
panel_dataa48 = data.DataReader('VSTTILLERS.NS', 'yahoo', start_date, end_date)
panel_dataa49 = data.DataReader('RAJTV.NS', 'yahoo', start_date, end_date)
panel_dataa50 = data.DataReader('NAHARSPING.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1['SYMBOL']='PRESSMN.NS'
panel_dataa2['SYMBOL']='GEEKAYWIRE.NS'
panel_dataa3['SYMBOL']='HITECH.NS'
panel_dataa4['SYMBOL']='MANINFRA.NS'
panel_dataa5['SYMBOL']='STEELCITY.NS'
panel_dataa6['SYMBOL']='GAYAHWS.NS'
panel_dataa7['SYMBOL']='SUJANAUNI.NS'
panel_dataa8['SYMBOL']='STRTECH.NS'
panel_dataa9['SYMBOL']='CCCL.NS'
panel_dataa10['SYMBOL']='KAPSTON.NS'
panel_dataa11['SYMBOL']='TRIGYN.NS'
panel_dataa12['SYMBOL']='AARVI.NS'
panel_dataa13['SYMBOL']='DSSL.NS'
panel_dataa14['SYMBOL']='ASHOKA.NS'
panel_dataa15['SYMBOL']='HFCL.NS'
panel_dataa16['SYMBOL']='STAMPEDE.NS'
panel_dataa17['SYMBOL']='VIJIFIN.NS'
panel_dataa18['SYMBOL']='VHL.NS'
panel_dataa19['SYMBOL']='BHARATGEAR.NS'
panel_dataa20['SYMBOL']='VIPULLTD.NS'
panel_dataa21['SYMBOL']='INDBANK.NS'
panel_dataa22['SYMBOL']='CAPTRUST.NS'
panel_dataa23['SYMBOL']='PRECOT.NS'
panel_dataa24['SYMBOL']='PRAENG.NS'
panel_dataa25['SYMBOL']='NDRAUTO.NS'
panel_dataa26['SYMBOL']='KIOCL.NS'
panel_dataa27['SYMBOL']='MARATHON.NS'
panel_dataa28['SYMBOL']='CMICABLES.NS'
panel_dataa29['SYMBOL']='ASIANHOTNR.NS'
panel_dataa30['SYMBOL']='ARIES.NS'
panel_dataa31['SYMBOL']='MURUDCERA.NS'
panel_dataa32['SYMBOL']='POLYPLEX.NS'
panel_dataa33['SYMBOL']='VINDHYATEL.NS'
panel_dataa34['SYMBOL']='MARALOVER.NS'
panel_dataa35['SYMBOL']='ORIENTBELL.NS'
panel_dataa36['SYMBOL']='BIRLACABLE.NS'
panel_dataa37['SYMBOL']='ENIL.NS'
panel_dataa38['SYMBOL']='VASCONEQ.NS'
panel_dataa39['SYMBOL']='TEXINFRA.NS'
panel_dataa40['SYMBOL']='MATRIMONY.NS'
panel_dataa41['SYMBOL']='AJMERA.NS'
panel_dataa42['SYMBOL']='UNIENTER.NS'
panel_dataa43['SYMBOL']='AMJLAND.NS'
panel_dataa44['SYMBOL']='NAHARCAP.NS'
panel_dataa45['SYMBOL']='JVLAGRO.NS'
panel_dataa46['SYMBOL']='BILENERGY.NS'
panel_dataa47['SYMBOL']='SATIA.NS'
panel_dataa48['SYMBOL']='VSTTILLERS.NS'
panel_dataa49['SYMBOL']='RAJTV.NS'
panel_dataa50['SYMBOL']='NAHARSPING.NS'

# %%
finall = pd.concat([panel_dataa1,
panel_dataa2,
panel_dataa3,
panel_dataa4,
panel_dataa5,
panel_dataa6,
panel_dataa7,
panel_dataa8,
panel_dataa9,
panel_dataa10,
panel_dataa11,
panel_dataa12,
panel_dataa13,
panel_dataa14,
panel_dataa15,
panel_dataa16,
panel_dataa17,
panel_dataa18,
panel_dataa19,
panel_dataa20,
panel_dataa21,
panel_dataa22,
panel_dataa23,
panel_dataa24,
panel_dataa25,
panel_dataa26,
panel_dataa27,
panel_dataa28,
panel_dataa29,
panel_dataa30,
panel_dataa31,
panel_dataa32,
panel_dataa33,
panel_dataa34,
panel_dataa35,
panel_dataa36,
panel_dataa37,
panel_dataa38,
panel_dataa39,
panel_dataa40,
panel_dataa41,
panel_dataa42,
panel_dataa43,
panel_dataa44,
panel_dataa45,
panel_dataa46,
panel_dataa47,
panel_dataa48,
panel_dataa49,
panel_dataa50])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1_TO_50_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1_TO_50_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1_TO_50_start_to_15082020.csv")

# %%
readdf
# Out:
#         Unnamed: 0        Date       High  ...    Volume  Adj Close         SYMBOL
# 0                0  2005-01-05  48.000000  ...   53430.0  27.258549     PRESSMN.NS
# 1                1  2005-01-06  37.000000  ...    9700.0  21.814053     PRESSMN.NS
# 2                2  2005-01-07  24.200001  ...     893.0  17.451241     PRESSMN.NS
# 3                3  2005-01-10  19.400000  ...    1000.0  13.989837     PRESSMN.NS
# 4                4  2005-01-11  15.550000  ...    1000.0  11.213504     PRESSMN.NS
# ...            ...         ...        ...  ...       ...        ...            ...
# 136510      136510  2020-08-10  34.200001  ...   17702.0  33.700001  NAHARSPING.NS
# 136511      136511  2020-08-11  34.500000  ...   10923.0  33.900002  NAHARSPING.NS
# 136512      136512  2020-08-12  36.200001  ...   35545.0  35.599998  NAHARSPING.NS
# 136513      136513  2020-08-13  38.000000  ...   44600.0  36.400002  NAHARSPING.NS
# ...
