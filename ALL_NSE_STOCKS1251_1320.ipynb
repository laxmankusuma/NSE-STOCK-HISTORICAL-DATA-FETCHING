# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa1251 = data.DataReader('KPITTECH.NS', 'yahoo', start_date, end_date)
panel_dataa1252 = data.DataReader('SALZERELEC.NS', 'yahoo', start_date, end_date)
panel_dataa1253 = data.DataReader('NITINSPIN.NS', 'yahoo', start_date, end_date)
panel_dataa1254 = data.DataReader('SUBEX.NS', 'yahoo', start_date, end_date)
panel_dataa1255 = data.DataReader('STEELXIND.NS', 'yahoo', start_date, end_date)
panel_dataa1256 = data.DataReader('TVSELECT.NS', 'yahoo', start_date, end_date)
panel_dataa1257 = data.DataReader('GRSE.NS', 'yahoo', start_date, end_date)
panel_dataa1258 = data.DataReader('LGBFORGE.NS', 'yahoo', start_date, end_date)
panel_dataa1259 = data.DataReader('ALCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa1260 = data.DataReader('NAHARINDUS.NS', 'yahoo', start_date, end_date)
panel_dataa1261 = data.DataReader('JISLJALEQS.NS', 'yahoo', start_date, end_date)
panel_dataa1262 = data.DataReader('SANWARIA.NS', 'yahoo', start_date, end_date)
panel_dataa1263 = data.DataReader('ADSL.NS', 'yahoo', start_date, end_date)
panel_dataa1264 = data.DataReader('BALLARPUR.NS', 'yahoo', start_date, end_date)
panel_dataa1265 = data.DataReader('UTTAMSTL.NS', 'yahoo', start_date, end_date)
panel_dataa1266 = data.DataReader('RUCHINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa1267 = data.DataReader('SEYAIND.NS', 'yahoo', start_date, end_date)
panel_dataa1268 = data.DataReader('RGL.NS', 'yahoo', start_date, end_date)
panel_dataa1269 = data.DataReader('SALASAR.NS', 'yahoo', start_date, end_date)
panel_dataa1270 = data.DataReader('YESBANK.NS', 'yahoo', start_date, end_date)
panel_dataa1271 = data.DataReader('LOKESHMACH.NS', 'yahoo', start_date, end_date)
panel_dataa1272 = data.DataReader('NOIDATOLL.NS', 'yahoo', start_date, end_date)
panel_dataa1273 = data.DataReader('PITTIENG.NS', 'yahoo', start_date, end_date)
panel_dataa1274 = data.DataReader('KIRLFER.NS', 'yahoo', start_date, end_date)
panel_dataa1275 = data.DataReader('UJAAS.NS', 'yahoo', start_date, end_date)
panel_dataa1276 = data.DataReader('HINDMOTORS.NS', 'yahoo', start_date, end_date)
panel_dataa1277 = data.DataReader('CENTEXT.NS', 'yahoo', start_date, end_date)
panel_dataa1278 = data.DataReader('IMPAL.NS', 'yahoo', start_date, end_date)
panel_dataa1279 = data.DataReader('BIRLATYRE.NS', 'yahoo', start_date, end_date)
panel_dataa1280 = data.DataReader('COX&KINGS.NS', 'yahoo', start_date, end_date)
panel_dataa1281 = data.DataReader('GVKPIL.NS', 'yahoo', start_date, end_date)
panel_dataa1282 = data.DataReader('BCP.NS', 'yahoo', start_date, end_date)
panel_dataa1283 = data.DataReader('PSL.NS', 'yahoo', start_date, end_date)
panel_dataa1284 = data.DataReader('DQE.NS', 'yahoo', start_date, end_date)
panel_dataa1285 = data.DataReader('NILASPACES.NS', 'yahoo', start_date, end_date)
panel_dataa1286 = data.DataReader('ELGIEQUIP.NS', 'yahoo', start_date, end_date)
panel_dataa1287 = data.DataReader('TALWALKARS.NS', 'yahoo', start_date, end_date)
panel_dataa1288 = data.DataReader('LPDC.NS', 'yahoo', start_date, end_date)
panel_dataa1289 = data.DataReader('SPTL.NS', 'yahoo', start_date, end_date)
panel_dataa1290 = data.DataReader('MERCATOR.NS', 'yahoo', start_date, end_date)
panel_dataa1291 = data.DataReader('LEMONTREE.NS', 'yahoo', start_date, end_date)
panel_dataa1292 = data.DataReader('VIKASPROP.NS', 'yahoo', start_date, end_date)
panel_dataa1293 = data.DataReader('TALWGYM.NS', 'yahoo', start_date, end_date)
panel_dataa1294 = data.DataReader('PEARLPOLY.NS', 'yahoo', start_date, end_date)
panel_dataa1295 = data.DataReader('WINDMACHIN.NS', 'yahoo', start_date, end_date)
panel_dataa1296 = data.DataReader('MANAKSTEEL.NS', 'yahoo', start_date, end_date)
panel_dataa1297 = data.DataReader('NECCLTD.NS', 'yahoo', start_date, end_date)
panel_dataa1298 = data.DataReader('RANASUG.NS', 'yahoo', start_date, end_date)
panel_dataa1299 = data.DataReader('PRAKASHSTL.NS', 'yahoo', start_date, end_date)
panel_dataa1300 = data.DataReader('CHROMATIC.NS', 'yahoo', start_date, end_date)
panel_dataa1301 = data.DataReader('XPROINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1302 = data.DataReader('MITTAL.NS', 'yahoo', start_date, end_date)
panel_dataa1303 = data.DataReader('AUTOIND.NS', 'yahoo', start_date, end_date)
panel_dataa1304 = data.DataReader('TRF.NS', 'yahoo', start_date, end_date)
panel_dataa1305 = data.DataReader('BOROLTD.NS', 'yahoo', start_date, end_date)
panel_dataa1306 = data.DataReader('MODIRUBBER.NS', 'yahoo', start_date, end_date)
panel_dataa1307 = data.DataReader('BALAXI.NS', 'yahoo', start_date, end_date)
panel_dataa1308 = data.DataReader('OMKARCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa1309 = data.DataReader('VARDMNPOLY.NS', 'yahoo', start_date, end_date)
panel_dataa1310 = data.DataReader('VARROC.NS', 'yahoo', start_date, end_date)
panel_dataa1311 = data.DataReader('SETUINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa1312 = data.DataReader('BODALCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa1313 = data.DataReader('EROSMEDIA.NS', 'yahoo', start_date, end_date)
panel_dataa1314 = data.DataReader('GOENKA.NS', 'yahoo', start_date, end_date)
panel_dataa1315 = data.DataReader('TEXMOPIPES.NS', 'yahoo', start_date, end_date)
panel_dataa1316 = data.DataReader('COMPINFO.NS', 'yahoo', start_date, end_date)
panel_dataa1317 = data.DataReader('MIC.NS', 'yahoo', start_date, end_date)
panel_dataa1318 = data.DataReader('TCIDEVELOP.NS', 'yahoo', start_date, end_date)
panel_dataa1319 = data.DataReader('KSK.NS', 'yahoo', start_date, end_date)
panel_dataa1320 = data.DataReader('KGL.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1251['SYMBOL']='KPITTECH.NS'
panel_dataa1252['SYMBOL']='SALZERELEC.NS'
panel_dataa1253['SYMBOL']='NITINSPIN.NS'
panel_dataa1254['SYMBOL']='SUBEX.NS'
panel_dataa1255['SYMBOL']='STEELXIND.NS'
panel_dataa1256['SYMBOL']='TVSELECT.NS'
panel_dataa1257['SYMBOL']='GRSE.NS'
panel_dataa1258['SYMBOL']='LGBFORGE.NS'
panel_dataa1259['SYMBOL']='ALCHEM.NS'
panel_dataa1260['SYMBOL']='NAHARINDUS.NS'
panel_dataa1261['SYMBOL']='JISLJALEQS.NS'
panel_dataa1262['SYMBOL']='SANWARIA.NS'
panel_dataa1263['SYMBOL']='ADSL.NS'
panel_dataa1264['SYMBOL']='BALLARPUR.NS'
panel_dataa1265['SYMBOL']='UTTAMSTL.NS'
panel_dataa1266['SYMBOL']='RUCHINFRA.NS'
panel_dataa1267['SYMBOL']='SEYAIND.NS'
panel_dataa1268['SYMBOL']='RGL.NS'
panel_dataa1269['SYMBOL']='SALASAR.NS'
panel_dataa1270['SYMBOL']='YESBANK.NS'
panel_dataa1271['SYMBOL']='LOKESHMACH.NS'
panel_dataa1272['SYMBOL']='NOIDATOLL.NS'
panel_dataa1273['SYMBOL']='PITTIENG.NS'
panel_dataa1274['SYMBOL']='KIRLFER.NS'
panel_dataa1275['SYMBOL']='UJAAS.NS'
panel_dataa1276['SYMBOL']='HINDMOTORS.NS'
panel_dataa1277['SYMBOL']='CENTEXT.NS'
panel_dataa1278['SYMBOL']='IMPAL.NS'
panel_dataa1279['SYMBOL']='BIRLATYRE.NS'
panel_dataa1280['SYMBOL']='COX&KINGS.NS'
panel_dataa1281['SYMBOL']='GVKPIL.NS'
panel_dataa1282['SYMBOL']='BCP.NS'
panel_dataa1283['SYMBOL']='PSL.NS'
panel_dataa1284['SYMBOL']='DQE.NS'
panel_dataa1285['SYMBOL']='NILASPACES.NS'
panel_dataa1286['SYMBOL']='ELGIEQUIP.NS'
panel_dataa1287['SYMBOL']='TALWALKARS.NS'
panel_dataa1288['SYMBOL']='LPDC.NS'
panel_dataa1289['SYMBOL']='SPTL.NS'
panel_dataa1290['SYMBOL']='MERCATOR.NS'
panel_dataa1291['SYMBOL']='LEMONTREE.NS'
panel_dataa1292['SYMBOL']='VIKASPROP.NS'
panel_dataa1293['SYMBOL']='TALWGYM.NS'
panel_dataa1294['SYMBOL']='PEARLPOLY.NS'
panel_dataa1295['SYMBOL']='WINDMACHIN.NS'
panel_dataa1296['SYMBOL']='MANAKSTEEL.NS'
panel_dataa1297['SYMBOL']='NECCLTD.NS'
panel_dataa1298['SYMBOL']='RANASUG.NS'
panel_dataa1299['SYMBOL']='PRAKASHSTL.NS'
panel_dataa1300['SYMBOL']='CHROMATIC.NS'
panel_dataa1301['SYMBOL']='XPROINDIA.NS'
panel_dataa1302['SYMBOL']='MITTAL.NS'
panel_dataa1303['SYMBOL']='AUTOIND.NS'
panel_dataa1304['SYMBOL']='TRF.NS'
panel_dataa1305['SYMBOL']='BOROLTD.NS'
panel_dataa1306['SYMBOL']='MODIRUBBER.NS'
panel_dataa1307['SYMBOL']='BALAXI.NS'
panel_dataa1308['SYMBOL']='OMKARCHEM.NS'
panel_dataa1309['SYMBOL']='VARDMNPOLY.NS'
panel_dataa1310['SYMBOL']='VARROC.NS'
panel_dataa1311['SYMBOL']='SETUINFRA.NS'
panel_dataa1312['SYMBOL']='BODALCHEM.NS'
panel_dataa1313['SYMBOL']='EROSMEDIA.NS'
panel_dataa1314['SYMBOL']='GOENKA.NS'
panel_dataa1315['SYMBOL']='TEXMOPIPES.NS'
panel_dataa1316['SYMBOL']='COMPINFO.NS'
panel_dataa1317['SYMBOL']='MIC.NS'
panel_dataa1318['SYMBOL']='TCIDEVELOP.NS'
panel_dataa1319['SYMBOL']='KSK.NS'
panel_dataa1320['SYMBOL']='KGL.NS'

# %%
finall = pd.concat([panel_dataa1251,
panel_dataa1252,
panel_dataa1253,
panel_dataa1254,
panel_dataa1255,
panel_dataa1256,
panel_dataa1257,
panel_dataa1258,
panel_dataa1259,
panel_dataa1260,
panel_dataa1261,
panel_dataa1262,
panel_dataa1263,
panel_dataa1264,
panel_dataa1265,
panel_dataa1266,
panel_dataa1267,
panel_dataa1268,
panel_dataa1269,
panel_dataa1270,
panel_dataa1271,
panel_dataa1272,
panel_dataa1273,
panel_dataa1274,
panel_dataa1275,
panel_dataa1276,
panel_dataa1277,
panel_dataa1278,
panel_dataa1279,
panel_dataa1280,
panel_dataa1281,
panel_dataa1282,
panel_dataa1283,
panel_dataa1284,
panel_dataa1285,
panel_dataa1286,
panel_dataa1287,
panel_dataa1288,
panel_dataa1289,
panel_dataa1290,
panel_dataa1291,
panel_dataa1292,
panel_dataa1293,
panel_dataa1294,
panel_dataa1295,
panel_dataa1296,
panel_dataa1297,
panel_dataa1298,
panel_dataa1299,
panel_dataa1300,
panel_dataa1301,
panel_dataa1302,
panel_dataa1303,
panel_dataa1304,
panel_dataa1305,
panel_dataa1306,
panel_dataa1307,
panel_dataa1308,
panel_dataa1309,
panel_dataa1310,
panel_dataa1311,
panel_dataa1312,
panel_dataa1313,
panel_dataa1314,
panel_dataa1315,
panel_dataa1316,
panel_dataa1317,
panel_dataa1318,
panel_dataa1319,
panel_dataa1320])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1251_TO_1320_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1251_TO_1320_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1251_TO_1320_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...     Volume   Adj Close       SYMBOL
# 0                0  2019-04-22  103.949997  ...  1066838.0  101.592178  KPITTECH.NS
# 1                1  2019-04-23  109.099998  ...   746528.0  106.625366  KPITTECH.NS
# 2                2  2019-04-24  114.550003  ...   233998.0  111.951759  KPITTECH.NS
# 3                3  2019-04-25  118.300003  ...   941577.0  108.628868  KPITTECH.NS
# 4                4  2019-04-26  111.000000  ...  1886188.0  106.185577  KPITTECH.NS
# ...            ...         ...         ...  ...        ...         ...          ...
# 173963      173963  2020-08-10    0.500000  ...   873495.0    0.450000       KGL.NS
# 173964      173964  2020-08-11    0.500000  ...   531354.0    0.500000       KGL.NS
# 173965      173965  2020-08-12    0.500000  ...  1094663.0    0.450000       KGL.NS
# 173966      173966  2020-08-13    0.500000  ...   799606.0    0.450000       KGL.NS
# ...
