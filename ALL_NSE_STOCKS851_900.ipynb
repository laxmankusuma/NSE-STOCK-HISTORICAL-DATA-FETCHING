# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa851 = data.DataReader('GAYAPROJ.NS', 'yahoo', start_date, end_date)
panel_dataa852 = data.DataReader('SPENCERS.NS', 'yahoo', start_date, end_date)
panel_dataa853 = data.DataReader('MGL.NS', 'yahoo', start_date, end_date)
panel_dataa854 = data.DataReader('SHALPAINTS.NS', 'yahoo', start_date, end_date)
panel_dataa855 = data.DataReader('JAGRAN.NS', 'yahoo', start_date, end_date)
panel_dataa856 = data.DataReader('SUNDARMHLD.NS', 'yahoo', start_date, end_date)
panel_dataa857 = data.DataReader('COLPAL.NS', 'yahoo', start_date, end_date)
panel_dataa858 = data.DataReader('LICHSGFIN.NS', 'yahoo', start_date, end_date)
panel_dataa859 = data.DataReader('KITEX.NS', 'yahoo', start_date, end_date)
panel_dataa860 = data.DataReader('L&TFH.NS', 'yahoo', start_date, end_date)
panel_dataa861 = data.DataReader('HDFCLIFE.NS', 'yahoo', start_date, end_date)
panel_dataa862 = data.DataReader('GESHIP.NS', 'yahoo', start_date, end_date)
panel_dataa863 = data.DataReader('ABBOTINDIA.NS', 'yahoo', start_date, end_date)
panel_dataa864 = data.DataReader('PIDILITIND.NS', 'yahoo', start_date, end_date)
panel_dataa865 = data.DataReader('ADANIENT.NS', 'yahoo', start_date, end_date)
panel_dataa866 = data.DataReader('JUSTDIAL.NS', 'yahoo', start_date, end_date)
panel_dataa867 = data.DataReader('TV18BRDCST.NS', 'yahoo', start_date, end_date)
panel_dataa868 = data.DataReader('CROMPTON.NS', 'yahoo', start_date, end_date)
panel_dataa869 = data.DataReader('INDIAGLYCO.NS', 'yahoo', start_date, end_date)
panel_dataa870 = data.DataReader('SHILPAMED.NS', 'yahoo', start_date, end_date)
panel_dataa871 = data.DataReader('CANBK.NS', 'yahoo', start_date, end_date)
panel_dataa872 = data.DataReader('GRAPHITE.NS', 'yahoo', start_date, end_date)
panel_dataa873 = data.DataReader('CHAMBLFERT.NS', 'yahoo', start_date, end_date)
panel_dataa874 = data.DataReader('IPCALAB.NS', 'yahoo', start_date, end_date)
panel_dataa875 = data.DataReader('JSWSTEEL.NS', 'yahoo', start_date, end_date)
panel_dataa876 = data.DataReader('NESTLEIND.NS', 'yahoo', start_date, end_date)
panel_dataa877 = data.DataReader('AYMSYNTEX.NS', 'yahoo', start_date, end_date)
panel_dataa878 = data.DataReader('BAJFINANCE.NS', 'yahoo', start_date, end_date)
panel_dataa879 = data.DataReader('BALRAMCHIN.NS', 'yahoo', start_date, end_date)
panel_dataa880 = data.DataReader('RANEHOLDIN.NS', 'yahoo', start_date, end_date)
panel_dataa881 = data.DataReader('INDUSINDBK.NS', 'yahoo', start_date, end_date)
panel_dataa882 = data.DataReader('ELECTHERM.NS', 'yahoo', start_date, end_date)
panel_dataa883 = data.DataReader('DCMSHRIRAM.NS', 'yahoo', start_date, end_date)
panel_dataa884 = data.DataReader('ISEC.NS', 'yahoo', start_date, end_date)
panel_dataa885 = data.DataReader('KMSUGAR.NS', 'yahoo', start_date, end_date)
panel_dataa886 = data.DataReader('IOC.NS', 'yahoo', start_date, end_date)
panel_dataa887 = data.DataReader('KPRMILL.NS', 'yahoo', start_date, end_date)
panel_dataa888 = data.DataReader('SHEMAROO.NS', 'yahoo', start_date, end_date)
panel_dataa889 = data.DataReader('RADICO.NS', 'yahoo', start_date, end_date)
panel_dataa890 = data.DataReader('BALMLAWRIE.NS', 'yahoo', start_date, end_date)
panel_dataa891 = data.DataReader('DWARKESH.NS', 'yahoo', start_date, end_date)
panel_dataa892 = data.DataReader('INSECTICID.NS', 'yahoo', start_date, end_date)
panel_dataa893 = data.DataReader('XCHANGING.NS', 'yahoo', start_date, end_date)
panel_dataa894 = data.DataReader('ONGC.NS', 'yahoo', start_date, end_date)
panel_dataa895 = data.DataReader('HAVELLS.NS', 'yahoo', start_date, end_date)
panel_dataa896 = data.DataReader('FLUOROCHEM.NS', 'yahoo', start_date, end_date)
panel_dataa897 = data.DataReader('BHARATRAS.NS', 'yahoo', start_date, end_date)
panel_dataa898 = data.DataReader('GRINDWELL.NS', 'yahoo', start_date, end_date)
panel_dataa899 = data.DataReader('RALLIS.NS', 'yahoo', start_date, end_date)
panel_dataa900 = data.DataReader('COROMANDEL.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa851['SYMBOL']='GAYAPROJ.NS'
panel_dataa852['SYMBOL']='SPENCERS.NS'
panel_dataa853['SYMBOL']='MGL.NS'
panel_dataa854['SYMBOL']='SHALPAINTS.NS'
panel_dataa855['SYMBOL']='JAGRAN.NS'
panel_dataa856['SYMBOL']='SUNDARMHLD.NS'
panel_dataa857['SYMBOL']='COLPAL.NS'
panel_dataa858['SYMBOL']='LICHSGFIN.NS'
panel_dataa859['SYMBOL']='KITEX.NS'
panel_dataa860['SYMBOL']='L&TFH.NS'
panel_dataa861['SYMBOL']='HDFCLIFE.NS'
panel_dataa862['SYMBOL']='GESHIP.NS'
panel_dataa863['SYMBOL']='ABBOTINDIA.NS'
panel_dataa864['SYMBOL']='PIDILITIND.NS'
panel_dataa865['SYMBOL']='ADANIENT.NS'
panel_dataa866['SYMBOL']='JUSTDIAL.NS'
panel_dataa867['SYMBOL']='TV18BRDCST.NS'
panel_dataa868['SYMBOL']='CROMPTON.NS'
panel_dataa869['SYMBOL']='INDIAGLYCO.NS'
panel_dataa870['SYMBOL']='SHILPAMED.NS'
panel_dataa871['SYMBOL']='CANBK.NS'
panel_dataa872['SYMBOL']='GRAPHITE.NS'
panel_dataa873['SYMBOL']='CHAMBLFERT.NS'
panel_dataa874['SYMBOL']='IPCALAB.NS'
panel_dataa875['SYMBOL']='JSWSTEEL.NS'
panel_dataa876['SYMBOL']='NESTLEIND.NS'
panel_dataa877['SYMBOL']='AYMSYNTEX.NS'
panel_dataa878['SYMBOL']='BAJFINANCE.NS'
panel_dataa879['SYMBOL']='BALRAMCHIN.NS'
panel_dataa880['SYMBOL']='RANEHOLDIN.NS'
panel_dataa881['SYMBOL']='INDUSINDBK.NS'
panel_dataa882['SYMBOL']='ELECTHERM.NS'
panel_dataa883['SYMBOL']='DCMSHRIRAM.NS'
panel_dataa884['SYMBOL']='ISEC.NS'
panel_dataa885['SYMBOL']='KMSUGAR.NS'
panel_dataa886['SYMBOL']='IOC.NS'
panel_dataa887['SYMBOL']='KPRMILL.NS'
panel_dataa888['SYMBOL']='SHEMAROO.NS'
panel_dataa889['SYMBOL']='RADICO.NS'
panel_dataa890['SYMBOL']='BALMLAWRIE.NS'
panel_dataa891['SYMBOL']='DWARKESH.NS'
panel_dataa892['SYMBOL']='INSECTICID.NS'
panel_dataa893['SYMBOL']='XCHANGING.NS'
panel_dataa894['SYMBOL']='ONGC.NS'
panel_dataa895['SYMBOL']='HAVELLS.NS'
panel_dataa896['SYMBOL']='FLUOROCHEM.NS'
panel_dataa897['SYMBOL']='BHARATRAS.NS'
panel_dataa898['SYMBOL']='GRINDWELL.NS'
panel_dataa899['SYMBOL']='RALLIS.NS'
panel_dataa900['SYMBOL']='COROMANDEL.NS'

# %%
finall = pd.concat([panel_dataa851,
panel_dataa852,
panel_dataa853,
panel_dataa854,
panel_dataa855,
panel_dataa856,
panel_dataa857,
panel_dataa858,
panel_dataa859,
panel_dataa860,
panel_dataa861,
panel_dataa862,
panel_dataa863,
panel_dataa864,
panel_dataa865,
panel_dataa866,
panel_dataa867,
panel_dataa868,
panel_dataa869,
panel_dataa870,
panel_dataa871,
panel_dataa872,
panel_dataa873,
panel_dataa874,
panel_dataa875,
panel_dataa876,
panel_dataa877,
panel_dataa878,
panel_dataa879,
panel_dataa880,
panel_dataa881,
panel_dataa882,
panel_dataa883,
panel_dataa884,
panel_dataa885,
panel_dataa886,
panel_dataa887,
panel_dataa888,
panel_dataa889,
panel_dataa890,
panel_dataa891,
panel_dataa892,
panel_dataa893,
panel_dataa894,
panel_dataa895,
panel_dataa896,
panel_dataa897,
panel_dataa898,
panel_dataa899,
panel_dataa900])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_851_TO_900_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_851_TO_900_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_851_TO_900_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...    Volume   Adj Close         SYMBOL
# 0                0  2011-08-22   24.759501  ...   51287.0   10.943792    GAYAPROJ.NS
# 1                1  2011-08-23   25.099501  ...   20002.0   11.337913    GAYAPROJ.NS
# 2                2  2011-08-24   27.520399  ...  196446.0   12.037803    GAYAPROJ.NS
# 3                3  2011-08-25   27.682400  ...  139107.0   12.188800    GAYAPROJ.NS
# 4                4  2011-08-26   26.880800  ...   84671.0   11.256886    GAYAPROJ.NS
# ...            ...         ...         ...  ...       ...         ...            ...
# 167740      167740  2020-08-10  808.750000  ...  389037.0  792.349976  COROMANDEL.NS
# 167741      167741  2020-08-11  798.700012  ...  354111.0  778.900024  COROMANDEL.NS
# 167742      167742  2020-08-12  782.000000  ...  522306.0  765.950012  COROMANDEL.NS
# 167743      167743  2020-08-13  774.299988  ...  467972.0  747.900024  COROMANDEL.NS
# ...
