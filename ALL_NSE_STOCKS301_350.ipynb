# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'

# %%
panel_dataa301 = data.DataReader('HCC.NS', 'yahoo', start_date, end_date)
panel_dataa302 = data.DataReader('UFO.NS', 'yahoo', start_date, end_date)
panel_dataa303 = data.DataReader('RAJRATAN.NS', 'yahoo', start_date, end_date)
panel_dataa304 = data.DataReader('MAWANASUG.NS', 'yahoo', start_date, end_date)
panel_dataa305 = data.DataReader('SYNCOM.NS', 'yahoo', start_date, end_date)
panel_dataa306 = data.DataReader('IZMO.NS', 'yahoo', start_date, end_date)
panel_dataa307 = data.DataReader('DECCANCE.NS', 'yahoo', start_date, end_date)
panel_dataa308 = data.DataReader('SUZLON.NS', 'yahoo', start_date, end_date)
panel_dataa309 = data.DataReader('TRIL.NS', 'yahoo', start_date, end_date)
panel_dataa310 = data.DataReader('SYMPHONY.NS', 'yahoo', start_date, end_date)
panel_dataa311 = data.DataReader('HINDCOMPOS.NS', 'yahoo', start_date, end_date)
panel_dataa312 = data.DataReader('IFBAGRO.NS', 'yahoo', start_date, end_date)
panel_dataa313 = data.DataReader('PAPERPROD.NS', 'yahoo', start_date, end_date)
panel_dataa314 = data.DataReader('AAVAS.NS', 'yahoo', start_date, end_date)
panel_dataa315 = data.DataReader('PRSMJOHNSN.NS', 'yahoo', start_date, end_date)
panel_dataa316 = data.DataReader('APARINDS.NS', 'yahoo', start_date, end_date)
panel_dataa317 = data.DataReader('ALLCARGO.NS', 'yahoo', start_date, end_date)
panel_dataa318 = data.DataReader('OCCL.NS', 'yahoo', start_date, end_date)
panel_dataa319 = data.DataReader('RSYSTEMS.NS', 'yahoo', start_date, end_date)
panel_dataa320 = data.DataReader('DFMFOODS.NS', 'yahoo', start_date, end_date)
panel_dataa321 = data.DataReader('MUNJALSHOW.NS', 'yahoo', start_date, end_date)
panel_dataa322 = data.DataReader('TVTODAY.NS', 'yahoo', start_date, end_date)
panel_dataa323 = data.DataReader('NBVENTURES.NS', 'yahoo', start_date, end_date)
panel_dataa324 = data.DataReader('BRIGADE.NS', 'yahoo', start_date, end_date)
panel_dataa325 = data.DataReader('SEQUENT.NS', 'yahoo', start_date, end_date)
panel_dataa326 = data.DataReader('TBZ.NS', 'yahoo', start_date, end_date)
panel_dataa327 = data.DataReader('TCPLPACK.NS', 'yahoo', start_date, end_date)
panel_dataa328 = data.DataReader('GARFIBRES.NS', 'yahoo', start_date, end_date)
panel_dataa329 = data.DataReader('VIDEOIND.NS', 'yahoo', start_date, end_date)
panel_dataa330 = data.DataReader('MOREPENLAB.NS', 'yahoo', start_date, end_date)
panel_dataa331 = data.DataReader('ENERGYDEV.NS', 'yahoo', start_date, end_date)
panel_dataa332 = data.DataReader('GFLLIMITED.NS', 'yahoo', start_date, end_date)
panel_dataa333 = data.DataReader('ROSSELLIND.NS', 'yahoo', start_date, end_date)
panel_dataa334 = data.DataReader('PRESTIGE.NS', 'yahoo', start_date, end_date)
panel_dataa335 = data.DataReader('GREENLAM.NS', 'yahoo', start_date, end_date)
panel_dataa336 = data.DataReader('SUVENPHAR.NS', 'yahoo', start_date, end_date)
panel_dataa337 = data.DataReader('ORIENTREF.NS', 'yahoo', start_date, end_date)
panel_dataa338 = data.DataReader('PENINLAND.NS', 'yahoo', start_date, end_date)
panel_dataa339 = data.DataReader('RHFL.NS', 'yahoo', start_date, end_date)
panel_dataa340 = data.DataReader('SATIN.NS', 'yahoo', start_date, end_date)
panel_dataa341 = data.DataReader('HERCULES.NS', 'yahoo', start_date, end_date)
panel_dataa342 = data.DataReader('PILANIINVS.NS', 'yahoo', start_date, end_date)
panel_dataa343 = data.DataReader('SONATSOFTW.NS', 'yahoo', start_date, end_date)
panel_dataa344 = data.DataReader('EMAMIREAL.NS', 'yahoo', start_date, end_date)
panel_dataa345 = data.DataReader('KOPRAN.NS', 'yahoo', start_date, end_date)
panel_dataa346 = data.DataReader('HINDOILEXP.NS', 'yahoo', start_date, end_date)
panel_dataa347 = data.DataReader('HONDAPOWER.NS', 'yahoo', start_date, end_date)
panel_dataa348 = data.DataReader('SPICEJET.NS', 'yahoo', start_date, end_date)
panel_dataa349 = data.DataReader('SAGCEM.NS', 'yahoo', start_date, end_date)
panel_dataa350 = data.DataReader('SUMMITSEC.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa301['SYMBOL']='HCC.NS'
panel_dataa302['SYMBOL']='UFO.NS'
panel_dataa303['SYMBOL']='RAJRATAN.NS'
panel_dataa304['SYMBOL']='MAWANASUG.NS'
panel_dataa305['SYMBOL']='SYNCOM.NS'
panel_dataa306['SYMBOL']='IZMO.NS'
panel_dataa307['SYMBOL']='DECCANCE.NS'
panel_dataa308['SYMBOL']='SUZLON.NS'
panel_dataa309['SYMBOL']='TRIL.NS'
panel_dataa310['SYMBOL']='SYMPHONY.NS'
panel_dataa311['SYMBOL']='HINDCOMPOS.NS'
panel_dataa312['SYMBOL']='IFBAGRO.NS'
panel_dataa313['SYMBOL']='PAPERPROD.NS'
panel_dataa314['SYMBOL']='AAVAS.NS'
panel_dataa315['SYMBOL']='PRSMJOHNSN.NS'
panel_dataa316['SYMBOL']='APARINDS.NS'
panel_dataa317['SYMBOL']='ALLCARGO.NS'
panel_dataa318['SYMBOL']='OCCL.NS'
panel_dataa319['SYMBOL']='RSYSTEMS.NS'
panel_dataa320['SYMBOL']='DFMFOODS.NS'
panel_dataa321['SYMBOL']='MUNJALSHOW.NS'
panel_dataa322['SYMBOL']='TVTODAY.NS'
panel_dataa323['SYMBOL']='NBVENTURES.NS'
panel_dataa324['SYMBOL']='BRIGADE.NS'
panel_dataa325['SYMBOL']='SEQUENT.NS'
panel_dataa326['SYMBOL']='TBZ.NS'
panel_dataa327['SYMBOL']='TCPLPACK.NS'
panel_dataa328['SYMBOL']='GARFIBRES.NS'
panel_dataa329['SYMBOL']='VIDEOIND.NS'
panel_dataa330['SYMBOL']='MOREPENLAB.NS'
panel_dataa331['SYMBOL']='ENERGYDEV.NS'
panel_dataa332['SYMBOL']='GFLLIMITED.NS'
panel_dataa333['SYMBOL']='ROSSELLIND.NS'
panel_dataa334['SYMBOL']='PRESTIGE.NS'
panel_dataa335['SYMBOL']='GREENLAM.NS'
panel_dataa336['SYMBOL']='SUVENPHAR.NS'
panel_dataa337['SYMBOL']='ORIENTREF.NS'
panel_dataa338['SYMBOL']='PENINLAND.NS'
panel_dataa339['SYMBOL']='RHFL.NS'
panel_dataa340['SYMBOL']='SATIN.NS'
panel_dataa341['SYMBOL']='HERCULES.NS'
panel_dataa342['SYMBOL']='PILANIINVS.NS'
panel_dataa343['SYMBOL']='SONATSOFTW.NS'
panel_dataa344['SYMBOL']='EMAMIREAL.NS'
panel_dataa345['SYMBOL']='KOPRAN.NS'
panel_dataa346['SYMBOL']='HINDOILEXP.NS'
panel_dataa347['SYMBOL']='HONDAPOWER.NS'
panel_dataa348['SYMBOL']='SPICEJET.NS'
panel_dataa349['SYMBOL']='SAGCEM.NS'
panel_dataa350['SYMBOL']='SUMMITSEC.NS'

# %%
finall = pd.concat([panel_dataa301,
panel_dataa302,
panel_dataa303,
panel_dataa304,
panel_dataa305,
panel_dataa306,
panel_dataa307,
panel_dataa308,
panel_dataa309,
panel_dataa310,
panel_dataa311,
panel_dataa312,
panel_dataa313,
panel_dataa314,
panel_dataa315,
panel_dataa316,
panel_dataa317,
panel_dataa318,
panel_dataa319,
panel_dataa320,
panel_dataa321,
panel_dataa322,
panel_dataa323,
panel_dataa324,
panel_dataa325,
panel_dataa326,
panel_dataa327,
panel_dataa328,
panel_dataa329,
panel_dataa330,
panel_dataa331,
panel_dataa332,
panel_dataa333,
panel_dataa334,
panel_dataa335,
panel_dataa336,
panel_dataa337,
panel_dataa338,
panel_dataa339,
panel_dataa340,
panel_dataa341,
panel_dataa342,
panel_dataa343,
panel_dataa344,
panel_dataa345,
panel_dataa346,
panel_dataa347,
panel_dataa348,
panel_dataa349,
panel_dataa350])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_301_TO_350_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_301_TO_350_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_301_TO_350_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date        High  ...   Volume   Adj Close        SYMBOL
# 0                0  1996-01-01    2.590550  ...  36783.0    0.000077        HCC.NS
# 1                1  1996-01-02    2.590550  ...  62419.0    0.000074        HCC.NS
# 2                2  1996-01-03    2.422340  ...  21178.0    0.000073        HCC.NS
# 3                3  1996-01-04    2.399910  ...   4459.0    0.000070        HCC.NS
# 4                4  1996-01-05    2.332620  ...  27866.0    0.000071        HCC.NS
# ...            ...         ...         ...  ...      ...         ...           ...
# 145625      145625  2020-08-10  406.549988  ...   2922.0  400.100006  SUMMITSEC.NS
# 145626      145626  2020-08-11  410.000000  ...   3430.0  392.000000  SUMMITSEC.NS
# 145627      145627  2020-08-12  405.600006  ...   1472.0  400.200012  SUMMITSEC.NS
# 145628      145628  2020-08-13  414.850006  ...   1100.0  400.200012  SUMMITSEC.NS
# ...
