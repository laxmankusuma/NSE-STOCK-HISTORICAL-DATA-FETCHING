# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa251 = data.DataReader('KENNAMET.NS', 'yahoo', start_date, end_date)
panel_dataa252 = data.DataReader('SHANKARA.NS', 'yahoo', start_date, end_date)
panel_dataa253 = data.DataReader('PGEL.NS', 'yahoo', start_date, end_date)
panel_dataa254 = data.DataReader('SUNTV.NS', 'yahoo', start_date, end_date)
panel_dataa255 = data.DataReader('DCAL.NS', 'yahoo', start_date, end_date)
panel_dataa256 = data.DataReader('JOCIL.NS', 'yahoo', start_date, end_date)
panel_dataa257 = data.DataReader('JAICORPLTD.NS', 'yahoo', start_date, end_date)
panel_dataa258 = data.DataReader('AKASH.NS', 'yahoo', start_date, end_date)
panel_dataa259 = data.DataReader('PRICOLLTD.NS', 'yahoo', start_date, end_date)
panel_dataa260 = data.DataReader('DALMIASUG.NS', 'yahoo', start_date, end_date)
panel_dataa261 = data.DataReader('NILAINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa262 = data.DataReader('RELIGARE.NS', 'yahoo', start_date, end_date)
panel_dataa263 = data.DataReader('LYPSAGEMS.NS', 'yahoo', start_date, end_date)
panel_dataa264 = data.DataReader('TVSMOTOR.NS', 'yahoo', start_date, end_date)
panel_dataa265 = data.DataReader('TEJASNET.NS', 'yahoo', start_date, end_date)
panel_dataa266 = data.DataReader('BROOKS.NS', 'yahoo', start_date, end_date)
panel_dataa267 = data.DataReader('HGINFRA.NS', 'yahoo', start_date, end_date)
panel_dataa268 = data.DataReader('PTL.NS', 'yahoo', start_date, end_date)
panel_dataa269 = data.DataReader('SANGHIIND.NS', 'yahoo', start_date, end_date)
panel_dataa270 = data.DataReader('HAL.NS', 'yahoo', start_date, end_date)
panel_dataa271 = data.DataReader('SURANAT&P.NS', 'yahoo', start_date, end_date)
panel_dataa272 = data.DataReader('GSS.NS', 'yahoo', start_date, end_date)
panel_dataa273 = data.DataReader('AARVEEDEN.NS', 'yahoo', start_date, end_date)
panel_dataa274 = data.DataReader('GOCLCORP.NS', 'yahoo', start_date, end_date)
panel_dataa275 = data.DataReader('SUNTECK.NS', 'yahoo', start_date, end_date)
panel_dataa276 = data.DataReader('JHS.NS', 'yahoo', start_date, end_date)
panel_dataa277 = data.DataReader('COSMOFILMS.NS', 'yahoo', start_date, end_date)
panel_dataa278 = data.DataReader('KELLTONTEC.NS', 'yahoo', start_date, end_date)
panel_dataa279 = data.DataReader('TVSSRICHAK.NS', 'yahoo', start_date, end_date)
panel_dataa280 = data.DataReader('20MICRONS.NS', 'yahoo', start_date, end_date)
panel_dataa281 = data.DataReader('ABAN.NS', 'yahoo', start_date, end_date)
panel_dataa282 = data.DataReader('JMTAUTOLTD.NS', 'yahoo', start_date, end_date)
panel_dataa283 = data.DataReader('PENIND.NS', 'yahoo', start_date, end_date)
panel_dataa284 = data.DataReader('SINTEX.NS', 'yahoo', start_date, end_date)
panel_dataa285 = data.DataReader('JMCPROJECT.NS', 'yahoo', start_date, end_date)
panel_dataa286 = data.DataReader('SUVEN.NS', 'yahoo', start_date, end_date)
panel_dataa287 = data.DataReader('SHARDACROP.NS', 'yahoo', start_date, end_date)
panel_dataa288 = data.DataReader('FELDVR.NS', 'yahoo', start_date, end_date)
panel_dataa289 = data.DataReader('BPL.NS', 'yahoo', start_date, end_date)
panel_dataa290 = data.DataReader('SUMEETINDS.NS', 'yahoo', start_date, end_date)
panel_dataa291 = data.DataReader('ZEEMEDIA.NS', 'yahoo', start_date, end_date)
panel_dataa292 = data.DataReader('TATACOMM.NS', 'yahoo', start_date, end_date)
panel_dataa293 = data.DataReader('SAKHTISUG.NS', 'yahoo', start_date, end_date)
panel_dataa294 = data.DataReader('TFCILTD.NS', 'yahoo', start_date, end_date)
panel_dataa295 = data.DataReader('HTMEDIA.NS', 'yahoo', start_date, end_date)
panel_dataa296 = data.DataReader('NAVNETEDUL.NS', 'yahoo', start_date, end_date)
panel_dataa297 = data.DataReader('ESSELPACK.NS', 'yahoo', start_date, end_date)
panel_dataa298 = data.DataReader('ELECTCAST.NS', 'yahoo', start_date, end_date)
panel_dataa299 = data.DataReader('KCP.NS', 'yahoo', start_date, end_date)
panel_dataa300 = data.DataReader('BARTRONICS.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa251['SYMBOL']='KENNAMET.NS'
panel_dataa252['SYMBOL']='SHANKARA.NS'
panel_dataa253['SYMBOL']='PGEL.NS'
panel_dataa254['SYMBOL']='SUNTV.NS'
panel_dataa255['SYMBOL']='DCAL.NS'
panel_dataa256['SYMBOL']='JOCIL.NS'
panel_dataa257['SYMBOL']='JAICORPLTD.NS'
panel_dataa258['SYMBOL']='AKASH.NS'
panel_dataa259['SYMBOL']='PRICOLLTD.NS'
panel_dataa260['SYMBOL']='DALMIASUG.NS'
panel_dataa261['SYMBOL']='NILAINFRA.NS'
panel_dataa262['SYMBOL']='RELIGARE.NS'
panel_dataa263['SYMBOL']='LYPSAGEMS.NS'
panel_dataa264['SYMBOL']='TVSMOTOR.NS'
panel_dataa265['SYMBOL']='TEJASNET.NS'
panel_dataa266['SYMBOL']='BROOKS.NS'
panel_dataa267['SYMBOL']='HGINFRA.NS'
panel_dataa268['SYMBOL']='PTL.NS'
panel_dataa269['SYMBOL']='SANGHIIND.NS'
panel_dataa270['SYMBOL']='HAL.NS'
panel_dataa271['SYMBOL']='SURANAT&P.NS'
panel_dataa272['SYMBOL']='GSS.NS'
panel_dataa273['SYMBOL']='AARVEEDEN.NS'
panel_dataa274['SYMBOL']='GOCLCORP.NS'
panel_dataa275['SYMBOL']='SUNTECK.NS'
panel_dataa276['SYMBOL']='JHS.NS'
panel_dataa277['SYMBOL']='COSMOFILMS.NS'
panel_dataa278['SYMBOL']='KELLTONTEC.NS'
panel_dataa279['SYMBOL']='TVSSRICHAK.NS'
panel_dataa280['SYMBOL']='20MICRONS.NS'
panel_dataa281['SYMBOL']='ABAN.NS'
panel_dataa282['SYMBOL']='JMTAUTOLTD.NS'
panel_dataa283['SYMBOL']='PENIND.NS'
panel_dataa284['SYMBOL']='SINTEX.NS'
panel_dataa285['SYMBOL']='JMCPROJECT.NS'
panel_dataa286['SYMBOL']='SUVEN.NS'
panel_dataa287['SYMBOL']='SHARDACROP.NS'
panel_dataa288['SYMBOL']='FELDVR.NS'
panel_dataa289['SYMBOL']='BPL.NS'
panel_dataa290['SYMBOL']='SUMEETINDS.NS'
panel_dataa291['SYMBOL']='ZEEMEDIA.NS'
panel_dataa292['SYMBOL']='TATACOMM.NS'
panel_dataa293['SYMBOL']='SAKHTISUG.NS'
panel_dataa294['SYMBOL']='TFCILTD.NS'
panel_dataa295['SYMBOL']='HTMEDIA.NS'
panel_dataa296['SYMBOL']='NAVNETEDUL.NS'
panel_dataa297['SYMBOL']='ESSELPACK.NS'
panel_dataa298['SYMBOL']='ELECTCAST.NS'
panel_dataa299['SYMBOL']='KCP.NS'
panel_dataa300['SYMBOL']='BARTRONICS.NS'

# %%
finall = pd.concat([panel_dataa251,
panel_dataa252,
panel_dataa253,
panel_dataa254,
panel_dataa255,
panel_dataa256,
panel_dataa257,
panel_dataa258,
panel_dataa259,
panel_dataa260,
panel_dataa261,
panel_dataa262,
panel_dataa263,
panel_dataa264,
panel_dataa265,
panel_dataa266,
panel_dataa267,
panel_dataa268,
panel_dataa269,
panel_dataa270,
panel_dataa271,
panel_dataa272,
panel_dataa273,
panel_dataa274,
panel_dataa275,
panel_dataa276,
panel_dataa277,
panel_dataa278,
panel_dataa279,
panel_dataa280,
panel_dataa281,
panel_dataa282,
panel_dataa283,
panel_dataa284,
panel_dataa285,
panel_dataa286,
panel_dataa287,
panel_dataa288,
panel_dataa289,
panel_dataa290,
panel_dataa291,
panel_dataa292,
panel_dataa293,
panel_dataa294,
panel_dataa295,
panel_dataa296,
panel_dataa297,
panel_dataa298,
panel_dataa299,
panel_dataa300])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_251_TO_300_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_251_TO_300_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_251_TO_300_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date     High  ...   Volume    Adj Close         SYMBOL
# 0                0  2019-08-19  1000.00  ...   3014.0   942.500000    KENNAMET.NS
# 1                1  2019-08-20   970.00  ...   1180.0   942.400024    KENNAMET.NS
# 2                2  2019-08-21   975.00  ...   8061.0   969.950012    KENNAMET.NS
# 3                3  2019-08-22  1019.00  ...   8572.0   970.549988    KENNAMET.NS
# 4                4  2019-08-23  1060.00  ...  26678.0  1049.500000    KENNAMET.NS
# ...            ...         ...      ...  ...      ...          ...            ...
# 156935      156935  2020-08-10     1.80  ...   9722.0     1.750000  BARTRONICS.NS
# 156936      156936  2020-08-11     1.80  ...   3556.0     1.800000  BARTRONICS.NS
# 156937      156937  2020-08-12     1.85  ...   1011.0     1.850000  BARTRONICS.NS
# 156938      156938  2020-08-13     1.90  ...   2481.0     1.900000  BARTRONICS.NS
# ...
