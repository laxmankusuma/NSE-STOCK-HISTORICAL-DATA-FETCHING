# %%
# !pip install pandas-datareader

# %%
# import required
from pandas_datareader import data
import matplotlib.pyplot as plt

import pandas as pd

#define start and end date
start_date = '1970-01-01'
end_date = '2020-08-14'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
panel_dataa1201 = data.DataReader('SNOWMAN.NS', 'yahoo', start_date, end_date)
panel_dataa1202 = data.DataReader('PSPPROJECT.NS', 'yahoo', start_date, end_date)
panel_dataa1203 = data.DataReader('PALREDTEC.NS', 'yahoo', start_date, end_date)
panel_dataa1204 = data.DataReader('MOHOTAIND.NS', 'yahoo', start_date, end_date)
panel_dataa1205 = data.DataReader('JCHAC.NS', 'yahoo', start_date, end_date)
panel_dataa1206 = data.DataReader('SKMEGGPROD.NS', 'yahoo', start_date, end_date)
panel_dataa1207 = data.DataReader('GLOBUSSPR.NS', 'yahoo', start_date, end_date)
panel_dataa1208 = data.DataReader('SYNGENE.NS', 'yahoo', start_date, end_date)
panel_dataa1209 = data.DataReader('MAGADSUGAR.NS', 'yahoo', start_date, end_date)
panel_dataa1210 = data.DataReader('KOTHARIPET.NS', 'yahoo', start_date, end_date)
panel_dataa1211 = data.DataReader('LAXMIMACH.NS', 'yahoo', start_date, end_date)
panel_dataa1212 = data.DataReader('MAGMA.NS', 'yahoo', start_date, end_date)
panel_dataa1213 = data.DataReader('MAJESCO.NS', 'yahoo', start_date, end_date)
panel_dataa1214 = data.DataReader('VIDHIING.NS', 'yahoo', start_date, end_date)
panel_dataa1215 = data.DataReader('SUPPETRO.NS', 'yahoo', start_date, end_date)
panel_dataa1216 = data.DataReader('WATERBASE.NS', 'yahoo', start_date, end_date)
panel_dataa1217 = data.DataReader('ANDHRAPAP.NS', 'yahoo', start_date, end_date)
panel_dataa1218 = data.DataReader('JAMNAAUTO.NS', 'yahoo', start_date, end_date)
panel_dataa1219 = data.DataReader('ADORWELD.NS', 'yahoo', start_date, end_date)
panel_dataa1220 = data.DataReader('MOTHERSUMI.NS', 'yahoo', start_date, end_date)
panel_dataa1221 = data.DataReader('CANTABIL.NS', 'yahoo', start_date, end_date)
panel_dataa1222 = data.DataReader('ALOKINDS.NS', 'yahoo', start_date, end_date)
panel_dataa1223 = data.DataReader('ONWARDTEC.NS', 'yahoo', start_date, end_date)
panel_dataa1224 = data.DataReader('MANGLMCEM.NS', 'yahoo', start_date, end_date)
panel_dataa1225 = data.DataReader('CEREBRAINT.NS', 'yahoo', start_date, end_date)
panel_dataa1226 = data.DataReader('SETCO.NS', 'yahoo', start_date, end_date)
panel_dataa1227 = data.DataReader('INDOSTAR.NS', 'yahoo', start_date, end_date)
panel_dataa1228 = data.DataReader('EMKAY.NS', 'yahoo', start_date, end_date)
panel_dataa1229 = data.DataReader('HLVLTD.NS', 'yahoo', start_date, end_date)
panel_dataa1230 = data.DataReader('SREEL.NS', 'yahoo', start_date, end_date)
panel_dataa1231 = data.DataReader('AIONJSW.NS', 'yahoo', start_date, end_date)
panel_dataa1232 = data.DataReader('RKFORGE.NS', 'yahoo', start_date, end_date)
panel_dataa1233 = data.DataReader('WONDERLA.NS', 'yahoo', start_date, end_date)
panel_dataa1234 = data.DataReader('PSB.NS', 'yahoo', start_date, end_date)
panel_dataa1235 = data.DataReader('SHALBY.NS', 'yahoo', start_date, end_date)
panel_dataa1236 = data.DataReader('JPASSOCIAT.NS', 'yahoo', start_date, end_date)
panel_dataa1237 = data.DataReader('EXCELINDUS.NS', 'yahoo', start_date, end_date)
panel_dataa1238 = data.DataReader('FOSECOIND.NS', 'yahoo', start_date, end_date)
panel_dataa1239 = data.DataReader('SUPRAJIT.NS', 'yahoo', start_date, end_date)
panel_dataa1240 = data.DataReader('EMMBI.NS', 'yahoo', start_date, end_date)
panel_dataa1241 = data.DataReader('INTELLECT.NS', 'yahoo', start_date, end_date)
panel_dataa1242 = data.DataReader('TIRUMALCHM.NS', 'yahoo', start_date, end_date)
panel_dataa1243 = data.DataReader('GULPOLY.NS', 'yahoo', start_date, end_date)
panel_dataa1244 = data.DataReader('LUMAXTECH.NS', 'yahoo', start_date, end_date)
panel_dataa1245 = data.DataReader('SUPREMEIND.NS', 'yahoo', start_date, end_date)
panel_dataa1246 = data.DataReader('NATHBIOGEN.NS', 'yahoo', start_date, end_date)
panel_dataa1247 = data.DataReader('TTML.NS', 'yahoo', start_date, end_date)
panel_dataa1248 = data.DataReader('SMARTLINK.NS', 'yahoo', start_date, end_date)
panel_dataa1249 = data.DataReader('ADFFOODS.NS', 'yahoo', start_date, end_date)
panel_dataa1250 = data.DataReader('HBLPOWER.NS', 'yahoo', start_date, end_date)

# %%
panel_dataa1201['SYMBOL']='SNOWMAN.NS'
panel_dataa1202['SYMBOL']='PSPPROJECT.NS'
panel_dataa1203['SYMBOL']='PALREDTEC.NS'
panel_dataa1204['SYMBOL']='MOHOTAIND.NS'
panel_dataa1205['SYMBOL']='JCHAC.NS'
panel_dataa1206['SYMBOL']='SKMEGGPROD.NS'
panel_dataa1207['SYMBOL']='GLOBUSSPR.NS'
panel_dataa1208['SYMBOL']='SYNGENE.NS'
panel_dataa1209['SYMBOL']='MAGADSUGAR.NS'
panel_dataa1210['SYMBOL']='KOTHARIPET.NS'
panel_dataa1211['SYMBOL']='LAXMIMACH.NS'
panel_dataa1212['SYMBOL']='MAGMA.NS'
panel_dataa1213['SYMBOL']='MAJESCO.NS'
panel_dataa1214['SYMBOL']='VIDHIING.NS'
panel_dataa1215['SYMBOL']='SUPPETRO.NS'
panel_dataa1216['SYMBOL']='WATERBASE.NS'
panel_dataa1217['SYMBOL']='ANDHRAPAP.NS'
panel_dataa1218['SYMBOL']='JAMNAAUTO.NS'
panel_dataa1219['SYMBOL']='ADORWELD.NS'
panel_dataa1220['SYMBOL']='MOTHERSUMI.NS'
panel_dataa1221['SYMBOL']='CANTABIL.NS'
panel_dataa1222['SYMBOL']='ALOKINDS.NS'
panel_dataa1223['SYMBOL']='ONWARDTEC.NS'
panel_dataa1224['SYMBOL']='MANGLMCEM.NS'
panel_dataa1225['SYMBOL']='CEREBRAINT.NS'
panel_dataa1226['SYMBOL']='SETCO.NS'
panel_dataa1227['SYMBOL']='INDOSTAR.NS'
panel_dataa1228['SYMBOL']='EMKAY.NS'
panel_dataa1229['SYMBOL']='HLVLTD.NS'
panel_dataa1230['SYMBOL']='SREEL.NS'
panel_dataa1231['SYMBOL']='AIONJSW.NS'
panel_dataa1232['SYMBOL']='RKFORGE.NS'
panel_dataa1233['SYMBOL']='WONDERLA.NS'
panel_dataa1234['SYMBOL']='PSB.NS'
panel_dataa1235['SYMBOL']='SHALBY.NS'
panel_dataa1236['SYMBOL']='JPASSOCIAT.NS'
panel_dataa1237['SYMBOL']='EXCELINDUS.NS'
panel_dataa1238['SYMBOL']='FOSECOIND.NS'
panel_dataa1239['SYMBOL']='SUPRAJIT.NS'
panel_dataa1240['SYMBOL']='EMMBI.NS'
panel_dataa1241['SYMBOL']='INTELLECT.NS'
panel_dataa1242['SYMBOL']='TIRUMALCHM.NS'
panel_dataa1243['SYMBOL']='GULPOLY.NS'
panel_dataa1244['SYMBOL']='LUMAXTECH.NS'
panel_dataa1245['SYMBOL']='SUPREMEIND.NS'
panel_dataa1246['SYMBOL']='NATHBIOGEN.NS'
panel_dataa1247['SYMBOL']='TTML.NS'
panel_dataa1248['SYMBOL']='SMARTLINK.NS'
panel_dataa1249['SYMBOL']='ADFFOODS.NS'
panel_dataa1250['SYMBOL']='HBLPOWER.NS'

# %%
finall = pd.concat([panel_dataa1201,
panel_dataa1202,
panel_dataa1203,
panel_dataa1204,
panel_dataa1205,
panel_dataa1206,
panel_dataa1207,
panel_dataa1208,
panel_dataa1209,
panel_dataa1210,
panel_dataa1211,
panel_dataa1212,
panel_dataa1213,
panel_dataa1214,
panel_dataa1215,
panel_dataa1216,
panel_dataa1217,
panel_dataa1218,
panel_dataa1219,
panel_dataa1220,
panel_dataa1221,
panel_dataa1222,
panel_dataa1223,
panel_dataa1224,
panel_dataa1225,
panel_dataa1226,
panel_dataa1227,
panel_dataa1228,
panel_dataa1229,
panel_dataa1230,
panel_dataa1231,
panel_dataa1232,
panel_dataa1233,
panel_dataa1234,
panel_dataa1235,
panel_dataa1236,
panel_dataa1237,
panel_dataa1238,
panel_dataa1239,
panel_dataa1240,
panel_dataa1241,
panel_dataa1242,
panel_dataa1243,
panel_dataa1244,
panel_dataa1245,
panel_dataa1246,
panel_dataa1247,
panel_dataa1248,
panel_dataa1249,
panel_dataa1250])

# %%
# to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#create file in local colab 
finall.reset_index().to_csv('NSE_1201_TO_1250_start_to_15082020.csv')

#copy colab to google drive
# !cp NSE_1201_TO_1250_start_to_15082020.csv "drive/My Drive/"

#read file from google drive
readdf = pd.read_csv("drive/My Drive/NSE_1201_TO_1250_start_to_15082020.csv")

readdf
# Out:
#         Unnamed: 0        Date       High  ...     Volume  Adj Close       SYMBOL
# 0                0  2014-09-12  79.800003  ...  9477447.0  79.435120   SNOWMAN.NS
# 1                1  2014-09-15  83.750000  ...   131729.0  83.367058   SNOWMAN.NS
# 2                2  2014-09-16  87.900002  ...  6748416.0  81.326431   SNOWMAN.NS
# 3                3  2014-09-17  85.750000  ...  2271887.0  85.357910   SNOWMAN.NS
# 4                4  2014-09-18  90.000000  ...   483947.0  89.588478   SNOWMAN.NS
# ...            ...         ...        ...  ...        ...        ...          ...
# 135792      135792  2020-08-10  15.800000  ...   845886.0  15.550000  HBLPOWER.NS
# 135793      135793  2020-08-11  16.150000  ...   750771.0  15.650000  HBLPOWER.NS
# 135794      135794  2020-08-12  16.350000  ...  1215338.0  16.049999  HBLPOWER.NS
# 135795      135795  2020-08-13  17.000000  ...  1674201.0  16.750000  HBLPOWER.NS
# ...
